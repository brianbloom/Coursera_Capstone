# %% [markdown]
# # Battle of the Neighborhoods
# ### Brian Bloom
# ### Coursera Capstone Final Project
# Dec, 2020

# %%
import pandas as pd
path = 'Capstone src files/uszips.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    zip       lat       lng       city state_id   state_name  zcta  \
# 0  601  18.18004 -66.75218   Adjuntas       PR  Puerto Rico  True
# 1  602  18.36073 -67.17517     Aguada       PR  Puerto Rico  True
# 2  603  18.45439 -67.12202  Aguadilla       PR  Puerto Rico  True
# 3  606  18.16724 -66.93828    Maricao       PR  Puerto Rico  True
# 4  610  18.29032 -67.12243     Anasco       PR  Puerto Rico  True
#
#    parent_zcta  population  density  county_fips county_name  \
# 0          NaN       17242    111.4        72001    Adjuntas
# 1          NaN       38442    523.5        72003      Aguada
# 2          NaN       48814    667.9        72005   Aguadilla
# 3          NaN        6437     60.4        72093     Maricao
# 4          NaN       27073    312.0        72011      Añasco
#
#                               county_weights             county_names_all  \
# 0               {'72001':99.43,'72141':0.57}              Adjuntas|Utuado
# 1                              {'72003':100}                       Aguada
# 2                              {'72005':100}                    Aguadilla
# 3  {'72093':94.88,'72121':1.35,'72153':3.78}  Maricao|Yauco|Sabana Grande
# 4               {'72003':0.55,'72011':99.45}                Añasco|Aguada
#
#      county_fips_all  imprecise  military             timezone
# 0        72001|72141      False     False  America/Puerto_Rico
# 1              72003      False     False  America/Puerto_Rico
# 2              72005      False     False  America/Puerto_Rico
# 3  72093|72153|72121      False     False  America/Puerto_Rico
# 4        72011|72003      False     False  America/Puerto_Rico

# %%
keepcolumns = ['zip','lat','lng','city','state_id','population']
df_filt = df.loc[:, keepcolumns]

# %%
df_filt
austx_zips = df_filt[(df_filt.city == 'Austin') & (df_filt.state_id == 'TX')]
austx_zips
# Out:
#          zip       lat       lng    city state_id  population
# 27354  78701  30.27049 -97.74235  Austin       TX        9427
# 27355  78702  30.26327 -97.71432  Austin       TX       23389
# 27356  78703  30.29409 -97.76571  Austin       TX       20890
# 27357  78704  30.24315 -97.76537  Austin       TX       48486
# 27358  78705  30.29437 -97.73855  Austin       TX       33948
# 27359  78712  30.28502 -97.73477  Austin       TX         860
# 27360  78717  30.48988 -97.75371  Austin       TX       30218
# 27361  78719  30.14483 -97.67083  Austin       TX        1815
# 27362  78721  30.27005 -97.68365  Austin       TX       12492
# 27363  78722  30.28997 -97.71465  Austin       TX        7110
# 27364  78723  30.30427 -97.68570  Austin       TX       34569
# 27365  78724  30.29440 -97.61415  Austin       TX       24779
# 27366  78725  30.23581 -97.60837  Austin       TX        7886
# 27367  78726  30.42949 -97.84207  Austin       TX       13867
# 27368  78727  30.42950 -97.71741  Austin       TX       29509
# 27369  78728  30.45655 -97.68986  Austin       TX       21480
# 27370  78729  30.45842 -97.75595  Austin       TX       29315
# 27371  78730  30.36489 -97.83731  Austin       TX        9186
# 27372  78731  30.34736 -97.76847  Austin       TX       27175
# 27373  78732  30.37912 -97.89310  Austin       TX       17849
# 27374  78733  30.32323 -97.87609  Austin       TX        8611
# 27375  78734  30.37853 -97.94961  Austin       TX       18745
# 27376  78735  30.26590 -97.86658  Austin       TX       17923
# 27377  78736  30.26110 -97.95944  Austin       TX        9047
# 27378  78737  30.18779 -97.95966  Austin       TX       16160
# 27379  78738  30.31942 -97.95838  Austin       TX       15589
# 27380  78739  30.17845 -97.88869  Austin       TX       20312
# 27381  78741  30.23049 -97.71401  Austin       TX       52716
# 27382  78742  30.24413 -97.65830  Austin       TX         828
# 27383  78744  30.18277 -97.72920  Austin       TX       48969
# 27384  78745  30.20685 -97.79738  Austin       TX       62771
# 27385  78746  30.29729 -97.81054  Austin       TX       28495
# 27386  78747  30.12653 -97.74017  Austin       TX       20166
# 27387  78748  30.16538 -97.82343  Austin       TX       50997
# 27388  78749  30.21376 -97.85821  Austin       TX       37774
# 27389  78750  30.41828 -97.80246  Austin       TX       30847
# 27390  78751  30.31082 -97.72274  Austin       TX       15805
# 27391  78752  30.33180 -97.70426  Austin       TX       21324
# 27392  78753  30.38204 -97.67361  Austin       TX       59085
# 27393  78754  30.35575 -97.64482  Austin       TX       24408
# 27394  78756  30.32227 -97.74017  Austin       TX        8323
# 27395  78757  30.35158 -97.73252  Austin       TX       24823
# 27396  78758  30.38799 -97.70684  Austin       TX       47470
# 27397  78759  30.40268 -97.76105  Austin       TX       42524

# %%
# save a local copy of the smaller set
austx_zips.to_csv('austx_zips.csv')

# %% [markdown]
# Let's do a quick visual check to make sure we have all of the main Austin area covered

# %%
import numpy as np 
import folium
#I'll just use one of the central postal codes (78751) as the map starting point rather than calling Nominatim to get it
latitude = 30.31082
longitude = -97.72274

# %%
austxmap = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, zipcode, population in zip(austx_zips['lat'], austx_zips['lng'], austx_zips['zip'], austx_zips['population']):
    label = str(zipcode)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=2*int(np.log10(population)), #scales the points to represent population in that zip
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(austxmap)  
    
austxmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## First criteria: affordability

# %% [markdown]
# Now let's merge in the Rent prices so we can rule out those places that are just too expensive

# %%
path = 'Capstone src files/AustinRents.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    ZIP\nCode     HUD Area Code HUD Metro Fair Market Rent Area Name  \
# 0      76511  METRO12420M12420            Austin-Round Rock, TX MSA
# 1      76527  METRO12420M12420            Austin-Round Rock, TX MSA
# 2      76530  METRO12420M12420            Austin-Round Rock, TX MSA
# 3      76537  METRO12420M12420            Austin-Round Rock, TX MSA
# 4      76571  METRO12420M12420            Austin-Round Rock, TX MSA
#
#   SAFMR\n0BR SAFMR\n1BR SAFMR\n2BR SAFMR\n3BR SAFMR\n4BR
# 0       $890     $1,030     $1,230     $1,590     $1,920
# 1       $890     $1,030     $1,230     $1,590     $1,920
# 2       $890     $1,030     $1,230     $1,590     $1,920
# 3       $940     $1,070     $1,270     $1,640     $1,950
# 4       $890     $1,030     $1,230     $1,590     $1,920

# %%
keepcolumns = ['ZIP\nCode','SAFMR\n3BR','SAFMR\n4BR']
df_filt = df.loc[:, keepcolumns]
df_filt.columns = ['zip','rent3br','rent4br']
df_filt
# Out:
#        zip rent3br rent4br
# 0    76511  $1,590  $1,920
# 1    76527  $1,590  $1,920
# 2    76530  $1,590  $1,920
# 3    76537  $1,640  $1,950
# 4    76571  $1,590  $1,920
# ..     ...     ...     ...
# 127  78942  $1,590  $1,920
# 128  78945  $1,590  $1,920
# 129  78953  $2,100  $2,510
# 130  78957  $1,590  $1,920
# 131  78959  $1,590  $1,920
#
# [132 rows x 3 columns]

# %% [markdown]
# We can see this has more rows because it includes the full metro area around Austin, rather than just the zip codes of the City of Austin.
#
# Given that we want to use transit, we probably don't want to go too far into neighboring suburbs, so we'll just use a left join from the "proper" Austin city zip codes to filter those outliers out.

# %%
austx_zr = austx_zips.merge(df_filt, on='zip',how='left')

# %%
austx_zr.head()
# Out:
#      zip       lat       lng    city state_id  population rent3br rent4br
# 0  78701  30.27049 -97.74235  Austin       TX        9427  $2,770  $3,310
# 1  78702  30.26327 -97.71432  Austin       TX       23389  $1,790  $2,140
# 2  78703  30.29409 -97.76571  Austin       TX       20890  $2,020  $2,420
# 3  78704  30.24315 -97.76537  Austin       TX       48486  $2,170  $2,590
# 4  78705  30.29437 -97.73855  Austin       TX       33948  $2,450  $2,920

# %%
austx_zr.shape
# Out:
# (44, 8)

# %%
#check to make sure no nulls
print("number of NaN values for rents :", austx_zr['rent3br'].isnull().sum())
# Out:
# number of NaN values for rents : 0

# %% [markdown]
# Let's come up with an affordability metric that we can use for filtering out expensive places, and highlight ones that are cheaper. For the purposes of this study, I'll look at 3 bedroom options since that would allow for a room for my daughter, plus an office space. Ultimately I'll tell my realtor that any 4 bedrooms that are not much more will also be worth looking into.
#
# I will consider my ideal rent for a 3 bedroom to be 1800. The rental data from the federal HUD database lists the median rents, so even if the *median* cost in a zip is out of my range, it's likely that that zip code will contain some units at lower rates. So I'll use a 20% over my budget as the center point for what I hope to afford, or $2160.
#
# So, (2160 - rent3br) will produce positive numbers for places under my budget, and negative ones for over it. I can then do a second pass through the data and normalize that difference for a 0-1 metric for affordability.

# %%
#first clean up the strings into numbers
austx_zr['rent3br'] = austx_zr['rent3br'].str.replace('$','').str.replace(',','').astype(int)

# %%
austx_zr['rent4br'] = austx_zr['rent4br'].str.replace('$','').str.replace(',','').astype(int)

# %%
austx_zr['bdgt3br'] = 2160 - austx_zr['rent3br']
# Out:
#      zip       lat       lng    city state_id  population  rent3br  rent4br  \
# 0  78701  30.27049 -97.74235  Austin       TX        9427     2770     3310
# 1  78702  30.26327 -97.71432  Austin       TX       23389     1790     2140
# 2  78703  30.29409 -97.76571  Austin       TX       20890     2020     2420
# 3  78704  30.24315 -97.76537  Austin       TX       48486     2170     2590
# 4  78705  30.29437 -97.73855  Austin       TX       33948     2450     2920
#
#    bdgt3br
# 0     -610
# 1      370
# 2      140
# 3      -10
# 4     -290

# %%
austx_zr.sort_values(by='bdgt3br', ascending=False, axis=0).tail(10)
# Out:
#       zip       lat       lng    city state_id  population  rent3br  rent4br  \
# 25  78738  30.31942 -97.95838  Austin       TX       15589     2320     2770
# 31  78746  30.29729 -97.81054  Austin       TX       28495     2410     2880
# 19  78732  30.37912 -97.89310  Austin       TX       17849     2440     2910
# 4   78705  30.29437 -97.73855  Austin       TX       33948     2450     2920
# 5   78712  30.28502 -97.73477  Austin       TX         860     2460     2930
# 20  78733  30.32323 -97.87609  Austin       TX        8611     2590     3090
# 21  78734  30.37853 -97.94961  Austin       TX       18745     2680     3200
# 26  78739  30.17845 -97.88869  Austin       TX       20312     2770     3310
# 24  78737  30.18779 -97.95966  Austin       TX       16160     2770     3310
# 0   78701  30.27049 -97.74235  Austin       TX        9427     2770     3310
#
#     bdgt3br
# 25     -160
# 31     -250
# 19     -280
# 4      -290
# 5      -300
# 20     -430
# 21     -520
# 26     -610
# 24     -610
# 0      -610

# %% [markdown]
# I can see there are several zip codes that are a couple hundred above my budget, even accounting for the difference between my range and the median. So I can either delete those from consideration, or flag them.
# I prefer to preserve all data in case my parameters change, so I will create a new flag column to mark those pricy ones as disqualified. And then I'll generate my affordability metric with the remainder.

# %%
austx_zr['isAffordable'] = austx_zr['bdgt3br'] > -250
austx_zr.head()
# Out:
#      zip       lat       lng    city state_id  population  rent3br  rent4br  \
# 0  78701  30.27049 -97.74235  Austin       TX        9427     2770     3310
# 1  78702  30.26327 -97.71432  Austin       TX       23389     1790     2140
# 2  78703  30.29409 -97.76571  Austin       TX       20890     2020     2420
# 3  78704  30.24315 -97.76537  Austin       TX       48486     2170     2590
# 4  78705  30.29437 -97.73855  Austin       TX       33948     2450     2920
#
#    bdgt3br  isAffordable
# 0     -610         False
# 1      370          True
# 2      140          True
# 3      -10          True
# 4     -290         False

# %%
#to simplify the feature scaling normalization formula with this new flag, I'll do it incrementally
maxrent = austx_zr.loc[austx_zr['isAffordable'] == True]['rent3br'].max()
minrent = austx_zr.loc[austx_zr['isAffordable'] == True]['rent3br'].min()
print('min: {}, max: {}'.format(minrent, maxrent))
# Out:
# min: 1590, max: 2320

# %%
# this will exceed the 0 to 1 range for the filtered items, but keep the viable candidates scaled correctly
austx_zr['rentscore'] = 1 - (austx_zr['rent3br'] - minrent)/ (maxrent - minrent)
austx_zr.head()
# Out:
#      zip       lat       lng    city state_id  population  rent3br  rent4br  \
# 0  78701  30.27049 -97.74235  Austin       TX        9427     2770     3310
# 1  78702  30.26327 -97.71432  Austin       TX       23389     1790     2140
# 2  78703  30.29409 -97.76571  Austin       TX       20890     2020     2420
# 3  78704  30.24315 -97.76537  Austin       TX       48486     2170     2590
# 4  78705  30.29437 -97.73855  Austin       TX       33948     2450     2920
#
#    bdgt3br  isAffordable  rentscore
# 0     -610         False  -0.616438
# 1      370          True   0.726027
# 2      140          True   0.410959
# 3      -10          True   0.205479
# 4     -290         False  -0.178082

# %%
#remove the negative values and make a visual to see where affordable places are:
austx_zrn = austx_zr[:]
austx_zrn['rentscore'] = austx_zrn['rentscore'].clip(lower = 0)
rentmap = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, zipcode,rentscore, afford in builtins.zip(austx_zrn['lat'], austx_zrn['lng'], austx_zrn['zip'], austx_zrn['rentscore'],austx_zrn['isAffordable']):
    label = str(zipcode)+ '\nTS:'+str(int(tsr))
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=3+10*rentscore, # should produce a 3-10 scale for the markers
        popup=label,
        color=('red','green')[afford],
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(rentmap)  
    
rentmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Second criteria: Pool for daughter
# That takes care of the first criteria, affordability.  Now I will do the steps to include the second criteria: nearby swimming pools for my daughter. She has been on a swimteam in North Carolina, and will want to maintain her practice in Austin as well. So now I will merge the data about pools in Austin into my dataset.
#
# The city of Austin maintains a very helpful open data file on its swimming pools, including lots of useful information including location, hours, open status, phone numbers, etc. This is provided in a JSON file format. Conventiently it includes lat/long so I can immediately determine proximity of the pools to each zip code.

# %% [markdown]
# City of Austin pool data: https://data.austintexas.gov/Recreation-and-Culture/Pool-Map/jfqh-bqzu

# %%
import json
path = 'Capstone src files/SwimmingPools.json'
with open(path) as json_file:
    pool_json = json.load(json_file)
pool_json
# Out:
# [{'pool_type': 'Splashpad',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Lott Splashpad',
#   'website': {'description': 'Lott Splash Pad',
#    'url': 'http://www.austintexas.gov/department/lott-splash-pad'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.269695108000064',
#    'human_address': '{"address": "1180 Curves", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.73017088999995'}},
#  {'pool_type': 'Neighborhood',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Metz',
#   'website': {'description': 'Metz Pool',
#    'url': 'http://www.austintexas.gov/department/metz-pool'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.252683793000074',
#    'human_address': '{"address": "2309 Canterbury St", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.71813028399998'}},
#  {'pool_type': 'Neighborhood',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Montopolis',
#   'website': {'description': 'Montopolis Pool',
#    'url': 'http://www.austintexas.gov/department/montopolis-pool'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.231947330000025',
#    'human_address': '{"address": "1200 Montopolis Dr", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.69905656299994'}},
#  {'pool_type': 'Neighborhood',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Canyon Vista',
#   'website': {'description': 'Canyon Vista Pool website',
#    'url': 'http://www.austintexas.gov/department/canyon-vista-pool'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.427132347000054',
#    'human_address': '{"address": "8455 Spicewood Springs", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.78468953899994'}},
#  {'pool_type': 'Neighborhood',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Kennemer',
#   'website': {'description': 'Kennemer Pool',
#    'url': 'http://www.austintexas.gov/department/kennemer-pool'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.36075515300007',
#    'human_address': '{"address": "200 Dawson Rd", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.70649799899996'}},
#  {'pool_type': 'Regional',
#   'weekend': '1:00 PM - 5:00 PM',
#   'closure_days': 'TUE/WED/SAT',
#   'weekday': '12:15 PM - 8:00 PM',
#   'open_date': '2020-09-26T12:15:00.000',
#   'status': 'Open',
#   'pool_name': 'Bartholomew',
#   'website': {'url': 'http://www.austintexas.gov/department/bartholomew-pool'},
#   'phone': '512-974-1650',
#   'location_1': {'latitude': '30.302395535000073',
#    'human_address': '{"address": "1800 E 51st St", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.69739842999996'}},
#  {'pool_type': 'Regional',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Walnut Creek',
#   'website': {'url': 'http://www.austintexas.gov/department/walnut-creek-pool'},
#   'phone': '512-834-0824',
#   'location_1': {'latitude': '30.398443986000075',
#    'human_address': '{"address": "12138 N Lamar Blvd", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.67950234099999'}},
#  {'pool_type': 'Neighborhood',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Parque Zaragoza',
#   'website': {'description': 'Parque Zaragoza Pool',
#    'url': 'http://www.austintexas.gov/department/parque-zaragoza-pool'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.262200781000047',
#    'human_address': '{"address": "2611 Webberville Rd", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.71307661199995'}},
#  {'pool_type': 'Neighborhood',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Patterson',
#   'website': {'description': 'Patterson Pool',
#    'url': 'http://www.austintexas.gov/department/patterson-pool'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.296592644000043',
#    'human_address': '{"address": "4200 Brookview Dr", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.71400165799997'}},
#  {'pool_type': 'Neighborhood',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Gillis',
#   'website': {'description': 'Gillis Pool',
#    'url': 'http://www.austintexas.gov/department/gillis-pool'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.239795595000032',
#    'human_address': '{"address": "2410 Durwood Ave", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.75878452399996'}},
#  {'pool_type': 'Neighborhood',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Martin',
#   'website': {'description': 'Martin Pool',
#    'url': 'http://www.austintexas.gov/department/martin-pool'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.250938086000076',
#    'human_address': '{"address": "1626 Nash Hernandez Sr Dr", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.73110151999998'}},
#  {'pool_type': 'Neighborhood',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Brentwood',
#   'website': {'description': 'Brentwood Pool',
#    'url': 'http://www.austintexas.gov/department/brentwood-pool'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.340441576000046',
#    'human_address': '{"address": "6710 Arroyo", "city": "Seco Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.73037097399998'}},
#  {'pool_type': 'Neighborhood',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Dottie Jordan',
#   'website': {'description': 'Dottie Jordan Pool',
#    'url': 'http://www.austintexas.gov/department/dottie-jordan-pool'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.314319348000026',
#    'human_address': '{"address": "2803 Loyola Ln", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.67341137899996'}},
#  {'pool_type': 'Regional',
#   'weekend': '9:00 AM - 7:00 PM',
#   'closure_days': 'SUN/TUE/FRI',
#   'weekday': '9:00 AM - 7:00 PM',
#   'open_date': '2020-09-26T09:00:00.000',
#   'status': 'Open',
#   'pool_name': 'Deep Eddy',
#   'website': {'url': 'http://www.austintexas.gov/department/deep-eddy-pool'},
#   'phone': '512-472-8546',
#   'location_1': {'latitude': '30.277590365000037',
#    'human_address': '{"address": "401 Deep Eddy Ave", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.77288902099997'}},
#  {'pool_type': 'Splashpad',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Bartholomew Splashpad',
#   'website': {'description': 'Bartholomew Splash Pad',
#    'url': 'http://www.austintexas.gov/department/bartholomew-splash-pad'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.305630359000077',
#    'human_address': '{"address": "5201 Berkman Dr", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.69783935199996'}},
#  {'pool_type': 'Neighborhood',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Murchison',
#   'website': {'description': 'Murchison Pool',
#    'url': 'http://www.austintexas.gov/department/murchison-pool'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.35336556900006',
#    'human_address': '{"address": "7022 Hart Ln", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.75870788799995'}},
#  {'pool_type': 'Regional',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Mabel Davis',
#   'website': {'description': 'Mabel Davis',
#    'url': 'http://www.austintexas.gov/department/mabel-davis-pool'},
#   'phone': '512-441-5247',
#   'location_1': {'latitude': '30.22025858300003',
#    'human_address': '{"address": "3427 Parker Lane", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.74271075999997'}},
#  {'pool_type': 'Regional',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Garrison',
#   'website': {'url': 'http://www.austintexas.gov/department/garrison-pool'},
#   'phone': '512-442-4048',
#   'location_1': {'latitude': '30.212930071000073',
#    'human_address': '{"address": "6001 Menchaca Rd", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.80184931899998'}},
#  {'pool_type': 'Neighborhood',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Rosewood',
#   'website': {'description': 'Rosewood Pool',
#    'url': 'http://www.austintexas.gov/department/rosewood-pool'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.271339',
#    'human_address': '{"address": "2300 Rosewood Ave", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.713836'}},
#  {'pool_type': 'Neighborhood',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Westenfield',
#   'website': {'description': 'Westenfield website',
#    'url': 'http://www.austintexas.gov/department/westenfield-pool'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.286483287000067',
#    'human_address': '{"address": "2000 Enfield Rd", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.76496863899996'}},
#  {'pool_type': 'Neighborhood',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Stacy Wading',
#   'website': {'description': 'Little Stacy Wading Pool',
#    'url': 'http://www.austintexas.gov/department/little-stacy-wading-pool'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.241312486000027',
#    'human_address': '{"address": "1401 Sunset Lane", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.74557365799996'}},
#  {'pool_type': 'Splashpad',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Metz Splashpad',
#   'website': {'description': 'Metz Splash Pad',
#    'url': 'http://www.austintexas.gov/department/metz-splash-pad'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.252683793000074',
#    'human_address': '{"address": "2407 Canterbury St", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.71813028399998'}},
#  {'pool_type': 'Regional',
#   'weekend': '5:00 AM - 10:00 PM',
#   'closure_days': 'MON/WED/THU',
#   'weekday': '5:00 AM - 10:00 PM',
#   'open_date': '2020-09-26T05:00:00.000',
#   'status': 'Open',
#   'pool_name': 'Barton Springs',
#   'website': {'url': 'http://www.austintexas.gov/department/barton-springs-pool'},
#   'phone': '512-867-3080',
#   'location_1': {'latitude': '30.265983430000063',
#    'human_address': '{"address": "2131 William Barton Dr", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.76862557799996'}},
#  {'pool_type': 'Neighborhood',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Dittmar',
#   'website': {'description': 'Dittmar Pool',
#    'url': 'http://www.austintexas.gov/department/dittmar-pool'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.185743134000063',
#    'human_address': '{"address": "1009 W Dittmar Dr", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.80106115899997'}},
#  {'pool_type': 'Splashpad',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Ricky Guerrero Splashpad',
#   'website': {'description': 'Ricky Guerrero Splash Pad',
#    'url': 'http://www.austintexas.gov/department/ricky-guerrero-splash-pad'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.246923898000034',
#    'human_address': '{"address": "1100 Brodie Street", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.76367140099995'}},
#  {'pool_type': 'Splashpad',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Clarksville Splashpad',
#   'website': {'description': 'Clarksville Splash Pad',
#    'url': 'http://www.austintexas.gov/department/clarksville-splash-pad'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.282105005000062',
#    'human_address': '{"address": "1811 W 11th St", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.76410287199997'}},
#  {'pool_type': 'Neighborhood',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Govalle',
#   'website': {'description': 'Govalle Pool',
#    'url': 'http://www.austintexas.gov/department/gillis-pool'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.258835826000052',
#    'human_address': '{"address": "5200 Bolm Rd", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.69156788399994'}},
#  {'pool_type': 'Neighborhood',
#   'weekend': '12:00 PM - 6:00 PM',
#   'closure_days': 'WED/FRI/SAT',
#   'weekday': '6:00 AM - 8:00 PM',
#   'open_date': '2020-09-26T12:00:00.000',
#   'status': 'Open',
#   'pool_name': 'Stacy',
#   'website': {'url': 'http://austintexas.gov/department/big-stacy-pool'},
#   'phone': '512-445-0304',
#   'location_1': {'latitude': '30.239596177000067',
#    'human_address': '{"address": "700 E Live Oak St", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.74730836399999'}},
#  {'pool_type': 'Community',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Dick Nichols',
#   'website': {'description': 'Dick Nichols Pool',
#    'url': 'http://www.austintexas.gov/department/dick-nichols-pool'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.21486475200004',
#    'human_address': '{"address": "8011 Beckett Rd", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.86331548799996'}},
#  {'pool_type': 'Community',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Givens',
#   'website': {'description': 'Givens Pool',
#    'url': 'http://www.austintexas.gov/department/givens-pool'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.27832090800007',
#    'human_address': '{"address": "3811 E 12th St", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.69072592299995'}},
#  {'pool_type': 'Neighborhood',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Ramsey',
#   'website': {'url': 'http://www.austintexas.gov/department/ramsey-pool'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.31187897700005',
#    'human_address': '{"address": "4201 Burnet Rd", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.74379847899996'}},
#  {'pool_type': 'Splashpad',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Liz Carpenter Splashpad',
#   'website': {'url': 'http://austintexas.gov/department/liz-carpenter-fountain'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.260196671000074',
#    'human_address': '{"address": "200 Dawson Rd", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.75523145399995'}},
#  {'pool_type': 'Splashpad',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Rosewood Splashpad',
#   'website': {'description': 'Rosewood Splash Pad',
#    'url': 'http://www.austintexas.gov/department/rosewood-splash-pad'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.271339',
#    'human_address': '{"address": "2300 Rosewood Ave", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.713836'}},
#  {'pool_type': 'Regional',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Northwest',
#   'website': {'description': 'Northwest Pool',
#    'url': 'http://www.austintexas.gov/department/northwest-pool'},
#   'phone': '512-453-0194',
#   'location_1': {'latitude': '30.348728787000027',
#    'human_address': '{"address": "7000 Ardath St", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.73985425299998'}},
#  {'pool_type': 'Splashpad',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Pease Splashpad',
#   'website': {'description': 'Pease Splash Pad',
#    'url': 'http://www.austintexas.gov/department/pease-splash-pad'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.28291173100007',
#    'human_address': '{"address": "1100 Kingsbury St", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.75437819199999'}},
#  {'pool_type': 'Regional',
#   'weekend': '1:00 PM - 5:00 PM',
#   'closure_days': 'SUN/MON/THU',
#   'weekday': '4:00 PM - 8:00 PM',
#   'open_date': '2020-09-26T13:00:00.000',
#   'status': 'Open',
#   'pool_name': 'Springwoods',
#   'website': {'url': 'http://austintexas.gov/department/springwoods-pool'},
#   'phone': '512-258-8082',
#   'location_1': {'latitude': '30.466694790000076',
#    'human_address': '{"address": "13320 Lyndhurst St", "city": "Austin", "state": "TX", "zip": "78729"}',
#    'needs_recoding': False,
#    'longitude': '-97.78281477599995'}},
#  {'pool_type': 'Community',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Dove Springs',
#   'website': {'description': 'Dove Springs Pool',
#    'url': 'http://www.austintexas.gov/department/dove-springs-pool'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.18812383100004',
#    'human_address': '{"address": "5801 Ainez Dr", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.73920481399995'}},
#  {'pool_type': 'Neighborhood',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Shipe',
#   'website': {'description': 'Shipe Pool',
#    'url': 'http://www.austintexas.gov/department/shipe-pool'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.306847952000055',
#    'human_address': '{"address": "4400 Ave", "city": "G Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.72711577799998'}},
#  {'pool_type': 'Neighborhood',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Balcones',
#   'website': {'url': 'http://www.austintexas.gov/department/balcones-pool'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.41340406100005',
#    'human_address': '{"address": "12017 Amherst Dr", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.72085543099996'}},
#  {'pool_type': 'Splashpad',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Chestnut Splashpad',
#   'website': {'description': 'Chestnut Splash Pad',
#    'url': 'http://www.austintexas.gov/department/bailey-splash-pad'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.27750823100007',
#    'human_address': '{"address": "2205 E 16th St", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.73795600299997'}},
#  {'pool_type': 'Neighborhood',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'West Austin',
#   'website': {'description': 'West Austin Pool',
#    'url': 'http://www.austintexas.gov/department/west-austin-pool'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.27739562900007',
#    'human_address': '{"address": "1317 W 10th St", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.75705321199996'}},
#  {'pool_type': 'Splashpad',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Baily Splashpad',
#   'website': {'description': 'Bailey Splash Pad',
#    'url': 'http://www.austintexas.gov/department/bailey-splash-pad'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.302605251000045',
#    'human_address': '{"address": "1201 W 33rd St", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.74689354299994'}},
#  {'pool_type': 'Splashpad',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Eastwoods Splashpad',
#   'website': {'description': 'Eastwoods Splash Pad',
#    'url': 'http://www.austintexas.gov/department/eastwoods-splash-pad'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.291143504000047',
#    'human_address': '{"address": "3001 Harris Park Blvd", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.73212589899998'}},
#  {'pool_type': 'Neighborhood',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Reed',
#   'website': {'description': 'Reed Pool',
#    'url': 'http://www.austintexas.gov/department/reed-pool'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.303090361000045',
#    'human_address': '{"address": "2614 Pecos St", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.77087252699994'}},
#  {'pool_type': 'Neighborhood',
#   'weekend': 'Closed',
#   'closure_days': 'Closed for Winter',
#   'weekday': 'Closed',
#   'status': 'Closed',
#   'pool_name': 'Civitan',
#   'website': {'description': 'Civitan Pool',
#    'url': 'http://www.austintexas.gov/department/civitan-pool'},
#   'phone': '512-974-9331',
#   'location_1': {'latitude': '30.237021979000076',
#    'human_address': '{"address": "513 Vargas Rd", "city": "Austin", "state": "TX", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-97.69142730499999'}}]

# %%
type(pool_json)
# Out:
# list

# %%
# make list into dataframe
pooldf = pd.DataFrame(pool_json)
pooldf.head()
# Out:
#       pool_type weekend       closure_days weekday  status       pool_name  \
# 0     Splashpad  Closed  Closed for Winter  Closed  Closed  Lott Splashpad
# 1  Neighborhood  Closed  Closed for Winter  Closed  Closed            Metz
# 2  Neighborhood  Closed  Closed for Winter  Closed  Closed      Montopolis
# 3  Neighborhood  Closed  Closed for Winter  Closed  Closed    Canyon Vista
# 4  Neighborhood  Closed  Closed for Winter  Closed  Closed        Kennemer
#
#                                              website         phone  \
# 0  {'description': 'Lott Splash Pad', 'url': 'htt...  512-974-9331
# 1  {'description': 'Metz Pool', 'url': 'http://ww...  512-974-9331
# 2  {'description': 'Montopolis Pool', 'url': 'htt...  512-974-9331
# 3  {'description': 'Canyon Vista Pool website', '...  512-974-9331
# 4  {'description': 'Kennemer Pool', 'url': 'http:...  512-974-9331
#
#                                           location_1 open_date
# 0  {'latitude': '30.269695108000064', 'human_addr...       NaN
# 1  {'latitude': '30.252683793000074', 'human_addr...       NaN
# 2  {'latitude': '30.231947330000025', 'human_addr...       NaN
# 3  {'latitude': '30.427132347000054', 'human_addr...       NaN
# 4  {'latitude': '30.36075515300007', 'human_addre...       NaN

# %%
pooldf['pool_type'].value_counts()
# Out:
# Neighborhood    23
# Splashpad       11
# Regional         8
# Community        3
# Name: pool_type, dtype: int64

# %% [markdown]
# I will assume that the 'Splashpads' are just water play venues and won't have a lap pool, so we will filter those out and keeping the others.

# %%
pooldf = pooldf[pooldf['pool_type'] != 'Splashpad']
pooldf['pool_type'].value_counts()
# Out:
# Neighborhood    23
# Regional         8
# Community        3
# Name: pool_type, dtype: int64

# %% [markdown]
# Now I'll make a simplified file that flattens out the latitude and longitudes and keeps a minimal set of columns

# %%
pooldata = [pooldf['pool_name'],pd.json_normalize(pooldf['location_1'])['latitude'],pd.json_normalize(pooldf['location_1'])['longitude']]
pooldata
headers = ['name','lat','long']
aus_pools = pd.concat(pooldata, axis = 1, keys = headers)
aus_pools
# Out:
#                name                 lat                long
# 0               NaN  30.252683793000074  -97.71813028399998
# 1              Metz  30.231947330000025  -97.69905656299994
# 2        Montopolis  30.427132347000054  -97.78468953899994
# 3      Canyon Vista   30.36075515300007  -97.70649799899996
# 4          Kennemer  30.302395535000073  -97.69739842999996
# 5       Bartholomew  30.398443986000075  -97.67950234099999
# 6      Walnut Creek  30.262200781000047  -97.71307661199995
# 7   Parque Zaragoza  30.296592644000043  -97.71400165799997
# 8         Patterson  30.239795595000032  -97.75878452399996
# 9            Gillis  30.250938086000076  -97.73110151999998
# 10           Martin  30.340441576000046  -97.73037097399998
# 11        Brentwood  30.314319348000026  -97.67341137899996
# 12    Dottie Jordan  30.277590365000037  -97.77288902099997
# 13        Deep Eddy   30.35336556900006  -97.75870788799995
# 14              NaN   30.22025858300003  -97.74271075999997
# 15        Murchison  30.212930071000073  -97.80184931899998
# 16      Mabel Davis           30.271339          -97.713836
# 17         Garrison  30.286483287000067  -97.76496863899996
# 18         Rosewood  30.241312486000027  -97.74557365799996
# 19      Westenfield  30.265983430000063  -97.76862557799996
# 20     Stacy Wading  30.185743134000063  -97.80106115899997
# 21              NaN  30.258835826000052  -97.69156788399994
# 22   Barton Springs  30.239596177000067  -97.74730836399999
# 23          Dittmar   30.21486475200004  -97.86331548799996
# 24              NaN   30.27832090800007  -97.69072592299995
# 25              NaN   30.31187897700005  -97.74379847899996
# 26          Govalle  30.348728787000027  -97.73985425299998
# 27            Stacy  30.466694790000076  -97.78281477599995
# 28     Dick Nichols   30.18812383100004  -97.73920481399995
# 29           Givens  30.306847952000055  -97.72711577799998
# 30           Ramsey   30.41340406100005  -97.72085543099996
# 31              NaN   30.27739562900007  -97.75705321199996
# 32              NaN  30.303090361000045  -97.77087252699994
# 33        Northwest  30.237021979000076  -97.69142730499999
# 35      Springwoods                 NaN                 NaN
# 36     Dove Springs                 NaN                 NaN
# 37            Shipe                 NaN                 NaN
# 38         Balcones                 NaN                 NaN
# 40      West Austin                 NaN                 NaN
# 43             Reed                 NaN                 NaN
# 44          Civitan                 NaN                 NaN

# %% [markdown]
# This isn't what was expected. I see we have a number of pools that have no longitude or latitude and we lost the first name, so I will backtrack and do something other than normalizing instead.

# %%
# Out:
#        pool_type             weekend       closure_days             weekday  \
# 1   Neighborhood              Closed  Closed for Winter              Closed
# 2   Neighborhood              Closed  Closed for Winter              Closed
# 3   Neighborhood              Closed  Closed for Winter              Closed
# 4   Neighborhood              Closed  Closed for Winter              Closed
# 5       Regional   1:00 PM - 5:00 PM        TUE/WED/SAT  12:15 PM - 8:00 PM
# 6       Regional              Closed  Closed for Winter              Closed
# 7   Neighborhood              Closed  Closed for Winter              Closed
# 8   Neighborhood              Closed  Closed for Winter              Closed
# 9   Neighborhood              Closed  Closed for Winter              Closed
# 10  Neighborhood              Closed  Closed for Winter              Closed
# 11  Neighborhood              Closed  Closed for Winter              Closed
# 12  Neighborhood              Closed  Closed for Winter              Closed
# 13      Regional   9:00 AM - 7:00 PM        SUN/TUE/FRI   9:00 AM - 7:00 PM
# 15  Neighborhood              Closed  Closed for Winter              Closed
# 16      Regional              Closed  Closed for Winter              Closed
# 17      Regional              Closed  Closed for Winter              Closed
# 18  Neighborhood              Closed  Closed for Winter              Closed
# 19  Neighborhood              Closed  Closed for Winter              Closed
# 20  Neighborhood              Closed  Closed for Winter              Closed
# 22      Regional  5:00 AM - 10:00 PM        MON/WED/THU  5:00 AM - 10:00 PM
# 23  Neighborhood              Closed  Closed for Winter              Closed
# 26  Neighborhood              Closed  Closed for Winter              Closed
# 27  Neighborhood  12:00 PM - 6:00 PM        WED/FRI/SAT   6:00 AM - 8:00 PM
# 28     Community              Closed  Closed for Winter              Closed
# 29     Community              Closed  Closed for Winter              Closed
# 30  Neighborhood              Closed  Closed for Winter              Closed
# 33      Regional              Closed  Closed for Winter              Closed
# 35      Regional   1:00 PM - 5:00 PM        SUN/MON/THU   4:00 PM - 8:00 PM
# 36     Community              Closed  Closed for Winter              Closed
# 37  Neighborhood              Closed  Closed for Winter              Closed
# 38  Neighborhood              Closed  Closed for Winter              Closed
# 40  Neighborhood              Closed  Closed for Winter              Closed
# 43  Neighborhood              Closed  Closed for Winter              Closed
# 44  Neighborhood              Closed  Closed for Winter              Closed
#
#     status        pool_name  \
# 1   Closed             Metz
# 2   Closed       Montopolis
# 3   Closed     Canyon Vista
# 4   Closed         Kennemer
# 5     Open      Bartholomew
# 6   Closed     Walnut Creek
# 7   Closed  Parque Zaragoza
# 8   Closed        Patterson
# 9   Closed           Gillis
# 10  Closed           Martin
# 11  Closed        Brentwood
# 12  Closed    Dottie Jordan
# 13    Open        Deep Eddy
# 15  Closed        Murchison
# 16  Closed      Mabel Davis
# 17  Closed         Garrison
# 18  Closed         Rosewood
# 19  Closed      Westenfield
# 20  Closed     Stacy Wading
# 22    Open   Barton Springs
# 23  Closed          Dittmar
# 26  Closed          Govalle
# 27    Open            Stacy
# 28  Closed     Dick Nichols
# 29  Closed           Givens
# 30  Closed           Ramsey
# 33  Closed        Northwest
# 35    Open      Springwoods
# 36  Closed     Dove Springs
# 37  Closed            Shipe
# 38  Closed         Balcones
# 40  Closed      West Austin
# 43  Closed             Reed
# 44  Closed          Civitan
#
#                                               website         phone  \
# 1   {'description': 'Metz Pool', 'url': 'http://ww...  512-974-9331
# 2   {'description': 'Montopolis Pool', 'url': 'htt...  512-974-9331
# 3   {'description': 'Canyon Vista Pool website', '...  512-974-9331
# 4   {'description': 'Kennemer Pool', 'url': 'http:...  512-974-9331
# 5   {'url': 'http://www.austintexas.gov/department...  512-974-1650
# 6   {'url': 'http://www.austintexas.gov/department...  512-834-0824
# 7   {'description': 'Parque Zaragoza Pool', 'url':...  512-974-9331
# 8   {'description': 'Patterson Pool', 'url': 'http...  512-974-9331
# 9   {'description': 'Gillis Pool', 'url': 'http://...  512-974-9331
# 10  {'description': 'Martin Pool', 'url': 'http://...  512-974-9331
# 11  {'description': 'Brentwood Pool', 'url': 'http...  512-974-9331
# 12  {'description': 'Dottie Jordan Pool', 'url': '...  512-974-9331
# 13  {'url': 'http://www.austintexas.gov/department...  512-472-8546
# 15  {'description': 'Murchison Pool', 'url': 'http...  512-974-9331
# 16  {'description': 'Mabel Davis', 'url': 'http://...  512-441-5247
# 17  {'url': 'http://www.austintexas.gov/department...  512-442-4048
# 18  {'description': 'Rosewood Pool', 'url': 'http:...  512-974-9331
# 19  {'description': 'Westenfield website', 'url': ...  512-974-9331
# 20  {'description': 'Little Stacy Wading Pool', 'u...  512-974-9331
# 22  {'url': 'http://www.austintexas.gov/department...  512-867-3080
# 23  {'description': 'Dittmar Pool', 'url': 'http:/...  512-974-9331
# 26  {'description': 'Govalle Pool', 'url': 'http:/...  512-974-9331
# 27  {'url': 'http://austintexas.gov/department/big...  512-445-0304
# 28  {'description': 'Dick Nichols Pool', 'url': 'h...  512-974-9331
# 29  {'description': 'Givens Pool', 'url': 'http://...  512-974-9331
# 30  {'url': 'http://www.austintexas.gov/department...  512-974-9331
# 33  {'description': 'Northwest Pool', 'url': 'http...  512-453-0194
# 35  {'url': 'http://austintexas.gov/department/spr...  512-258-8082
# 36  {'description': 'Dove Springs Pool', 'url': 'h...  512-974-9331
# 37  {'description': 'Shipe Pool', 'url': 'http://w...  512-974-9331
# 38  {'url': 'http://www.austintexas.gov/department...  512-974-9331
# 40  {'description': 'West Austin Pool', 'url': 'ht...  512-974-9331
# 43  {'description': 'Reed Pool', 'url': 'http://ww...  512-974-9331
# 44  {'description': 'Civitan Pool', 'url': 'http:/...  512-974-9331
#
#                                            location_1                open_date
# 1   {'latitude': '30.252683793000074', 'human_addr...                      NaN
# 2   {'latitude': '30.231947330000025', 'human_addr...                      NaN
# 3   {'latitude': '30.427132347000054', 'human_addr...                      NaN
# 4   {'latitude': '30.36075515300007', 'human_addre...                      NaN
# 5   {'latitude': '30.302395535000073', 'human_addr...  2020-09-26T12:15:00.000
# 6   {'latitude': '30.398443986000075', 'human_addr...                      NaN
# 7   {'latitude': '30.262200781000047', 'human_addr...                      NaN
# 8   {'latitude': '30.296592644000043', 'human_addr...                      NaN
# 9   {'latitude': '30.239795595000032', 'human_addr...                      NaN
# 10  {'latitude': '30.250938086000076', 'human_addr...                      NaN
# 11  {'latitude': '30.340441576000046', 'human_addr...                      NaN
# 12  {'latitude': '30.314319348000026', 'human_addr...                      NaN
# 13  {'latitude': '30.277590365000037', 'human_addr...  2020-09-26T09:00:00.000
# 15  {'latitude': '30.35336556900006', 'human_addre...                      NaN
# 16  {'latitude': '30.22025858300003', 'human_addre...                      NaN
# 17  {'latitude': '30.212930071000073', 'human_addr...                      NaN
# 18  {'latitude': '30.271339', 'human_address': '{"...                      NaN
# 19  {'latitude': '30.286483287000067', 'human_addr...                      NaN
# 20  {'latitude': '30.241312486000027', 'human_addr...                      NaN
# 22  {'latitude': '30.265983430000063', 'human_addr...  2020-09-26T05:00:00.000
# 23  {'latitude': '30.185743134000063', 'human_addr...                      NaN
# 26  {'latitude': '30.258835826000052', 'human_addr...                      NaN
# 27  {'latitude': '30.239596177000067', 'human_addr...  2020-09-26T12:00:00.000
# 28  {'latitude': '30.21486475200004', 'human_addre...                      NaN
# 29  {'latitude': '30.27832090800007', 'human_addre...                      NaN
# 30  {'latitude': '30.31187897700005', 'human_addre...                      NaN
# 33  {'latitude': '30.348728787000027', 'human_addr...                      NaN
# 35  {'latitude': '30.466694790000076', 'human_addr...  2020-09-26T13:00:00.000
# 36  {'latitude': '30.18812383100004', 'human_addre...                      NaN
# 37  {'latitude': '30.306847952000055', 'human_addr...                      NaN
# 38  {'latitude': '30.41340406100005', 'human_addre...                      NaN
# 40  {'latitude': '30.27739562900007', 'human_addre...                      NaN
# 43  {'latitude': '30.303090361000045', 'human_addr...                      NaN
# 44  {'latitude': '30.237021979000076', 'human_addr...                      NaN

# %%
aus_pools = pd.concat([pooldf['pool_name'],pooldf['location_1'].apply(pd.Series)['latitude'],pooldf['location_1'].apply(pd.Series)['longitude']], axis = 1)
aus_pools
# Out:
#           pool_name            latitude           longitude
# 1              Metz  30.252683793000074  -97.71813028399998
# 2        Montopolis  30.231947330000025  -97.69905656299994
# 3      Canyon Vista  30.427132347000054  -97.78468953899994
# 4          Kennemer   30.36075515300007  -97.70649799899996
# 5       Bartholomew  30.302395535000073  -97.69739842999996
# 6      Walnut Creek  30.398443986000075  -97.67950234099999
# 7   Parque Zaragoza  30.262200781000047  -97.71307661199995
# 8         Patterson  30.296592644000043  -97.71400165799997
# 9            Gillis  30.239795595000032  -97.75878452399996
# 10           Martin  30.250938086000076  -97.73110151999998
# 11        Brentwood  30.340441576000046  -97.73037097399998
# 12    Dottie Jordan  30.314319348000026  -97.67341137899996
# 13        Deep Eddy  30.277590365000037  -97.77288902099997
# 15        Murchison   30.35336556900006  -97.75870788799995
# 16      Mabel Davis   30.22025858300003  -97.74271075999997
# 17         Garrison  30.212930071000073  -97.80184931899998
# 18         Rosewood           30.271339          -97.713836
# 19      Westenfield  30.286483287000067  -97.76496863899996
# 20     Stacy Wading  30.241312486000027  -97.74557365799996
# 22   Barton Springs  30.265983430000063  -97.76862557799996
# 23          Dittmar  30.185743134000063  -97.80106115899997
# 26          Govalle  30.258835826000052  -97.69156788399994
# 27            Stacy  30.239596177000067  -97.74730836399999
# 28     Dick Nichols   30.21486475200004  -97.86331548799996
# 29           Givens   30.27832090800007  -97.69072592299995
# 30           Ramsey   30.31187897700005  -97.74379847899996
# 33        Northwest  30.348728787000027  -97.73985425299998
# 35      Springwoods  30.466694790000076  -97.78281477599995
# 36     Dove Springs   30.18812383100004  -97.73920481399995
# 37            Shipe  30.306847952000055  -97.72711577799998
# 38         Balcones   30.41340406100005  -97.72085543099996
# 40      West Austin   30.27739562900007  -97.75705321199996
# 43             Reed  30.303090361000045  -97.77087252699994
# 44          Civitan  30.237021979000076  -97.69142730499999

# %%
aus_pools.reset_index()
# Out:
#     index        pool_name            latitude           longitude
# 0       1             Metz  30.252683793000074  -97.71813028399998
# 1       2       Montopolis  30.231947330000025  -97.69905656299994
# 2       3     Canyon Vista  30.427132347000054  -97.78468953899994
# 3       4         Kennemer   30.36075515300007  -97.70649799899996
# 4       5      Bartholomew  30.302395535000073  -97.69739842999996
# 5       6     Walnut Creek  30.398443986000075  -97.67950234099999
# 6       7  Parque Zaragoza  30.262200781000047  -97.71307661199995
# 7       8        Patterson  30.296592644000043  -97.71400165799997
# 8       9           Gillis  30.239795595000032  -97.75878452399996
# 9      10           Martin  30.250938086000076  -97.73110151999998
# 10     11        Brentwood  30.340441576000046  -97.73037097399998
# 11     12    Dottie Jordan  30.314319348000026  -97.67341137899996
# 12     13        Deep Eddy  30.277590365000037  -97.77288902099997
# 13     15        Murchison   30.35336556900006  -97.75870788799995
# 14     16      Mabel Davis   30.22025858300003  -97.74271075999997
# 15     17         Garrison  30.212930071000073  -97.80184931899998
# 16     18         Rosewood           30.271339          -97.713836
# 17     19      Westenfield  30.286483287000067  -97.76496863899996
# 18     20     Stacy Wading  30.241312486000027  -97.74557365799996
# 19     22   Barton Springs  30.265983430000063  -97.76862557799996
# 20     23          Dittmar  30.185743134000063  -97.80106115899997
# 21     26          Govalle  30.258835826000052  -97.69156788399994
# 22     27            Stacy  30.239596177000067  -97.74730836399999
# 23     28     Dick Nichols   30.21486475200004  -97.86331548799996
# 24     29           Givens   30.27832090800007  -97.69072592299995
# 25     30           Ramsey   30.31187897700005  -97.74379847899996
# 26     33        Northwest  30.348728787000027  -97.73985425299998
# 27     35      Springwoods  30.466694790000076  -97.78281477599995
# 28     36     Dove Springs   30.18812383100004  -97.73920481399995
# 29     37            Shipe  30.306847952000055  -97.72711577799998
# 30     38         Balcones   30.41340406100005  -97.72085543099996
# 31     40      West Austin   30.27739562900007  -97.75705321199996
# 32     43             Reed  30.303090361000045  -97.77087252699994
# 33     44          Civitan  30.237021979000076  -97.69142730499999

# %%
austx_zr.shape
# Out:
# (44, 11)

# %% [markdown]
# Now to figure out how far the nearest pool is for each zip code

# %%
from math import cos, asin, sqrt
#helper functions for distance
def distance(lat1, lon1, lat2, lon2):
    #print ('DISTANCE with ',lat1, lon1, lat2, lon2)
    #convert in case of string values
    lat1 = float(lat1)
    lon1 = float(lon1)
    lat2 = float(lat2)
    lon2 = float(lon2)
    p = 0.0174532925199433
    a = 0.5 - cos((lat2-lat1)*p)/2 + cos(lat1*p)*cos(lat2*p) * (1-cos((lon2-lon1)*p)) / 2
    return 12742 * asin(sqrt(a))

def closest(pools, zipcode):  
    column_names = ['zip', 'pool', 'distance'] 
    dl = pd.DataFrame(columns=column_names)
    #dl = pd.DataFrame()
    for index, p in pools.iterrows():
        ap = {}
        #print('zip',zipcode['zip'], 'pool',p['pool_name'], 'distance',0)
        #print('zip',zipcode['zip'], 'pool',p['pool_name'], 'distance',distance(zipcode['lat'],zipcode['lng'],p['latitude'],p['longitude']))
        ap = {'zip': zipcode['zip'], 'pool': p['pool_name'], 'distance': distance(zipcode['lat'],zipcode['lng'],p['latitude'],p['longitude'])}
        print('ap = {}'.format(ap))
        dl = dl.append(ap, ignore_index=True)
    dl_sorted = dl.sort_values('distance')
    return dl_sorted.head(1)

# %%
pooldist = pd.DataFrame()
aus_pools.dtypes
aus_pools
for index,zc in austx_zr.iterrows():
    #print('I={}, zc = {}'.format(index,zc))
    #print('for {}, closest = {}'.format(zc['zip'],closest(aus_pools,zc)))
    pooldist = pooldist.append(closest(aus_pools,zc))
    #pooldist.append(
pooldist
# Out:
# ap = {'zip': 78701, 'pool': 'Metz', 'distance': 3.0546879056569995}
# ap = {'zip': 78701, 'pool': 'Montopolis', 'distance': 5.971637078571492}
# ap = {'zip': 78701, 'pool': 'Canyon Vista', 'distance': 17.885390731292496}
# ap = {'zip': 78701, 'pool': 'Kennemer', 'distance': 10.61062433514068}
# ap = {'zip': 78701, 'pool': 'Bartholomew', 'distance': 5.587113160521369}
# ap = {'zip': 78701, 'pool': 'Walnut Creek', 'distance': 15.453517142224083}
# ap = {'zip': 78701, 'pool': 'Parque Zaragoza', 'distance': 2.9586011921706623}
# ap = {'zip': 78701, 'pool': 'Patterson', 'distance': 3.9791869359164065}
# ap = {'zip': 78701, 'pool': 'Gillis', 'distance': 3.7604151395084635}
# ap = {'zip': 78701, 'pool': 'Martin', 'distance': 2.4277029547331024}
# ap = {'zip': 78701, 'pool': 'Brentwood', 'distance': 7.8628111263616995}
# ap = {'zip': 78701, 'pool': 'Dottie Jordan', 'distance': 8.219663392213231}
# ap = {'zip': 78701, 'pool': 'Deep Eddy', 'distance': 3.0370983444003508}
# ap = {'zip': 78701, 'pool': 'Murchison', 'distance': 9.348167280856712}
# ap = {'zip': 78701, 'pool': 'Mabel Davis', 'distance': 5.585586229613033}
# ap = {'zip': 78701, 'pool': 'Garrison', 'distance': 8.580982786890901}
# ap = {'zip': 78701, 'pool': 'Rosewood', 'distance': 2.7399309409624237}
# ap = {'zip': 78701, 'pool': 'Westenfield', 'distance': 2.8071551449561944}
# ap = {'zip': 78701, 'pool': 'Stacy Wading', 'distance': 3.2591325995460254}
# ap = {'zip': 78701, 'pool': 'Barton Springs', 'distance': 2.5726838468994053}
# ap = {'zip': 78701, 'pool': 'Dittmar', 'distance': 10.982641369585524}
# ap = {'zip': 78701, 'pool': 'Govalle', 'distance': 5.0463310337918275}
# ap = {'zip': 78701, 'pool': 'Stacy', 'distance': 3.468091705257728}
# ap = {'zip': 78701, 'pool': 'Dick Nichols', 'distance': 13.163736269510865}
# ap = {'zip': 78701, 'pool': 'Givens', 'distance': 5.033364635302526}
# ap = {'zip': 78701, 'pool': 'Ramsey', 'distance': 4.6043451028457865}
# ap = {'zip': 78701, 'pool': 'Northwest', 'distance': 8.703054449507112}
# ap = {'zip': 78701, 'pool': 'Springwoods', 'distance': 22.15967583056233}
# ap = {'zip': 78701, 'pool': 'Dove Springs', 'distance': 9.163683516477121}
# ap = {'zip': 78701, 'pool': 'Shipe', 'distance': 4.2993001062485785}
# ap = {'zip': 78701, 'pool': 'Balcones', 'distance': 16.024629817180415}
# ap = {'zip': 78701, 'pool': 'West Austin', 'distance': 1.6072511937418097}
# ap = {'zip': 78701, 'pool': 'Reed', 'distance': 4.543231676393303}
# ap = {'zip': 78701, 'pool': 'Civitan', 'distance': 6.145949571028424}
# ap = {'zip': 78702, 'pool': 'Metz', 'distance': 1.232708576041832}
# ap = {'zip': 78702, 'pool': 'Montopolis', 'distance': 3.778934576993576}
# ap = {'zip': 78702, 'pool': 'Canyon Vista', 'distance': 19.431720143143743}
# ap = {'zip': 78702, 'pool': 'Kennemer', 'distance': 10.86582881598387}
# ap = {'zip': 78702, 'pool': 'Bartholomew', 'distance': 4.644081830637384}
# ap = {'zip': 78702, 'pool': 'Walnut Creek', 'distance': 15.397636977384767}
# ap = {'zip': 78702, 'pool': 'Parque Zaragoza', 'distance': 0.16851017556696285}
# ap = {'zip': 78702, 'pool': 'Patterson', 'distance': 3.7054350491104038}
# ap = {'zip': 78702, 'pool': 'Gillis', 'distance': 5.005417543445142}
# ap = {'zip': 78702, 'pool': 'Martin', 'distance': 2.116192922137245}
# ap = {'zip': 78702, 'pool': 'Brentwood', 'distance': 8.718347682790395}
# ap = {'zip': 78702, 'pool': 'Dottie Jordan', 'distance': 6.902909003781414}
# ap = {'zip': 78702, 'pool': 'Deep Eddy', 'distance': 5.845682154811383}
# ap = {'zip': 78702, 'pool': 'Murchison', 'distance': 10.886723869797084}
# ap = {'zip': 78702, 'pool': 'Mabel Davis', 'distance': 5.50561528333463}
# ap = {'zip': 78702, 'pool': 'Garrison', 'distance': 10.101314263922434}
# ap = {'zip': 78702, 'pool': 'Rosewood', 'distance': 0.8984350817019374}
# ap = {'zip': 78702, 'pool': 'Westenfield', 'distance': 5.506262947814944}
# ap = {'zip': 78702, 'pool': 'Stacy Wading', 'distance': 3.869505888171038}
# ap = {'zip': 78702, 'pool': 'Barton Springs', 'distance': 5.22421804648365}
# ap = {'zip': 78702, 'pool': 'Dittmar', 'distance': 11.99042524494049}
# ap = {'zip': 78702, 'pool': 'Govalle', 'distance': 2.2401239914384647}
# ap = {'zip': 78702, 'pool': 'Stacy', 'distance': 4.119434881015316}
# ap = {'zip': 78702, 'pool': 'Dick Nichols', 'distance': 15.29178668738133}
# ap = {'zip': 78702, 'pool': 'Givens', 'distance': 2.8168891640708114}
# ap = {'zip': 78702, 'pool': 'Ramsey', 'distance': 6.101329598360142}
# ap = {'zip': 78702, 'pool': 'Northwest', 'distance': 9.813654889432856}
# ap = {'zip': 78702, 'pool': 'Springwoods', 'distance': 23.55504154963413}
# ap = {'zip': 78702, 'pool': 'Dove Springs', 'distance': 8.691197585029549}
# ap = {'zip': 78702, 'pool': 'Shipe', 'distance': 4.9989872373029405}
# ap = {'zip': 78702, 'pool': 'Balcones', 'distance': 16.705923322770186}
# ap = {'zip': 78702, 'pool': 'West Austin', 'distance': 4.394165489260864}
# ap = {'zip': 78702, 'pool': 'Reed', 'distance': 7.006669471820795}
# ap = {'zip': 78702, 'pool': 'Civitan', 'distance': 3.654286779509845}
# ap = {'zip': 78703, 'pool': 'Metz', 'distance': 6.486549653673416}
# ap = {'zip': 78703, 'pool': 'Montopolis', 'distance': 9.419472223533749}
# ap = {'zip': 78703, 'pool': 'Canyon Vista', 'distance': 14.905290044740946}
# ap = {'zip': 78703, 'pool': 'Kennemer', 'distance': 9.340624970973458}
# ap = {'zip': 78703, 'pool': 'Bartholomew', 'distance': 6.623089203448174}
# ap = {'zip': 78703, 'pool': 'Walnut Creek', 'distance': 14.250548526424417}
# ap = {'zip': 78703, 'pool': 'Parque Zaragoza', 'distance': 6.174020718313846}
# ap = {'zip': 78703, 'pool': 'Patterson', 'distance': 4.9722990776655935}
# ap = {'zip': 78703, 'pool': 'Gillis', 'distance': 6.0737881685768}
# ap = {'zip': 78703, 'pool': 'Martin', 'distance': 5.836887134301987}
# ap = {'zip': 78703, 'pool': 'Brentwood', 'distance': 6.170162018354289}
# ap = {'zip': 78703, 'pool': 'Dottie Jordan', 'distance': 9.141827385383975}
# ap = {'zip': 78703, 'pool': 'Deep Eddy', 'distance': 1.959898205962325}
# ap = {'zip': 78703, 'pool': 'Murchison', 'distance': 6.625318616085124}
# ap = {'zip': 78703, 'pool': 'Mabel Davis', 'distance': 8.501679567583812}
# ap = {'zip': 78703, 'pool': 'Garrison', 'distance': 9.669135310086467}
# ap = {'zip': 78703, 'pool': 'Rosewood', 'distance': 5.586657500596413}
# ap = {'zip': 78703, 'pool': 'Westenfield', 'distance': 0.8488177940326332}
# ap = {'zip': 78703, 'pool': 'Stacy Wading', 'distance': 6.179002199632274}
# ap = {'zip': 78703, 'pool': 'Barton Springs', 'distance': 3.1378227970085324}
# ap = {'zip': 78703, 'pool': 'Dittmar', 'distance': 12.517101016274546}
# ap = {'zip': 78703, 'pool': 'Govalle', 'distance': 8.12759008190657}
# ap = {'zip': 78703, 'pool': 'Stacy', 'distance': 6.3118891352897855}
# ap = {'zip': 78703, 'pool': 'Dick Nichols', 'distance': 12.864548026898232}
# ap = {'zip': 78703, 'pool': 'Givens', 'distance': 7.410313718437774}
# ap = {'zip': 78703, 'pool': 'Ramsey', 'distance': 2.887491284100651}
# ap = {'zip': 78703, 'pool': 'Northwest', 'distance': 6.5628829389547505}
# ap = {'zip': 78703, 'pool': 'Springwoods', 'distance': 19.262785529689612}
# ap = {'zip': 78703, 'pool': 'Dove Springs', 'distance': 12.054861395363272}
# ap = {'zip': 78703, 'pool': 'Shipe', 'distance': 3.9675180085698596}
# ap = {'zip': 78703, 'pool': 'Balcones', 'distance': 13.947761525110838}
# ap = {'zip': 78703, 'pool': 'West Austin', 'distance': 2.0339324611250444}
# ap = {'zip': 78703, 'pool': 'Reed', 'distance': 1.116801334876497}
# ap = {'zip': 78703, 'pool': 'Civitan', 'distance': 9.547876595142556}
# ap = {'zip': 78704, 'pool': 'Metz', 'distance': 4.659854363588818}
# ap = {'zip': 78704, 'pool': 'Montopolis', 'distance': 6.491133445966788}
# ap = {'zip': 78704, 'pool': 'Canyon Vista', 'distance': 20.541751170894447}
# ap = {'zip': 78704, 'pool': 'Kennemer', 'distance': 14.246208857343454}
# ap = {'zip': 78704, 'pool': 'Bartholomew', 'distance': 9.273972026460882}
# ap = {'zip': 78704, 'pool': 'Walnut Creek', 'distance': 19.134023363535512}
# ap = {'zip': 78704, 'pool': 'Parque Zaragoza', 'distance': 5.451285892802363}
# ap = {'zip': 78704, 'pool': 'Patterson', 'distance': 7.723328678159196}
# ap = {'zip': 78704, 'pool': 'Gillis', 'distance': 0.7343895062764907}
# ap = {'zip': 78704, 'pool': 'Martin', 'distance': 3.4037363313634073}
# ap = {'zip': 78704, 'pool': 'Brentwood', 'distance': 11.328209745387948}
# ap = {'zip': 78704, 'pool': 'Dottie Jordan', 'distance': 11.857591638715506}
# ap = {'zip': 78704, 'pool': 'Deep Eddy', 'distance': 3.8970885877483865}
# ap = {'zip': 78704, 'pool': 'Murchison', 'distance': 12.272091310829024}
# ap = {'zip': 78704, 'pool': 'Mabel Davis', 'distance': 3.3493408342769238}
# ap = {'zip': 78704, 'pool': 'Garrison', 'distance': 4.855415657018457}
# ap = {'zip': 78704, 'pool': 'Rosewood', 'distance': 5.85869767284298}
# ap = {'zip': 78704, 'pool': 'Westenfield', 'distance': 4.818595848810723}
# ap = {'zip': 78704, 'pool': 'Stacy Wading', 'distance': 1.9126157191720268}
# ap = {'zip': 78704, 'pool': 'Barton Springs', 'distance': 2.5581449108335077}
# ap = {'zip': 78704, 'pool': 'Dittmar', 'distance': 7.246296444238607}
# ap = {'zip': 78704, 'pool': 'Govalle', 'distance': 7.300345835111555}
# ap = {'zip': 78704, 'pool': 'Stacy', 'distance': 1.7794788620926612}
# ap = {'zip': 78704, 'pool': 'Dick Nichols', 'distance': 9.921778475159252}
# ap = {'zip': 78704, 'pool': 'Givens', 'distance': 8.166417905042442}
# ap = {'zip': 78704, 'pool': 'Ramsey', 'distance': 7.918072571053568}
# ap = {'zip': 78704, 'pool': 'Northwest', 'distance': 11.992695860989084}
# ap = {'zip': 78704, 'pool': 'Springwoods', 'distance': 24.913340400610632}
# ap = {'zip': 78704, 'pool': 'Dove Springs', 'distance': 6.615028781683117}
# ap = {'zip': 78704, 'pool': 'Shipe', 'distance': 7.978860509282748}
# ap = {'zip': 78704, 'pool': 'Balcones', 'distance': 19.407493301330796}
# ap = {'zip': 78704, 'pool': 'West Austin', 'distance': 3.8908167857878433}
# ap = {'zip': 78704, 'pool': 'Reed', 'distance': 6.68597802327348}
# ap = {'zip': 78704, 'pool': 'Civitan', 'distance': 7.135825796351605}
# ap = {'zip': 78705, 'pool': 'Metz', 'distance': 5.033010622533103}
# ap = {'zip': 78705, 'pool': 'Montopolis', 'distance': 7.909835097878367}
# ap = {'zip': 78705, 'pool': 'Canyon Vista', 'distance': 15.4119666576419}
# ap = {'zip': 78705, 'pool': 'Kennemer', 'distance': 7.997059449243111}
# ap = {'zip': 78705, 'pool': 'Bartholomew', 'distance': 4.0503621582372045}
# ap = {'zip': 78705, 'pool': 'Walnut Creek', 'distance': 12.885205313569672}
# ap = {'zip': 78705, 'pool': 'Parque Zaragoza', 'distance': 4.333452903340865}
# ap = {'zip': 78705, 'pool': 'Patterson', 'distance': 2.36979992217588}
# ap = {'zip': 78705, 'pool': 'Gillis', 'distance': 6.371949867559496}
# ap = {'zip': 78705, 'pool': 'Martin', 'distance': 4.8820927137454655}
# ap = {'zip': 78705, 'pool': 'Brentwood', 'distance': 5.182733978248337}
# ap = {'zip': 78705, 'pool': 'Dottie Jordan', 'distance': 6.635158927109953}
# ap = {'zip': 78705, 'pool': 'Deep Eddy', 'distance': 3.788502273081569}
# ap = {'zip': 78705, 'pool': 'Murchison', 'distance': 6.839380068044926}
# ap = {'zip': 78705, 'pool': 'Mabel Davis', 'distance': 8.250497635357707}
# ap = {'zip': 78705, 'pool': 'Garrison', 'distance': 10.907402171754862}
# ap = {'zip': 78705, 'pool': 'Rosewood', 'distance': 3.4914048796002755}
# ap = {'zip': 78705, 'pool': 'Westenfield', 'distance': 2.683891409883715}
# ap = {'zip': 78705, 'pool': 'Stacy Wading', 'distance': 5.9381613601372125}
# ap = {'zip': 78705, 'pool': 'Barton Springs', 'distance': 4.27827628830744}
# ap = {'zip': 78705, 'pool': 'Dittmar', 'distance': 13.48914774885218}
# ap = {'zip': 78705, 'pool': 'Govalle', 'distance': 5.997224697272409}
# ap = {'zip': 78705, 'pool': 'Stacy', 'distance': 6.148378653186129}
# ap = {'zip': 78705, 'pool': 'Dick Nichols', 'distance': 14.891752824818523}
# ap = {'zip': 78705, 'pool': 'Givens', 'distance': 4.926578609066559}
# ap = {'zip': 78705, 'pool': 'Ramsey', 'distance': 2.0110535661103013}
# ap = {'zip': 78705, 'pool': 'Northwest', 'distance': 6.045717589151984}
# ap = {'zip': 78705, 'pool': 'Springwoods', 'distance': 19.626470319567925}
# ap = {'zip': 78705, 'pool': 'Dove Springs', 'distance': 11.814202429195934}
# ap = {'zip': 78705, 'pool': 'Shipe', 'distance': 1.7692210787713363}
# ap = {'zip': 78705, 'pool': 'Balcones', 'distance': 13.344433677312962}
# ap = {'zip': 78705, 'pool': 'West Austin', 'distance': 2.5921115210186394}
# ap = {'zip': 78705, 'pool': 'Reed', 'distance': 3.251139887756985}
# ap = {'zip': 78705, 'pool': 'Civitan', 'distance': 7.819513954238495}
# ap = {'zip': 78712, 'pool': 'Metz', 'distance': 3.934732988456625}
# ap = {'zip': 78712, 'pool': 'Montopolis', 'distance': 6.825864550382698}
# ap = {'zip': 78712, 'pool': 'Canyon Vista', 'distance': 16.51213876220784}
# ap = {'zip': 78712, 'pool': 'Kennemer', 'distance': 8.847776312189648}
# ap = {'zip': 78712, 'pool': 'Bartholomew', 'distance': 4.075208999299133}
# ap = {'zip': 78712, 'pool': 'Walnut Creek', 'distance': 13.681971278750693}
# ap = {'zip': 78712, 'pool': 'Parque Zaragoza', 'distance': 3.28301488303417}
# ap = {'zip': 78712, 'pool': 'Patterson', 'distance': 2.3732177828793195}
# ap = {'zip': 78712, 'pool': 'Gillis', 'distance': 5.5324101481659245}
# ap = {'zip': 78712, 'pool': 'Martin', 'distance': 3.8060766426956105}
# ap = {'zip': 78712, 'pool': 'Brentwood', 'distance': 6.177048715356898}
# ap = {'zip': 78712, 'pool': 'Dottie Jordan', 'distance': 6.731663762185049}
# ap = {'zip': 78712, 'pool': 'Deep Eddy', 'distance': 3.7523939655799565}
# ap = {'zip': 78712, 'pool': 'Murchison', 'distance': 7.939434657643885}
# ap = {'zip': 78712, 'pool': 'Mabel Davis', 'distance': 7.241420925084442}
# ap = {'zip': 78712, 'pool': 'Garrison', 'distance': 10.284603607315038}
# ap = {'zip': 78712, 'pool': 'Rosewood', 'distance': 2.5209541811307075}
# ap = {'zip': 78712, 'pool': 'Westenfield', 'distance': 2.9042092839074773}
# ap = {'zip': 78712, 'pool': 'Stacy Wading', 'distance': 4.96958047843947}
# ap = {'zip': 78712, 'pool': 'Barton Springs', 'distance': 3.8794998482152083}
# ap = {'zip': 78712, 'pool': 'Dittmar', 'distance': 12.744370177023711}
# ap = {'zip': 78712, 'pool': 'Govalle', 'distance': 5.068507933876412}
# ap = {'zip': 78712, 'pool': 'Stacy', 'distance': 5.19246574864866}
# ap = {'zip': 78712, 'pool': 'Dick Nichols', 'distance': 14.605160236761389}
# ap = {'zip': 78712, 'pool': 'Givens', 'distance': 4.294350518592316}
# ap = {'zip': 78712, 'pool': 'Ramsey', 'distance': 3.109823932902612}
# ap = {'zip': 78712, 'pool': 'Northwest', 'distance': 7.100884471790261}
# ap = {'zip': 78712, 'pool': 'Springwoods', 'distance': 20.720418641722787}
# ap = {'zip': 78712, 'pool': 'Dove Springs', 'distance': 10.78278236558496}
# ap = {'zip': 78712, 'pool': 'Shipe', 'distance': 2.5359684148506423}
# ap = {'zip': 78712, 'pool': 'Balcones', 'distance': 14.337960766788456}
# ap = {'zip': 78712, 'pool': 'West Austin', 'distance': 2.3015488696488933}
# ap = {'zip': 78712, 'pool': 'Reed', 'distance': 4.006524774434312}
# ap = {'zip': 78712, 'pool': 'Civitan', 'distance': 6.768584792240942}
# ap = {'zip': 78717, 'pool': 'Metz', 'distance': 26.5949684258449}
# ap = {'zip': 78717, 'pool': 'Montopolis', 'distance': 29.156223589031754}
# ap = {'zip': 78717, 'pool': 'Canyon Vista', 'distance': 7.582796952467479}
# ap = {'zip': 78717, 'pool': 'Kennemer', 'distance': 15.054727158759635}
# ap = {'zip': 78717, 'pool': 'Bartholomew', 'distance': 21.53556186397746}
# ap = {'zip': 78717, 'pool': 'Walnut Creek', 'distance': 12.408821477184446}
# ap = {'zip': 78717, 'pool': 'Parque Zaragoza', 'distance': 25.615099413408636}
# ap = {'zip': 78717, 'pool': 'Patterson', 'distance': 21.827412671808318}
# ap = {'zip': 78717, 'pool': 'Gillis', 'distance': 27.81237863087469}
# ap = {'zip': 78717, 'pool': 'Martin', 'distance': 26.657513348506487}
# ap = {'zip': 78717, 'pool': 'Brentwood', 'distance': 16.766831631462036}
# ap = {'zip': 78717, 'pool': 'Dottie Jordan', 'distance': 20.985546680555633}
# ap = {'zip': 78717, 'pool': 'Deep Eddy', 'distance': 23.677111209774413}
# ap = {'zip': 78717, 'pool': 'Murchison', 'distance': 15.187274903002924}
# ap = {'zip': 78717, 'pool': 'Mabel Davis', 'distance': 29.999104077135126}
# ap = {'zip': 78717, 'pool': 'Garrison', 'distance': 31.139930212033825}
# ap = {'zip': 78717, 'pool': 'Rosewood', 'distance': 24.59983536691303}
# ap = {'zip': 78717, 'pool': 'Westenfield', 'distance': 22.64245004366769}
# ap = {'zip': 78717, 'pool': 'Stacy Wading', 'distance': 27.65046742944371}
# ap = {'zip': 78717, 'pool': 'Barton Springs', 'distance': 24.937245149861543}
# ap = {'zip': 78717, 'pool': 'Dittmar', 'distance': 34.1224125949511}
# ap = {'zip': 78717, 'pool': 'Govalle', 'distance': 26.373528990285283}
# ap = {'zip': 78717, 'pool': 'Stacy', 'distance': 27.83706767991417}
# ap = {'zip': 78717, 'pool': 'Dick Nichols', 'distance': 32.33826123199096}
# ap = {'zip': 78717, 'pool': 'Givens', 'distance': 24.287723300343984}
# ap = {'zip': 78717, 'pool': 'Ramsey', 'distance': 19.81562390090478}
# ap = {'zip': 78717, 'pool': 'Northwest', 'distance': 15.751431239333039}
# ap = {'zip': 78717, 'pool': 'Springwoods', 'distance': 3.798111462889454}
# ap = {'zip': 78717, 'pool': 'Dove Springs', 'distance': 33.582617346165875}
# ap = {'zip': 78717, 'pool': 'Shipe', 'distance': 20.511438751579853}
# ap = {'zip': 78717, 'pool': 'Balcones', 'distance': 9.068172298958062}
# ap = {'zip': 78717, 'pool': 'West Austin', 'distance': 23.629360313866382}
# ap = {'zip': 78717, 'pool': 'Reed', 'distance': 20.835185062456162}
# ap = {'zip': 78717, 'pool': 'Civitan', 'distance': 28.74450839253029}
# ap = {'zip': 78719, 'pool': 'Metz', 'distance': 12.825404524784854}
# ap = {'zip': 78719, 'pool': 'Montopolis', 'distance': 10.059736920567653}
# ap = {'zip': 78719, 'pool': 'Canyon Vista', 'distance': 33.23991362293634}
# ap = {'zip': 78719, 'pool': 'Kennemer', 'distance': 24.25297489184193}
# ap = {'zip': 78719, 'pool': 'Bartholomew', 'distance': 17.705471865220694}
# ap = {'zip': 78719, 'pool': 'Walnut Creek', 'distance': 28.212883585457647}
# ap = {'zip': 78719, 'pool': 'Parque Zaragoza', 'distance': 13.667923713732025}
# ap = {'zip': 78719, 'pool': 'Patterson', 'distance': 17.377568972842347}
# ap = {'zip': 78719, 'pool': 'Gillis', 'distance': 13.526500415634683}
# ap = {'zip': 78719, 'pool': 'Martin', 'distance': 13.14384683933997}
# ap = {'zip': 78719, 'pool': 'Brentwood', 'distance': 22.490447584006834}
# ap = {'zip': 78719, 'pool': 'Dottie Jordan', 'distance': 18.84798731389336}
# ap = {'zip': 78719, 'pool': 'Deep Eddy', 'distance': 17.722956342805322}
# ap = {'zip': 78719, 'pool': 'Murchison', 'distance': 24.67671072648652}
# ap = {'zip': 78719, 'pool': 'Mabel Davis', 'distance': 10.866606554684537}
# ap = {'zip': 78719, 'pool': 'Garrison', 'distance': 14.695268935036863}
# ap = {'zip': 78719, 'pool': 'Rosewood', 'distance': 14.6616461393089}
# ap = {'zip': 78719, 'pool': 'Westenfield', 'distance': 18.163703783012366}
# ap = {'zip': 78719, 'pool': 'Stacy Wading', 'distance': 12.911303480393931}
# ap = {'zip': 78719, 'pool': 'Barton Springs', 'distance': 16.425780811919648}
# ap = {'zip': 78719, 'pool': 'Dittmar', 'distance': 13.32092766978655}
# ap = {'zip': 78719, 'pool': 'Govalle', 'distance': 12.832568229016655}
# ap = {'zip': 78719, 'pool': 'Stacy', 'distance': 12.847853484454273}
# ap = {'zip': 78719, 'pool': 'Dick Nichols', 'distance': 20.074287816660604}
# ap = {'zip': 78719, 'pool': 'Givens', 'distance': 14.966126432124613}
# ap = {'zip': 78719, 'pool': 'Ramsey', 'distance': 19.853895232322024}
# ap = {'zip': 78719, 'pool': 'Northwest', 'distance': 23.62209302289696}
# ap = {'zip': 78719, 'pool': 'Springwoods', 'distance': 37.369470094788575}
# ap = {'zip': 78719, 'pool': 'Dove Springs', 'distance': 8.147567328443342}
# ap = {'zip': 78719, 'pool': 'Shipe', 'distance': 18.809712625623884}
# ap = {'zip': 78719, 'pool': 'Balcones', 'distance': 30.24795097900493}
# ap = {'zip': 78719, 'pool': 'West Austin', 'distance': 16.909563934653388}
# ap = {'zip': 78719, 'pool': 'Reed', 'distance': 20.051733894573097}
# ap = {'zip': 78719, 'pool': 'Civitan', 'distance': 10.440677181181451}
# ap = {'zip': 78721, 'pool': 'Metz', 'distance': 3.833473969527747}
# ap = {'zip': 78721, 'pool': 'Montopolis', 'distance': 4.487830964448303}
# ap = {'zip': 78721, 'pool': 'Canyon Vista', 'distance': 19.977249885246}
# ap = {'zip': 78721, 'pool': 'Kennemer', 'distance': 10.3216515413759}
# ap = {'zip': 78721, 'pool': 'Bartholomew', 'distance': 3.8312712300963683}
# ap = {'zip': 78721, 'pool': 'Walnut Creek', 'distance': 14.282307997983327}
# ap = {'zip': 78721, 'pool': 'Parque Zaragoza', 'distance': 2.957789003126422}
# ap = {'zip': 78721, 'pool': 'Patterson', 'distance': 4.147843575990699}
# ap = {'zip': 78721, 'pool': 'Gillis', 'distance': 7.962223561699528}
# ap = {'zip': 78721, 'pool': 'Martin', 'distance': 5.028558120870968}
# ap = {'zip': 78721, 'pool': 'Brentwood', 'distance': 9.021197593651655}
# ap = {'zip': 78721, 'pool': 'Dottie Jordan', 'distance': 5.019724810656093}
# ap = {'zip': 78721, 'pool': 'Deep Eddy', 'distance': 8.61061577918851}
# ap = {'zip': 78721, 'pool': 'Murchison', 'distance': 11.736265821320044}
# ap = {'zip': 78721, 'pool': 'Mabel Davis', 'distance': 7.927159259919128}
# ap = {'zip': 78721, 'pool': 'Garrison', 'distance': 13.010221373497288}
# ap = {'zip': 78721, 'pool': 'Rosewood', 'distance': 2.9024200965022153}
# ap = {'zip': 78721, 'pool': 'Westenfield', 'distance': 8.019692926333187}
# ap = {'zip': 78721, 'pool': 'Stacy Wading', 'distance': 6.751731828944227}
# ap = {'zip': 78721, 'pool': 'Barton Springs', 'distance': 8.173275378860886}
# ap = {'zip': 78721, 'pool': 'Dittmar', 'distance': 14.667232017314388}
# ap = {'zip': 78721, 'pool': 'Govalle', 'distance': 1.4605364189988377}
# ap = {'zip': 78721, 'pool': 'Stacy', 'distance': 6.989445749057061}
# ap = {'zip': 78721, 'pool': 'Dick Nichols', 'distance': 18.317346576806983}
# ap = {'zip': 78721, 'pool': 'Givens', 'distance': 1.1434783872158094}
# ap = {'zip': 78721, 'pool': 'Ramsey', 'distance': 7.415197144398023}
# ap = {'zip': 78721, 'pool': 'Northwest', 'distance': 10.278598876858387}
# ap = {'zip': 78721, 'pool': 'Springwoods', 'distance': 23.845918070262567}
# ap = {'zip': 78721, 'pool': 'Dove Springs', 'distance': 10.558213224039047}
# ap = {'zip': 78721, 'pool': 'Shipe', 'distance': 5.844648729300473}
# ap = {'zip': 78721, 'pool': 'Balcones', 'distance': 16.33521006434609}
# ap = {'zip': 78721, 'pool': 'West Austin', 'distance': 7.096143294374473}
# ap = {'zip': 78721, 'pool': 'Reed', 'distance': 9.145364667977463}
# ap = {'zip': 78721, 'pool': 'Civitan', 'distance': 3.7477517844516157}
# ap = {'zip': 78722, 'pool': 'Metz', 'distance': 4.159486539647906}
# ap = {'zip': 78722, 'pool': 'Montopolis', 'distance': 6.6233685804616895}
# ap = {'zip': 78722, 'pool': 'Canyon Vista', 'distance': 16.6666238446649}
# ap = {'zip': 78722, 'pool': 'Kennemer', 'distance': 7.909744113299449}
# ap = {'zip': 78722, 'pool': 'Bartholomew', 'distance': 2.1569239083159713}
# ap = {'zip': 78722, 'pool': 'Walnut Creek', 'distance': 12.524455855186186}
# ap = {'zip': 78722, 'pool': 'Parque Zaragoza', 'distance': 3.0914905902870347}
# ap = {'zip': 78722, 'pool': 'Patterson', 'distance': 0.739030674630661}
# ap = {'zip': 78722, 'pool': 'Gillis', 'distance': 7.006642408518604}
# ap = {'zip': 78722, 'pool': 'Martin', 'distance': 4.6187677895114705}
# ap = {'zip': 78722, 'pool': 'Brentwood', 'distance': 5.811528680628767}
# ap = {'zip': 78722, 'pool': 'Dottie Jordan', 'distance': 4.796316159982167}
# ap = {'zip': 78722, 'pool': 'Deep Eddy', 'distance': 5.759106222734701}
# ap = {'zip': 78722, 'pool': 'Murchison', 'distance': 8.220421370153627}
# ap = {'zip': 78722, 'pool': 'Mabel Davis', 'distance': 8.20675220584514}
# ap = {'zip': 78722, 'pool': 'Garrison', 'distance': 11.98068834039198}
# ap = {'zip': 78722, 'pool': 'Rosewood', 'distance': 2.0731467006951627}
# ap = {'zip': 78722, 'pool': 'Westenfield', 'distance': 4.846962157497387}
# ap = {'zip': 78722, 'pool': 'Stacy Wading', 'distance': 6.17197777911097}
# ap = {'zip': 78722, 'pool': 'Barton Springs', 'distance': 5.829099354207779}
# ap = {'zip': 78722, 'pool': 'Dittmar', 'distance': 14.25573321274375}
# ap = {'zip': 78722, 'pool': 'Govalle', 'distance': 4.110768275811677}
# ap = {'zip': 78722, 'pool': 'Stacy', 'distance': 6.419683393325254}
# ap = {'zip': 78722, 'pool': 'Dick Nichols', 'distance': 16.542399003886597}
# ap = {'zip': 78722, 'pool': 'Givens', 'distance': 2.63723618301694}
# ap = {'zip': 78722, 'pool': 'Ramsey', 'distance': 3.710234041298834}
# ap = {'zip': 78722, 'pool': 'Northwest', 'distance': 6.967193702723867}
# ap = {'zip': 78722, 'pool': 'Springwoods', 'distance': 20.710275867051113}
# ap = {'zip': 78722, 'pool': 'Dove Springs', 'distance': 11.567833433379919}
# ap = {'zip': 78722, 'pool': 'Shipe', 'distance': 2.2258685312732025}
# ap = {'zip': 78722, 'pool': 'Balcones', 'distance': 13.73815119022877}
# ap = {'zip': 78722, 'pool': 'West Austin', 'distance': 4.304992312445474}
# ap = {'zip': 78722, 'pool': 'Reed', 'distance': 5.591527838305254}
# ap = {'zip': 78722, 'pool': 'Civitan', 'distance': 6.295842117414736}
# ap = {'zip': 78723, 'pool': 'Metz', 'distance': 6.526952656580953}
# ap = {'zip': 78723, 'pool': 'Montopolis', 'distance': 8.143570567598871}
# ap = {'zip': 78723, 'pool': 'Canyon Vista', 'distance': 16.63841177126754}
# ap = {'zip': 78723, 'pool': 'Kennemer', 'distance': 6.590406884958805}
# ap = {'zip': 78723, 'pool': 'Bartholomew', 'distance': 1.142249615665118}
# ap = {'zip': 78723, 'pool': 'Walnut Creek', 'distance': 10.488542516217533}
# ap = {'zip': 78723, 'pool': 'Parque Zaragoza', 'distance': 5.365901946804924}
# ap = {'zip': 78723, 'pool': 'Patterson', 'distance': 2.8480479827787417}
# ap = {'zip': 78723, 'pool': 'Gillis', 'distance': 10.032799947634112}
# ap = {'zip': 78723, 'pool': 'Martin', 'distance': 7.360392838087268}
# ap = {'zip': 78723, 'pool': 'Brentwood', 'distance': 5.878890058662125}
# ap = {'zip': 78723, 'pool': 'Dottie Jordan', 'distance': 1.624888124956288}
# ap = {'zip': 78723, 'pool': 'Deep Eddy', 'distance': 8.88148918838288}
# ap = {'zip': 78723, 'pool': 'Murchison', 'distance': 8.882664983390958}
# ap = {'zip': 78723, 'pool': 'Mabel Davis', 'distance': 10.82805048407855}
# ap = {'zip': 78723, 'pool': 'Garrison', 'distance': 15.086536356774001}
# ap = {'zip': 78723, 'pool': 'Rosewood', 'distance': 4.5504720979802125}
# ap = {'zip': 78723, 'pool': 'Westenfield', 'distance': 7.863351309198429}
# ap = {'zip': 78723, 'pool': 'Stacy Wading', 'distance': 9.059123445330252}
# ap = {'zip': 78723, 'pool': 'Barton Springs', 'distance': 9.029157147336377}
# ap = {'zip': 78723, 'pool': 'Dittmar', 'distance': 17.219191513861805}
# ap = {'zip': 78723, 'pool': 'Govalle', 'distance': 5.083373415021966}
# ap = {'zip': 78723, 'pool': 'Stacy', 'distance': 9.312369101260398}
# ap = {'zip': 78723, 'pool': 'Dick Nichols', 'distance': 19.744423463451714}
# ap = {'zip': 78723, 'pool': 'Givens', 'distance': 2.9254807441393007}
# ap = {'zip': 78723, 'pool': 'Ramsey', 'distance': 5.641107314808549}
# ap = {'zip': 78723, 'pool': 'Northwest', 'distance': 7.173215326597811}
# ap = {'zip': 78723, 'pool': 'Springwoods', 'distance': 20.32164433871123}
# ap = {'zip': 78723, 'pool': 'Dove Springs', 'distance': 13.899955369935029}
# ap = {'zip': 78723, 'pool': 'Shipe', 'distance': 3.986225036599463}
# ap = {'zip': 78723, 'pool': 'Balcones', 'distance': 12.595221457910096}
# ap = {'zip': 78723, 'pool': 'West Austin', 'distance': 7.4742894312705905}
# ap = {'zip': 78723, 'pool': 'Reed', 'distance': 8.177750825438332}
# ap = {'zip': 78723, 'pool': 'Civitan', 'distance': 7.497839593977786}
# ap = {'zip': 78724, 'pool': 'Metz', 'distance': 11.010173285555164}
# ap = {'zip': 78724, 'pool': 'Montopolis', 'distance': 10.710805004100768}
# ap = {'zip': 78724, 'pool': 'Canyon Vista', 'distance': 22.035537540319673}
# ap = {'zip': 78724, 'pool': 'Kennemer', 'distance': 11.532557059302139}
# ap = {'zip': 78724, 'pool': 'Bartholomew', 'distance': 8.041709908429793}
# ap = {'zip': 78724, 'pool': 'Walnut Creek', 'distance': 13.159535386202563}
# ap = {'zip': 78724, 'pool': 'Parque Zaragoza', 'distance': 10.15189772532813}
# ap = {'zip': 78724, 'pool': 'Patterson', 'distance': 9.589818685959695}
# ap = {'zip': 78724, 'pool': 'Gillis', 'distance': 15.159386367841071}
# ap = {'zip': 78724, 'pool': 'Martin', 'distance': 12.226717554645314}
# ap = {'zip': 78724, 'pool': 'Brentwood', 'distance': 12.27447917252171}
# ap = {'zip': 78724, 'pool': 'Dottie Jordan', 'distance': 6.105105950012952}
# ap = {'zip': 78724, 'pool': 'Deep Eddy', 'distance': 15.356127805637652}
# ap = {'zip': 78724, 'pool': 'Murchison', 'distance': 15.346123811376836}
# ap = {'zip': 78724, 'pool': 'Mabel Davis', 'distance': 14.847081717791811}
# ap = {'zip': 78724, 'pool': 'Garrison', 'distance': 20.176651351248356}
# ap = {'zip': 78724, 'pool': 'Rosewood', 'distance': 9.909567434981163}
# ap = {'zip': 78724, 'pool': 'Westenfield', 'distance': 14.507516908998356}
# ap = {'zip': 78724, 'pool': 'Stacy Wading', 'distance': 13.933703819873916}
# ap = {'zip': 78724, 'pool': 'Barton Springs', 'distance': 15.166263069944167}
# ap = {'zip': 78724, 'pool': 'Dittmar', 'distance': 21.64193028215139}
# ap = {'zip': 78724, 'pool': 'Govalle', 'distance': 8.42064115096588}
# ap = {'zip': 78724, 'pool': 'Stacy', 'distance': 14.165932209566172}
# ap = {'zip': 78724, 'pool': 'Dick Nichols', 'distance': 25.51405034792783}
# ap = {'zip': 78724, 'pool': 'Givens', 'distance': 7.566965769622557}
# ap = {'zip': 78724, 'pool': 'Ramsey', 'distance': 12.597363763154359}
# ap = {'zip': 78724, 'pool': 'Northwest', 'distance': 13.493463654377091}
# ap = {'zip': 78724, 'pool': 'Springwoods', 'distance': 25.07613485071437}
# ap = {'zip': 78724, 'pool': 'Dove Springs', 'distance': 16.85125227326324}
# ap = {'zip': 78724, 'pool': 'Shipe', 'distance': 10.93320405812122}
# ap = {'zip': 78724, 'pool': 'Balcones', 'distance': 16.731187784031665}
# ap = {'zip': 78724, 'pool': 'West Austin', 'distance': 13.851086565613873}
# ap = {'zip': 78724, 'pool': 'Reed', 'distance': 15.077367867647007}
# ap = {'zip': 78724, 'pool': 'Civitan', 'distance': 9.78706446255732}
# ap = {'zip': 78725, 'pool': 'Metz', 'distance': 10.70919078153618}
# ap = {'zip': 78725, 'pool': 'Montopolis', 'distance': 8.722828167371466}
# ap = {'zip': 78725, 'pool': 'Canyon Vista', 'distance': 27.183543952312462}
# ap = {'zip': 78725, 'pool': 'Kennemer', 'distance': 16.786225034467755}
# ap = {'zip': 78725, 'pool': 'Bartholomew', 'distance': 11.31014304972429}
# ap = {'zip': 78725, 'pool': 'Walnut Creek', 'distance': 19.33012267037565}
# ap = {'zip': 78725, 'pool': 'Parque Zaragoza', 'distance': 10.476965128883323}
# ap = {'zip': 78725, 'pool': 'Patterson', 'distance': 12.18995011159218}
# ap = {'zip': 78725, 'pool': 'Gillis', 'distance': 14.456522502377881}
# ap = {'zip': 78725, 'pool': 'Martin', 'distance': 11.90906553402501}
# ap = {'zip': 78725, 'pool': 'Brentwood', 'distance': 16.51008003648248}
# ap = {'zip': 78725, 'pool': 'Dottie Jordan', 'distance': 10.734121287564362}
# ap = {'zip': 78725, 'pool': 'Deep Eddy', 'distance': 16.470437070109647}
# ap = {'zip': 78725, 'pool': 'Murchison', 'distance': 19.47323622466143}
# ap = {'zip': 78725, 'pool': 'Mabel Davis', 'distance': 13.022192402037692}
# ap = {'zip': 78725, 'pool': 'Garrison', 'distance': 18.762617687665482}
# ap = {'zip': 78725, 'pool': 'Rosewood', 'distance': 10.873178673134742}
# ap = {'zip': 78725, 'pool': 'Westenfield', 'distance': 16.061057399610522}
# ap = {'zip': 78725, 'pool': 'Stacy Wading', 'distance': 13.194704321343687}
# ap = {'zip': 78725, 'pool': 'Barton Springs', 'distance': 15.754473448341482}
# ap = {'zip': 78725, 'pool': 'Dittmar', 'distance': 19.33498848366239}
# ap = {'zip': 78725, 'pool': 'Govalle', 'distance': 8.391839245331576}
# ap = {'zip': 78725, 'pool': 'Stacy', 'distance': 13.353910375095264}
# ap = {'zip': 78725, 'pool': 'Dick Nichols', 'distance': 24.605179675545106}
# ap = {'zip': 78725, 'pool': 'Givens', 'distance': 9.214852147635392}
# ap = {'zip': 78725, 'pool': 'Ramsey', 'distance': 15.513989397869258}
# ap = {'zip': 78725, 'pool': 'Northwest', 'distance': 17.805126559246755}
# ap = {'zip': 78725, 'pool': 'Springwoods', 'distance': 30.648037626910675}
# ap = {'zip': 78725, 'pool': 'Dove Springs', 'distance': 13.644537025639407}
# ap = {'zip': 78725, 'pool': 'Shipe', 'distance': 13.872128067883882}
# ap = {'zip': 78725, 'pool': 'Balcones', 'distance': 22.50621598243788}
# ap = {'zip': 78725, 'pool': 'West Austin', 'distance': 15.010664956286703}
# ap = {'zip': 78725, 'pool': 'Reed', 'distance': 17.306483189442545}
# ap = {'zip': 78725, 'pool': 'Civitan', 'distance': 7.980237487902654}
# ap = {'zip': 78726, 'pool': 'Metz', 'distance': 22.977763833157876}
# ap = {'zip': 78726, 'pool': 'Montopolis', 'distance': 25.901527653207093}
# ap = {'zip': 78726, 'pool': 'Canyon Vista', 'distance': 5.507842620449144}
# ap = {'zip': 78726, 'pool': 'Kennemer', 'distance': 15.082843672075615}
# ap = {'zip': 78726, 'pool': 'Bartholomew', 'distance': 19.808368550569174}
# ap = {'zip': 78726, 'pool': 'Walnut Creek', 'distance': 15.966826792399559}
# ap = {'zip': 78726, 'pool': 'Parque Zaragoza', 'distance': 22.34377653084564}
# ap = {'zip': 78726, 'pool': 'Patterson', 'distance': 19.21855363573681}
# ap = {'zip': 78726, 'pool': 'Gillis', 'distance': 22.556708942474405}
# ap = {'zip': 78726, 'pool': 'Martin', 'distance': 22.529731619079005}
# ap = {'zip': 78726, 'pool': 'Brentwood', 'distance': 14.589114834497003}
# ap = {'zip': 78726, 'pool': 'Dottie Jordan', 'distance': 20.634992554199524}
# ap = {'zip': 78726, 'pool': 'Deep Eddy', 'distance': 18.14806634984887}
# ap = {'zip': 78726, 'pool': 'Murchison', 'distance': 11.643963473054642}
# ap = {'zip': 78726, 'pool': 'Mabel Davis', 'distance': 25.14415243645116}
# ap = {'zip': 78726, 'pool': 'Garrison', 'distance': 24.387863368493775}
# ap = {'zip': 78726, 'pool': 'Rosewood', 'distance': 21.463008745888587}
# ap = {'zip': 78726, 'pool': 'Westenfield', 'distance': 17.538192688807595}
# ap = {'zip': 78726, 'pool': 'Stacy Wading', 'distance': 22.882137574004073}
# ap = {'zip': 78726, 'pool': 'Barton Springs', 'distance': 19.499261339595478}
# ap = {'zip': 78726, 'pool': 'Dittmar', 'distance': 27.387827610160375}
# ap = {'zip': 78726, 'pool': 'Govalle', 'distance': 23.846774981837257}
# ap = {'zip': 78726, 'pool': 'Stacy', 'distance': 22.99045331037664}
# ap = {'zip': 78726, 'pool': 'Dick Nichols', 'distance': 23.952202619359536}
# ap = {'zip': 78726, 'pool': 'Givens', 'distance': 22.21336370692136}
# ap = {'zip': 78726, 'pool': 'Ramsey', 'distance': 16.121733119150306}
# ap = {'zip': 78726, 'pool': 'Northwest', 'distance': 13.29545721275549}
# ap = {'zip': 78726, 'pool': 'Springwoods', 'distance': 7.027039901674108}
# ap = {'zip': 78726, 'pool': 'Dove Springs', 'distance': 28.597639562347695}
# ap = {'zip': 78726, 'pool': 'Shipe', 'distance': 17.538549410769534}
# ap = {'zip': 78726, 'pool': 'Balcones', 'distance': 11.759616188341521}
# ap = {'zip': 78726, 'pool': 'West Austin', 'distance': 18.776748121277432}
# ap = {'zip': 78726, 'pool': 'Reed', 'distance': 15.626945866085181}
# ap = {'zip': 78726, 'pool': 'Civitan', 'distance': 25.827192218755723}
# ap = {'zip': 78727, 'pool': 'Metz', 'distance': 19.661186671858353}
# ap = {'zip': 78727, 'pool': 'Montopolis', 'distance': 22.03736564153735}
# ap = {'zip': 78727, 'pool': 'Canyon Vista', 'distance': 6.456086786926219}
# ap = {'zip': 78727, 'pool': 'Kennemer', 'distance': 7.715392693425503}
# ap = {'zip': 78727, 'pool': 'Bartholomew', 'distance': 14.263179507843148}
# ap = {'zip': 78727, 'pool': 'Walnut Creek', 'distance': 5.0138804625910876}
# ap = {'zip': 78727, 'pool': 'Parque Zaragoza', 'distance': 18.607471402998033}
# ap = {'zip': 78727, 'pool': 'Patterson', 'distance': 14.782241122743295}
# ap = {'zip': 78727, 'pool': 'Gillis', 'distance': 21.464641758397306}
# ap = {'zip': 78727, 'pool': 'Martin', 'distance': 19.898605658074143}
# ap = {'zip': 78727, 'pool': 'Brentwood', 'distance': 9.980580433322276}
# ap = {'zip': 78727, 'pool': 'Dottie Jordan', 'distance': 13.48513818692038}
# ap = {'zip': 78727, 'pool': 'Deep Eddy', 'distance': 17.710552414502242}
# ap = {'zip': 78727, 'pool': 'Murchison', 'distance': 9.34663153847682}
# ap = {'zip': 78727, 'pool': 'Mabel Davis', 'distance': 23.392968752623457}
# ap = {'zip': 78727, 'pool': 'Garrison', 'distance': 25.408780745338206}
# ap = {'zip': 78727, 'pool': 'Rosewood', 'distance': 17.590044246956076}
# ap = {'zip': 78727, 'pool': 'Westenfield', 'distance': 16.544468842372723}
# ap = {'zip': 78727, 'pool': 'Stacy Wading', 'distance': 21.0993357376534}
# ap = {'zip': 78727, 'pool': 'Barton Springs', 'distance': 18.834696635065967}
# ap = {'zip': 78727, 'pool': 'Dittmar', 'distance': 28.26908650425216}
# ap = {'zip': 78727, 'pool': 'Govalle', 'distance': 19.13833467559093}
# ap = {'zip': 78727, 'pool': 'Stacy', 'distance': 21.310402386238952}
# ap = {'zip': 78727, 'pool': 'Dick Nichols', 'distance': 27.67180289789809}
# ap = {'zip': 78727, 'pool': 'Givens', 'distance': 17.004218443174366}
# ap = {'zip': 78727, 'pool': 'Ramsey', 'distance': 13.321622064743199}
# ap = {'zip': 78727, 'pool': 'Northwest', 'distance': 9.23575636818582}
# ap = {'zip': 78727, 'pool': 'Springwoods', 'distance': 7.51095810767104}
# ap = {'zip': 78727, 'pool': 'Dove Springs', 'distance': 26.921228743300517}
# ap = {'zip': 78727, 'pool': 'Shipe', 'distance': 13.670035951023712}
# ap = {'zip': 78727, 'pool': 'Balcones', 'distance': 1.8200220347799212}
# ap = {'zip': 78727, 'pool': 'West Austin', 'distance': 17.335713725982515}
# ap = {'zip': 78727, 'pool': 'Reed', 'distance': 14.962719873635454}
# ap = {'zip': 78727, 'pool': 'Civitan', 'distance': 21.547356486584558}
# ap = {'zip': 78728, 'pool': 'Metz', 'distance': 22.830605814277813}
# ap = {'zip': 78728, 'pool': 'Montopolis', 'distance': 24.99026510659261}
# ap = {'zip': 78728, 'pool': 'Canyon Vista', 'distance': 9.661525563579675}
# ap = {'zip': 78728, 'pool': 'Kennemer', 'distance': 10.770738605438185}
# ap = {'zip': 78728, 'pool': 'Bartholomew', 'distance': 17.156441326152027}
# ap = {'zip': 78728, 'pool': 'Walnut Creek', 'distance': 6.53696948978207}
# ap = {'zip': 78728, 'pool': 'Parque Zaragoza', 'distance': 21.725149132576572}
# ap = {'zip': 78728, 'pool': 'Patterson', 'distance': 17.93658614869635}
# ap = {'zip': 78728, 'pool': 'Gillis', 'distance': 24.99297826175767}
# ap = {'zip': 78728, 'pool': 'Martin', 'distance': 23.202940981762385}
# ap = {'zip': 78728, 'pool': 'Brentwood', 'distance': 13.482629087354418}
# ap = {'zip': 78728, 'pool': 'Dottie Jordan', 'distance': 15.893833344245945}
# ap = {'zip': 78728, 'pool': 'Deep Eddy', 'distance': 21.434539536576498}
# ap = {'zip': 78728, 'pool': 'Murchison', 'distance': 13.23776310002768}
# ap = {'zip': 78728, 'pool': 'Mabel Davis', 'distance': 26.75946843248635}
# ap = {'zip': 78728, 'pool': 'Garrison', 'distance': 29.14350471673746}
# ap = {'zip': 78728, 'pool': 'Rosewood', 'distance': 20.72259286508036}
# ap = {'zip': 78728, 'pool': 'Westenfield', 'distance': 20.236824403274746}
# ap = {'zip': 78728, 'pool': 'Stacy Wading', 'distance': 24.52314870611187}
# ap = {'zip': 78728, 'pool': 'Barton Springs', 'distance': 22.497297991470557}
# ap = {'zip': 78728, 'pool': 'Dittmar', 'distance': 31.948061220385735}
# ap = {'zip': 78728, 'pool': 'Govalle', 'distance': 21.98542378452617}
# ap = {'zip': 78728, 'pool': 'Stacy', 'distance': 24.74599744995343}
# ap = {'zip': 78728, 'pool': 'Dick Nichols', 'distance': 31.612154865197102}
# ap = {'zip': 78728, 'pool': 'Givens', 'distance': 19.818344932920024}
# ap = {'zip': 78728, 'pool': 'Ramsey', 'distance': 16.898249296432905}
# ap = {'zip': 78728, 'pool': 'Northwest', 'distance': 12.912364233684931}
# ap = {'zip': 78728, 'pool': 'Springwoods', 'distance': 8.980525442117978}
# ap = {'zip': 78728, 'pool': 'Dove Springs', 'distance': 30.221071563969737}
# ap = {'zip': 78728, 'pool': 'Shipe', 'distance': 17.025413324524685}
# ap = {'zip': 78728, 'pool': 'Balcones', 'distance': 5.643365124324496}
# ap = {'zip': 78728, 'pool': 'West Austin', 'distance': 20.938138589696603}
# ap = {'zip': 78728, 'pool': 'Reed', 'distance': 18.75021643548004}
# ap = {'zip': 78728, 'pool': 'Civitan', 'distance': 24.410865501334765}
# ap = {'zip': 78729, 'pool': 'Metz', 'distance': 23.162845008339435}
# ap = {'zip': 78729, 'pool': 'Montopolis', 'distance': 25.76762544874746}
# ap = {'zip': 78729, 'pool': 'Canyon Vista', 'distance': 4.437828090129505}
# ap = {'zip': 78729, 'pool': 'Kennemer', 'distance': 11.850137219554219}
# ap = {'zip': 78729, 'pool': 'Bartholomew', 'distance': 18.235648630479528}
# ap = {'zip': 78729, 'pool': 'Walnut Creek', 'distance': 9.909643503758863}
# ap = {'zip': 78729, 'pool': 'Parque Zaragoza', 'distance': 22.202964593271062}
# ap = {'zip': 78729, 'pool': 'Patterson', 'distance': 18.43884162489781}
# ap = {'zip': 78729, 'pool': 'Gillis', 'distance': 24.311446226258248}
# ap = {'zip': 78729, 'pool': 'Martin', 'distance': 23.193808275403008}
# ap = {'zip': 78729, 'pool': 'Brentwood', 'distance': 13.346011966225584}
# ap = {'zip': 78729, 'pool': 'Dottie Jordan', 'distance': 17.872494796224828}
# ap = {'zip': 78729, 'pool': 'Deep Eddy', 'distance': 20.172902706394588}
# ap = {'zip': 78729, 'pool': 'Murchison', 'distance': 11.684513512635526}
# ap = {'zip': 78729, 'pool': 'Mabel Davis', 'distance': 26.512801269677336}
# ap = {'zip': 78729, 'pool': 'Garrison', 'distance': 27.65036553110194}
# ap = {'zip': 78729, 'pool': 'Rosewood', 'distance': 21.191218777620392}
# ap = {'zip': 78729, 'pool': 'Westenfield', 'distance': 19.138057105393827}
# ap = {'zip': 78729, 'pool': 'Stacy Wading', 'distance': 24.161778020789132}
# ap = {'zip': 78729, 'pool': 'Barton Springs', 'distance': 21.432502123275032}
# ap = {'zip': 78729, 'pool': 'Dittmar', 'distance': 30.627893396522005}
# ap = {'zip': 78729, 'pool': 'Govalle', 'distance': 23.03643283602861}
# ap = {'zip': 78729, 'pool': 'Stacy', 'distance': 24.346224655145733}
# ap = {'zip': 78729, 'pool': 'Dick Nichols', 'distance': 28.975996223523037}
# ap = {'zip': 78729, 'pool': 'Givens', 'distance': 20.98096480357352}
# ap = {'zip': 78729, 'pool': 'Ramsey', 'distance': 16.336254022770913}
# ap = {'zip': 78729, 'pool': 'Northwest', 'distance': 12.294398277758317}
# ap = {'zip': 78729, 'pool': 'Springwoods', 'distance': 2.734332922069923}
# ap = {'zip': 78729, 'pool': 'Dove Springs', 'distance': 30.098506102880272}
# ap = {'zip': 78729, 'pool': 'Shipe', 'distance': 17.079489112435386}
# ap = {'zip': 78729, 'pool': 'Balcones', 'distance': 6.0312418743638885}
# ap = {'zip': 78729, 'pool': 'West Austin', 'distance': 20.129269913354975}
# ap = {'zip': 78729, 'pool': 'Reed', 'distance': 17.331084496609062}
# ap = {'zip': 78729, 'pool': 'Civitan', 'distance': 25.384976777566397}
# ap = {'zip': 78730, 'pool': 'Metz', 'distance': 16.928155826558374}
# ap = {'zip': 78730, 'pool': 'Montopolis', 'distance': 19.86713725158946}
# ap = {'zip': 78730, 'pool': 'Canyon Vista', 'distance': 8.565730315667736}
# ap = {'zip': 78730, 'pool': 'Kennemer', 'distance': 12.558996931005035}
# ap = {'zip': 78730, 'pool': 'Bartholomew', 'distance': 15.119215164981057}
# ap = {'zip': 78730, 'pool': 'Walnut Creek', 'distance': 15.590740670321763}
# ap = {'zip': 78730, 'pool': 'Parque Zaragoza', 'distance': 16.510535075196334}
# ap = {'zip': 78730, 'pool': 'Patterson', 'distance': 14.061640215045697}
# ap = {'zip': 78730, 'pool': 'Gillis', 'distance': 15.821373384024648}
# ap = {'zip': 78730, 'pool': 'Martin', 'distance': 16.263584487006632}
# ap = {'zip': 78730, 'pool': 'Brentwood', 'distance': 10.615194467822274}
# ap = {'zip': 78730, 'pool': 'Dottie Jordan', 'distance': 16.703719028040872}
# ap = {'zip': 78730, 'pool': 'Deep Eddy', 'distance': 11.509376575595619}
# ap = {'zip': 78730, 'pool': 'Murchison', 'distance': 7.649753329587803}
# ap = {'zip': 78730, 'pool': 'Mabel Davis', 'distance': 18.469845685667426}
# ap = {'zip': 78730, 'pool': 'Garrison', 'distance': 17.23679423396092}
# ap = {'zip': 78730, 'pool': 'Rosewood', 'distance': 15.769547865669214}
# ap = {'zip': 78730, 'pool': 'Westenfield', 'distance': 11.145437291835211}
# ap = {'zip': 78730, 'pool': 'Stacy Wading', 'distance': 16.321200343997063}
# ap = {'zip': 78730, 'pool': 'Barton Springs', 'distance': 12.822711691729403}
# ap = {'zip': 78730, 'pool': 'Dittmar', 'distance': 20.222074183608868}
# ap = {'zip': 78730, 'pool': 'Govalle', 'distance': 18.2974325635464}
# ap = {'zip': 78730, 'pool': 'Stacy', 'distance': 16.393858503683944}
# ap = {'zip': 78730, 'pool': 'Dick Nichols', 'distance': 16.867877029433537}
# ap = {'zip': 78730, 'pool': 'Givens', 'distance': 17.047521383471885}
# ap = {'zip': 78730, 'pool': 'Ramsey', 'distance': 10.73684437717728}
# ap = {'zip': 78730, 'pool': 'Northwest', 'distance': 9.521945674136802}
# ap = {'zip': 78730, 'pool': 'Springwoods', 'distance': 12.468105065551983}
# ap = {'zip': 78730, 'pool': 'Dove Springs', 'distance': 21.796588398149762}
# ap = {'zip': 78730, 'pool': 'Shipe', 'distance': 12.389180890022873}
# ap = {'zip': 78730, 'pool': 'Balcones', 'distance': 12.40448186338247}
# ap = {'zip': 78730, 'pool': 'West Austin', 'distance': 12.409453721698249}
# ap = {'zip': 78730, 'pool': 'Reed', 'distance': 9.374260452255061}
# ap = {'zip': 78730, 'pool': 'Civitan', 'distance': 19.957687948452637}
# ap = {'zip': 78731, 'pool': 'Metz', 'distance': 11.583833801056997}
# ap = {'zip': 78731, 'pool': 'Montopolis', 'distance': 14.460725916423929}
# ap = {'zip': 78731, 'pool': 'Canyon Vista', 'distance': 9.00568155443262}
# ap = {'zip': 78731, 'pool': 'Kennemer', 'distance': 6.130059435124411}
# ap = {'zip': 78731, 'pool': 'Bartholomew', 'distance': 8.457610739979067}
# ap = {'zip': 78731, 'pool': 'Walnut Creek', 'distance': 10.252404898040847}
# ap = {'zip': 78731, 'pool': 'Parque Zaragoza', 'distance': 10.860297325667714}
# ap = {'zip': 78731, 'pool': 'Patterson', 'distance': 7.694125963240479}
# ap = {'zip': 78731, 'pool': 'Gillis', 'distance': 11.996711348490768}
# ap = {'zip': 78731, 'pool': 'Martin', 'distance': 11.305934946256162}
# ap = {'zip': 78731, 'pool': 'Brentwood', 'distance': 3.7361251795526362}
# ap = {'zip': 78731, 'pool': 'Dottie Jordan', 'distance': 9.8352235439274}
# ap = {'zip': 78731, 'pool': 'Deep Eddy', 'distance': 7.769617896244212}
# ap = {'zip': 78731, 'pool': 'Murchison', 'distance': 1.150394873600923}
# ap = {'zip': 78731, 'pool': 'Mabel Davis', 'distance': 14.347838241648718}
# ap = {'zip': 78731, 'pool': 'Garrison', 'distance': 15.287708452139382}
# ap = {'zip': 78731, 'pool': 'Rosewood', 'distance': 9.947967745564705}
# ap = {'zip': 78731, 'pool': 'Westenfield', 'distance': 6.777519979357512}
# ap = {'zip': 78731, 'pool': 'Stacy Wading', 'distance': 11.995102233053114}
# ap = {'zip': 78731, 'pool': 'Barton Springs', 'distance': 9.048674057806632}
# ap = {'zip': 78731, 'pool': 'Dittmar', 'distance': 18.241512346973558}
# ap = {'zip': 78731, 'pool': 'Govalle', 'distance': 12.304412327210892}
# ap = {'zip': 78731, 'pool': 'Stacy', 'distance': 12.153819205559206}
# ap = {'zip': 78731, 'pool': 'Dick Nichols', 'distance': 17.32051641727852}
# ap = {'zip': 78731, 'pool': 'Givens', 'distance': 10.70642089610989}
# ap = {'zip': 78731, 'pool': 'Ramsey', 'distance': 4.6013386824603675}
# ap = {'zip': 78731, 'pool': 'Northwest', 'distance': 2.7501284677341786}
# ap = {'zip': 78731, 'pool': 'Springwoods', 'distance': 13.340541677589114}
# ap = {'zip': 78731, 'pool': 'Dove Springs', 'distance': 17.92792589427497}
# ap = {'zip': 78731, 'pool': 'Shipe', 'distance': 6.003879009514676}
# ap = {'zip': 78731, 'pool': 'Balcones', 'distance': 8.648287550275093}
# ap = {'zip': 78731, 'pool': 'West Austin', 'distance': 7.856496501646713}
# ap = {'zip': 78731, 'pool': 'Reed', 'distance': 4.927957393111601}
# ap = {'zip': 78731, 'pool': 'Civitan', 'distance': 14.326406987388802}
# ap = {'zip': 78732, 'pool': 'Metz', 'distance': 21.902931150773867}
# ap = {'zip': 78732, 'pool': 'Montopolis', 'distance': 24.795466396391657}
# ap = {'zip': 78732, 'pool': 'Canyon Vista', 'distance': 11.68758831761029}
# ap = {'zip': 78732, 'pool': 'Kennemer', 'distance': 18.01806297710252}
# ap = {'zip': 78732, 'pool': 'Bartholomew', 'distance': 20.627489685691657}
# ap = {'zip': 78732, 'pool': 'Walnut Creek', 'distance': 20.60026009246897}
# ap = {'zip': 78732, 'pool': 'Parque Zaragoza', 'distance': 21.624144642269908}
# ap = {'zip': 78732, 'pool': 'Patterson', 'distance': 19.48405336209029}
# ap = {'zip': 78732, 'pool': 'Gillis', 'distance': 20.15578339533975}
# ap = {'zip': 78732, 'pool': 'Martin', 'distance': 21.094195449324697}
# ap = {'zip': 78732, 'pool': 'Brentwood', 'distance': 16.194824272118083}
# ap = {'zip': 78732, 'pool': 'Dottie Jordan', 'distance': 22.27859518786724}
# ap = {'zip': 78732, 'pool': 'Deep Eddy', 'distance': 16.14216178107724}
# ap = {'zip': 78732, 'pool': 'Murchison', 'distance': 13.207818201545678}
# ap = {'zip': 78732, 'pool': 'Mabel Davis', 'distance': 22.81444069446118}
# ...
# ap = {'zip': 78753, 'pool': 'Patterson', 'distance': 10.261592211475028}
# ap = {'zip': 78753, 'pool': 'Gillis', 'distance': 17.80518281605543}
# ap = {'zip': 78753, 'pool': 'Martin', 'distance': 15.58745225064933}
# ap = {'zip': 78753, 'pool': 'Brentwood', 'distance': 7.145197379509358}
# ap = {'zip': 78753, 'pool': 'Dottie Jordan', 'distance': 7.530217051148017}
# ap = {'zip': 78753, 'pool': 'Deep Eddy', 'distance': 15.022705026285786}
# ap = {'zip': 78753, 'pool': 'Murchison', 'distance': 8.764717165689207}
# ap = {'zip': 78753, 'pool': 'Mabel Davis', 'distance': 19.173503390486005}
# ap = {'zip': 78753, 'pool': 'Garrison', 'distance': 22.47622594073507}
# ap = {'zip': 78753, 'pool': 'Rosewood', 'distance': 12.900668729818221}
# ap = {'zip': 78753, 'pool': 'Westenfield', 'distance': 13.77586793238177}
# ap = {'zip': 78753, 'pool': 'Stacy Wading', 'distance': 17.10517449682653}
# ap = {'zip': 78753, 'pool': 'Barton Springs', 'distance': 15.802100015455304}
# ap = {'zip': 78753, 'pool': 'Dittmar', 'distance': 25.02389440213686}
# ap = {'zip': 78753, 'pool': 'Govalle', 'distance': 13.807690430362312}
# ap = {'zip': 78753, 'pool': 'Stacy', 'distance': 17.347202779745203}
# ap = {'zip': 78753, 'pool': 'Dick Nichols', 'distance': 26.024320646137276}
# ap = {'zip': 78753, 'pool': 'Givens', 'distance': 11.649439410764234}
# ap = {'zip': 78753, 'pool': 'Ramsey', 'distance': 10.306671938456105}
# ap = {'zip': 78753, 'pool': 'Northwest', 'distance': 7.356145913112726}
# ap = {'zip': 78753, 'pool': 'Springwoods', 'distance': 14.080049619746935}
# ap = {'zip': 78753, 'pool': 'Dove Springs', 'distance': 22.46354689616575}
# ap = {'zip': 78753, 'pool': 'Shipe', 'distance': 9.811677009459913}
# ap = {'zip': 78753, 'pool': 'Balcones', 'distance': 5.717982551516413}
# ap = {'zip': 78753, 'pool': 'West Austin', 'distance': 14.125565429502318}
# ap = {'zip': 78753, 'pool': 'Reed', 'distance': 12.813444306538436}
# ap = {'zip': 78753, 'pool': 'Civitan', 'distance': 16.215723780934532}
# ap = {'zip': 78754, 'pool': 'Metz', 'distance': 13.44891075067763}
# ap = {'zip': 78754, 'pool': 'Montopolis', 'distance': 14.718192985715842}
# ap = {'zip': 78754, 'pool': 'Canyon Vista', 'distance': 15.587865795023681}
# ap = {'zip': 78754, 'pool': 'Kennemer', 'distance': 5.944000464705489}
# ap = {'zip': 78754, 'pool': 'Bartholomew', 'distance': 7.788624316454189}
# ap = {'zip': 78754, 'pool': 'Walnut Creek', 'distance': 5.797131228570805}
# ap = {'zip': 78754, 'pool': 'Parque Zaragoza', 'distance': 12.293881803631265}
# ap = {'zip': 78754, 'pool': 'Patterson', 'distance': 9.346656536796802}
# ap = {'zip': 78754, 'pool': 'Gillis', 'distance': 16.910302862559774}
# ap = {'zip': 78754, 'pool': 'Martin', 'distance': 14.29824616321591}
# ap = {'zip': 78754, 'pool': 'Brentwood', 'distance': 8.383929166005535}
# ap = {'zip': 78754, 'pool': 'Dottie Jordan', 'distance': 5.36213886085422}
# ap = {'zip': 78754, 'pool': 'Deep Eddy', 'distance': 15.055080225283405}
# ap = {'zip': 78754, 'pool': 'Murchison', 'distance': 10.930956708716357}
# ap = {'zip': 78754, 'pool': 'Mabel Davis', 'distance': 17.75746159006462}
# ap = {'zip': 78754, 'pool': 'Garrison', 'distance': 21.898594391645677}
# ap = {'zip': 78754, 'pool': 'Rosewood', 'distance': 11.488635349752427}
# ap = {'zip': 78754, 'pool': 'Westenfield', 'distance': 13.867908333277363}
# ap = {'zip': 78754, 'pool': 'Stacy Wading', 'distance': 15.984041958728218}
# ap = {'zip': 78754, 'pool': 'Barton Springs', 'distance': 15.520219375207015}
# ap = {'zip': 78754, 'pool': 'Dittmar', 'distance': 24.134834931471335}
# ap = {'zip': 78754, 'pool': 'Govalle', 'distance': 11.673454040702044}
# ap = {'zip': 78754, 'pool': 'Stacy', 'distance': 16.236820857428263}
# ap = {'zip': 78754, 'pool': 'Dick Nichols', 'distance': 26.183359574269172}
# ap = {'zip': 78754, 'pool': 'Givens', 'distance': 9.671816687326865}
# ap = {'zip': 78754, 'pool': 'Ramsey', 'distance': 10.678548686168261}
# ap = {'zip': 78754, 'pool': 'Northwest', 'distance': 9.152277957517894}
# ap = {'zip': 78754, 'pool': 'Springwoods', 'distance': 18.091591079090755}
# ap = {'zip': 78754, 'pool': 'Dove Springs', 'distance': 20.726202151031092}
# ap = {'zip': 78754, 'pool': 'Shipe', 'distance': 9.589122566307658}
# ap = {'zip': 78754, 'pool': 'Balcones', 'distance': 9.710503522694031}
# ap = {'zip': 78754, 'pool': 'West Austin', 'distance': 13.855334002303055}
# ap = {'zip': 78754, 'pool': 'Reed', 'distance': 13.440605067130482}
# ap = {'zip': 78754, 'pool': 'Civitan', 'distance': 13.939676552961744}
# ap = {'zip': 78756, 'pool': 'Metz', 'distance': 8.021798964804633}
# ap = {'zip': 78756, 'pool': 'Montopolis', 'distance': 10.791535324446123}
# ap = {'zip': 78756, 'pool': 'Canyon Vista', 'distance': 12.417708409754075}
# ap = {'zip': 78756, 'pool': 'Kennemer', 'distance': 5.3623020048696315}
# ap = {'zip': 78756, 'pool': 'Bartholomew', 'distance': 4.662749790537472}
# ap = {'zip': 78756, 'pool': 'Walnut Creek', 'distance': 10.277430942073249}
# ap = {'zip': 78756, 'pool': 'Parque Zaragoza', 'distance': 7.168061581945578}
# ap = {'zip': 78756, 'pool': 'Patterson', 'distance': 3.802964838044953}
# ap = {'zip': 78756, 'pool': 'Gillis', 'distance': 9.3433033349908}
# ap = {'zip': 78756, 'pool': 'Martin', 'distance': 7.979398341713191}
# ap = {'zip': 78756, 'pool': 'Brentwood', 'distance': 2.228728449659741}
# ap = {'zip': 78756, 'pool': 'Dottie Jordan', 'distance': 6.468676520487685}
# ap = {'zip': 78756, 'pool': 'Deep Eddy', 'distance': 5.87789325636209}
# ap = {'zip': 78756, 'pool': 'Murchison', 'distance': 3.888506937226252}
# ap = {'zip': 78756, 'pool': 'Mabel Davis', 'distance': 11.345775989188738}
# ap = {'zip': 78756, 'pool': 'Garrison', 'distance': 13.52426693333009}
# ap = {'zip': 78756, 'pool': 'Rosewood', 'distance': 6.202002093457555}
# ap = {'zip': 78756, 'pool': 'Westenfield', 'distance': 4.6370821154839765}
# ap = {'zip': 78756, 'pool': 'Stacy Wading', 'distance': 9.017006322235806}
# ap = {'zip': 78756, 'pool': 'Barton Springs', 'distance': 6.829086371322633}
# ap = {'zip': 78756, 'pool': 'Dittmar', 'distance': 16.26873777340321}
# ap = {'zip': 78756, 'pool': 'Govalle', 'distance': 8.457479226318211}
# ap = {'zip': 78756, 'pool': 'Stacy', 'distance': 9.218429071795663}
# ap = {'zip': 78756, 'pool': 'Dick Nichols', 'distance': 16.807642740559018}
# ap = {'zip': 78756, 'pool': 'Givens', 'distance': 6.812838098092082}
# ap = {'zip': 78756, 'pool': 'Ramsey', 'distance': 1.2067823812176535}
# ap = {'zip': 78756, 'pool': 'Northwest', 'distance': 2.942238927291256}
# ap = {'zip': 78756, 'pool': 'Springwoods', 'distance': 16.571985789317882}
# ap = {'zip': 78756, 'pool': 'Dove Springs', 'distance': 14.916661499721007}
# ap = {'zip': 78756, 'pool': 'Shipe', 'distance': 2.1238996755341266}
# ap = {'zip': 78756, 'pool': 'Balcones', 'distance': 10.301671149868685}
# ap = {'zip': 78756, 'pool': 'West Austin', 'distance': 5.24646322114911}
# ap = {'zip': 78756, 'pool': 'Reed', 'distance': 3.637915608200383}
# ap = {'zip': 78756, 'pool': 'Civitan', 'distance': 10.571732515306786}
# ap = {'zip': 78757, 'pool': 'Metz', 'distance': 11.083188948336698}
# ap = {'zip': 78757, 'pool': 'Montopolis', 'distance': 13.6850526533976}
# ap = {'zip': 78757, 'pool': 'Canyon Vista', 'distance': 9.778405265014507}
# ap = {'zip': 78757, 'pool': 'Kennemer', 'distance': 2.697212714100517}
# ap = {'zip': 78757, 'pool': 'Bartholomew', 'distance': 6.424467615822202}
# ap = {'zip': 78757, 'pool': 'Walnut Creek', 'distance': 7.2816924633147355}
# ap = {'zip': 78757, 'pool': 'Parque Zaragoza', 'distance': 10.112272086600676}
# ap = {'zip': 78757, 'pool': 'Patterson', 'distance': 6.36742260579481}
# ap = {'zip': 78757, 'pool': 'Gillis', 'distance': 12.683061988306942}
# ap = {'zip': 78757, 'pool': 'Martin', 'distance': 11.191698786876817}
# ap = {'zip': 78757, 'pool': 'Brentwood', 'distance': 1.2555871265860175}
# ap = {'zip': 78757, 'pool': 'Dottie Jordan', 'distance': 7.024744526608946}
# ap = {'zip': 78757, 'pool': 'Deep Eddy', 'distance': 9.094178736036367}
# ap = {'zip': 78757, 'pool': 'Murchison', 'distance': 2.520658669241776}
# ap = {'zip': 78757, 'pool': 'Mabel Davis', 'distance': 14.635023706305683}
# ap = {'zip': 78757, 'pool': 'Garrison', 'distance': 16.793066644168114}
# ap = {'zip': 78757, 'pool': 'Rosewood', 'distance': 9.100873974539885}
# ap = {'zip': 78757, 'pool': 'Westenfield', 'distance': 7.88008402694482}
# ap = {'zip': 78757, 'pool': 'Stacy Wading', 'distance': 12.325072225829757}
# ap = {'zip': 78757, 'pool': 'Barton Springs', 'distance': 10.129350601099006}
# ap = {'zip': 78757, 'pool': 'Dittmar', 'distance': 19.5798290874281}
# ap = {'zip': 78757, 'pool': 'Govalle', 'distance': 11.036637159426013}
# ap = {'zip': 78757, 'pool': 'Stacy', 'distance': 12.532718130554661}
# ap = {'zip': 78757, 'pool': 'Dick Nichols', 'distance': 19.718907411907104}
# ap = {'zip': 78757, 'pool': 'Givens', 'distance': 9.08035178854802}
# ap = {'zip': 78757, 'pool': 'Ramsey', 'distance': 4.5453221242162}
# ap = {'zip': 78757, 'pool': 'Northwest', 'distance': 0.771881620288865}
# ap = {'zip': 78757, 'pool': 'Springwoods', 'distance': 13.67872960975969}
# ap = {'zip': 78757, 'pool': 'Dove Springs', 'distance': 18.18683071213307}
# ap = {'zip': 78757, 'pool': 'Shipe', 'distance': 5.0009471931116245}
# ap = {'zip': 78757, 'pool': 'Balcones', 'distance': 6.964985608404345}
# ap = {'zip': 78757, 'pool': 'West Austin', 'distance': 8.578499141355902}
# ap = {'zip': 78757, 'pool': 'Reed', 'distance': 6.52850664128163}
# ap = {'zip': 78757, 'pool': 'Civitan', 'distance': 13.3352635309744}
# ap = {'zip': 78758, 'pool': 'Metz', 'distance': 15.084342139463008}
# ap = {'zip': 78758, 'pool': 'Montopolis', 'distance': 17.367233167860874}
# ap = {'zip': 78758, 'pool': 'Canyon Vista', 'distance': 8.641819786148922}
# ap = {'zip': 78758, 'pool': 'Kennemer', 'distance': 3.028554532811042}
# ap = {'zip': 78758, 'pool': 'Bartholomew', 'distance': 9.560696746968489}
# ap = {'zip': 78758, 'pool': 'Walnut Creek', 'distance': 2.8681765534057906}
# ap = {'zip': 78758, 'pool': 'Parque Zaragoza', 'distance': 13.999925843295722}
# ap = {'zip': 78758, 'pool': 'Patterson', 'distance': 10.1861334801147}
# ap = {'zip': 78758, 'pool': 'Gillis', 'distance': 17.216340539323614}
# ap = {'zip': 78758, 'pool': 'Martin', 'distance': 15.416382136758545}
# ap = {'zip': 78758, 'pool': 'Brentwood', 'distance': 5.748974824190304}
# ap = {'zip': 78758, 'pool': 'Dottie Jordan', 'distance': 8.797421319976028}
# ap = {'zip': 78758, 'pool': 'Deep Eddy', 'distance': 13.815903766736616}
# ap = {'zip': 78758, 'pool': 'Murchison', 'distance': 6.291540689082626}
# ap = {'zip': 78758, 'pool': 'Mabel Davis', 'distance': 18.966128373818414}
# ap = {'zip': 78758, 'pool': 'Garrison', 'distance': 21.49686621561948}
# ap = {'zip': 78758, 'pool': 'Rosewood', 'distance': 12.988366668951384}
# ap = {'zip': 78758, 'pool': 'Westenfield', 'distance': 12.590356428137152}
# ap = {'zip': 78758, 'pool': 'Stacy Wading', 'distance': 16.728224872278894}
# ap = {'zip': 78758, 'pool': 'Barton Springs', 'distance': 14.805956244738207}
# ap = {'zip': 78758, 'pool': 'Dittmar', 'distance': 24.24034015218779}
# ap = {'zip': 78758, 'pool': 'Govalle', 'distance': 14.43590455685693}
# ap = {'zip': 78758, 'pool': 'Stacy', 'distance': 16.951738499919777}
# ap = {'zip': 78758, 'pool': 'Dick Nichols', 'distance': 24.41833093877542}
# ap = {'zip': 78758, 'pool': 'Givens', 'distance': 12.292318909884893}
# ap = {'zip': 78758, 'pool': 'Ramsey', 'distance': 9.176165079079503}
# ap = {'zip': 78758, 'pool': 'Northwest', 'distance': 5.393593074640888}
# ap = {'zip': 78758, 'pool': 'Springwoods', 'distance': 11.386558216291306}
# ap = {'zip': 78758, 'pool': 'Dove Springs', 'distance': 22.440315592505012}
# ap = {'zip': 78758, 'pool': 'Shipe', 'distance': 9.229979951734233}
# ap = {'zip': 78758, 'pool': 'Balcones', 'distance': 3.1293110298352316}
# ap = {'zip': 78758, 'pool': 'West Austin', 'distance': 13.208074600413854}
# ap = {'zip': 78758, 'pool': 'Reed', 'distance': 11.263986978398163}
# ap = {'zip': 78758, 'pool': 'Civitan', 'distance': 16.851950079308516}
# ap = {'zip': 78759, 'pool': 'Metz', 'distance': 17.179988011542505}
# ap = {'zip': 78759, 'pool': 'Montopolis', 'distance': 19.895360547077807}
# ap = {'zip': 78759, 'pool': 'Canyon Vista', 'distance': 3.539980916653651}
# ap = {'zip': 78759, 'pool': 'Kennemer', 'distance': 7.008278098604956}
# ap = {'zip': 78759, 'pool': 'Bartholomew', 'distance': 12.714180269983789}
# ap = {'zip': 78759, 'pool': 'Walnut Creek', 'distance': 7.835128941211816}
# ap = {'zip': 78759, 'pool': 'Parque Zaragoza', 'distance': 16.284986085302087}
# ap = {'zip': 78759, 'pool': 'Patterson', 'distance': 12.63075844819798}
# ap = {'zip': 78759, 'pool': 'Gillis', 'distance': 18.113224763193468}
# ap = {'zip': 78759, 'pool': 'Martin', 'distance': 17.116018842434563}
# ap = {'zip': 78759, 'pool': 'Brentwood', 'distance': 7.52044236242944}
# ap = {'zip': 78759, 'pool': 'Dottie Jordan', 'distance': 12.932228239480708}
# ap = {'zip': 78759, 'pool': 'Deep Eddy', 'distance': 13.955656790230423}
# ap = {'zip': 78759, 'pool': 'Murchison', 'distance': 5.488115422612654}
# ap = {'zip': 78759, 'pool': 'Mabel Davis', 'distance': 20.3605867322449}
# ap = {'zip': 78759, 'pool': 'Garrison', 'distance': 21.459671131941484}
# ap = {'zip': 78759, 'pool': 'Rosewood', 'distance': 15.291196536635162}
# ap = {'zip': 78759, 'pool': 'Westenfield', 'distance': 12.925955940948306}
# ap = {'zip': 78759, 'pool': 'Stacy Wading', 'distance': 18.00463318960107}
# ap = {'zip': 78759, 'pool': 'Barton Springs', 'distance': 15.217342905031062}
# ap = {'zip': 78759, 'pool': 'Dittmar', 'distance': 24.426245597642776}
# ap = {'zip': 78759, 'pool': 'Govalle', 'distance': 17.329203990446015}
# ap = {'zip': 78759, 'pool': 'Stacy', 'distance': 18.181998575955152}
# ap = {'zip': 78759, 'pool': 'Dick Nichols', 'distance': 23.076434194345715}
# ap = {'zip': 78759, 'pool': 'Givens', 'distance': 15.387042955093902}
# ap = {'zip': 78759, 'pool': 'Ramsey', 'distance': 10.2313979994992}
# ap = {'zip': 78759, 'pool': 'Northwest', 'distance': 6.33432249806996}
# ap = {'zip': 78759, 'pool': 'Springwoods', 'distance': 7.4176655142961545}
# ap = {'zip': 78759, 'pool': 'Dove Springs', 'distance': 23.949570242159975}
# ap = {'zip': 78759, 'pool': 'Shipe', 'distance': 11.142393504639804}
# ap = {'zip': 78759, 'pool': 'Balcones', 'distance': 4.034863924042677}
# ap = {'zip': 78759, 'pool': 'West Austin', 'distance': 13.936265572790637}
# ap = {'zip': 78759, 'pool': 'Reed', 'distance': 11.113898846737035}
# ap = {'zip': 78759, 'pool': 'Civitan', 'distance': 19.59510642691666}
#       zip             pool   distance
# 31  78701      West Austin   1.607251
# 6   78702  Parque Zaragoza   0.168510
# 17  78703      Westenfield   0.848818
# 8   78704           Gillis   0.734390
# 29  78705            Shipe   1.769221
# 31  78712      West Austin   2.301549
# 27  78717      Springwoods   3.798111
# 28  78719     Dove Springs   8.147567
# 24  78721           Givens   1.143478
# 7   78722        Patterson   0.739031
# 4   78723      Bartholomew   1.142250
# 11  78724    Dottie Jordan   6.105106
# 33  78725          Civitan   7.980237
# 2   78726     Canyon Vista   5.507843
# 30  78727         Balcones   1.820022
# 30  78728         Balcones   5.643365
# 27  78729      Springwoods   2.734333
# 13  78730        Murchison   7.649753
# 13  78731        Murchison   1.150395
# 2   78732     Canyon Vista  11.687588
# 32  78733             Reed  10.345357
# 2   78734     Canyon Vista  16.714405
# 23  78735     Dick Nichols   5.683519
# 23  78736     Dick Nichols  10.568972
# 23  78737     Dick Nichols   9.736027
# 23  78738     Dick Nichols  14.782299
# 23  78739     Dick Nichols   4.726786
# 1   78741       Montopolis   1.445724
# 33  78742          Civitan   3.279002
# 28  78744     Dove Springs   1.130993
# 15  78745         Garrison   0.800950
# 32  78746             Reed   3.862507
# 28  78747     Dove Springs   6.849550
# 20  78748          Dittmar   3.122580
# 23  78749     Dick Nichols   0.505727
# 2   78750     Canyon Vista   1.967804
# 29  78751            Shipe   0.609528
# 10  78752        Brentwood   2.683783
# 5   78753     Walnut Creek   1.909593
# 11  78754    Dottie Jordan   5.362139
# 25  78756           Ramsey   1.206782
# 26  78757        Northwest   0.771882
# 5   78758     Walnut Creek   2.868177
# 2   78759     Canyon Vista   3.539981

# %%
austx_zr
# Out:
#       zip       lat       lng    city state_id  population  rent3br  rent4br  \
# 0   78701  30.27049 -97.74235  Austin       TX        9427     2770     3310
# 1   78702  30.26327 -97.71432  Austin       TX       23389     1790     2140
# 2   78703  30.29409 -97.76571  Austin       TX       20890     2020     2420
# 3   78704  30.24315 -97.76537  Austin       TX       48486     2170     2590
# 4   78705  30.29437 -97.73855  Austin       TX       33948     2450     2920
# 5   78712  30.28502 -97.73477  Austin       TX         860     2460     2930
# 6   78717  30.48988 -97.75371  Austin       TX       30218     2000     2390
# 7   78719  30.14483 -97.67083  Austin       TX        1815     1590     1920
# 8   78721  30.27005 -97.68365  Austin       TX       12492     1620     1940
# 9   78722  30.28997 -97.71465  Austin       TX        7110     2020     2420
# 10  78723  30.30427 -97.68570  Austin       TX       34569     1590     1920
# 11  78724  30.29440 -97.61415  Austin       TX       24779     1770     2110
# 12  78725  30.23581 -97.60837  Austin       TX        7886     2190     2620
# 13  78726  30.42949 -97.84207  Austin       TX       13867     1800     2150
# 14  78727  30.42950 -97.71741  Austin       TX       29509     2140     2550
# 15  78728  30.45655 -97.68986  Austin       TX       21480     1800     2150
# 16  78729  30.45842 -97.75595  Austin       TX       29315     2010     2400
# 17  78730  30.36489 -97.83731  Austin       TX        9186     2020     2420
# 18  78731  30.34736 -97.76847  Austin       TX       27175     1980     2370
# 19  78732  30.37912 -97.89310  Austin       TX       17849     2440     2910
# 20  78733  30.32323 -97.87609  Austin       TX        8611     2590     3090
# 21  78734  30.37853 -97.94961  Austin       TX       18745     2680     3200
# 22  78735  30.26590 -97.86658  Austin       TX       17923     2190     2620
# 23  78736  30.26110 -97.95944  Austin       TX        9047     2110     2520
# 24  78737  30.18779 -97.95966  Austin       TX       16160     2770     3310
# 25  78738  30.31942 -97.95838  Austin       TX       15589     2320     2770
# 26  78739  30.17845 -97.88869  Austin       TX       20312     2770     3310
# 27  78741  30.23049 -97.71401  Austin       TX       52716     1640     1950
# 28  78742  30.24413 -97.65830  Austin       TX         828     1650     1970
# 29  78744  30.18277 -97.72920  Austin       TX       48969     1690     2020
# 30  78745  30.20685 -97.79738  Austin       TX       62771     1930     2310
# 31  78746  30.29729 -97.81054  Austin       TX       28495     2410     2880
# 32  78747  30.12653 -97.74017  Austin       TX       20166     2170     2590
# 33  78748  30.16538 -97.82343  Austin       TX       50997     1960     2340
# 34  78749  30.21376 -97.85821  Austin       TX       37774     2140     2550
# 35  78750  30.41828 -97.80246  Austin       TX       30847     1950     2320
# 36  78751  30.31082 -97.72274  Austin       TX       15805     2260     2690
# 37  78752  30.33180 -97.70426  Austin       TX       21324     1600     1920
# 38  78753  30.38204 -97.67361  Austin       TX       59085     1660     1990
# 39  78754  30.35575 -97.64482  Austin       TX       24408     1870     2230
# 40  78756  30.32227 -97.74017  Austin       TX        8323     1950     2320
# 41  78757  30.35158 -97.73252  Austin       TX       24823     1830     2190
# 42  78758  30.38799 -97.70684  Austin       TX       47470     1780     2120
# 43  78759  30.40268 -97.76105  Austin       TX       42524     2050     2450
#
#     bdgt3br  isAffordable  rentscore
# 0      -610         False  -0.616438
# 1       370          True   0.726027
# 2       140          True   0.410959
# 3       -10          True   0.205479
# 4      -290         False  -0.178082
# 5      -300         False  -0.191781
# 6       160          True   0.438356
# 7       570          True   1.000000
# 8       540          True   0.958904
# 9       140          True   0.410959
# 10      570          True   1.000000
# 11      390          True   0.753425
# 12      -30          True   0.178082
# 13      360          True   0.712329
# 14       20          True   0.246575
# 15      360          True   0.712329
# 16      150          True   0.424658
# 17      140          True   0.410959
# 18      180          True   0.465753
# 19     -280         False  -0.164384
# 20     -430         False  -0.369863
# 21     -520         False  -0.493151
# 22      -30          True   0.178082
# 23       50          True   0.287671
# 24     -610         False  -0.616438
# 25     -160          True   0.000000
# 26     -610         False  -0.616438
# 27      520          True   0.931507
# 28      510          True   0.917808
# 29      470          True   0.863014
# 30      230          True   0.534247
# 31     -250         False  -0.123288
# 32      -10          True   0.205479
# 33      200          True   0.493151
# 34       20          True   0.246575
# 35      210          True   0.506849
# 36     -100          True   0.082192
# 37      560          True   0.986301
# 38      500          True   0.904110
# 39      290          True   0.616438
# 40      210          True   0.506849
# 41      330          True   0.671233
# 42      380          True   0.739726
# 43      110          True   0.369863

# %% [markdown]
# So now I will join the pool info into the main zip dataframe and we'll flag places more than 10 miles from the nearest pool.  For the remainder I'll make a scoring metric much like the rentscore.

# %%
austx_zrp = austx_zr.merge(pooldist, on='zip',how='left')
austx_zrp
# Out:
#       zip       lat       lng    city state_id  population  rent3br  rent4br  \
# 0   78701  30.27049 -97.74235  Austin       TX        9427     2770     3310
# 1   78702  30.26327 -97.71432  Austin       TX       23389     1790     2140
# 2   78703  30.29409 -97.76571  Austin       TX       20890     2020     2420
# 3   78704  30.24315 -97.76537  Austin       TX       48486     2170     2590
# 4   78705  30.29437 -97.73855  Austin       TX       33948     2450     2920
# 5   78712  30.28502 -97.73477  Austin       TX         860     2460     2930
# 6   78717  30.48988 -97.75371  Austin       TX       30218     2000     2390
# 7   78719  30.14483 -97.67083  Austin       TX        1815     1590     1920
# 8   78721  30.27005 -97.68365  Austin       TX       12492     1620     1940
# 9   78722  30.28997 -97.71465  Austin       TX        7110     2020     2420
# 10  78723  30.30427 -97.68570  Austin       TX       34569     1590     1920
# 11  78724  30.29440 -97.61415  Austin       TX       24779     1770     2110
# 12  78725  30.23581 -97.60837  Austin       TX        7886     2190     2620
# 13  78726  30.42949 -97.84207  Austin       TX       13867     1800     2150
# 14  78727  30.42950 -97.71741  Austin       TX       29509     2140     2550
# 15  78728  30.45655 -97.68986  Austin       TX       21480     1800     2150
# 16  78729  30.45842 -97.75595  Austin       TX       29315     2010     2400
# 17  78730  30.36489 -97.83731  Austin       TX        9186     2020     2420
# 18  78731  30.34736 -97.76847  Austin       TX       27175     1980     2370
# 19  78732  30.37912 -97.89310  Austin       TX       17849     2440     2910
# 20  78733  30.32323 -97.87609  Austin       TX        8611     2590     3090
# 21  78734  30.37853 -97.94961  Austin       TX       18745     2680     3200
# 22  78735  30.26590 -97.86658  Austin       TX       17923     2190     2620
# 23  78736  30.26110 -97.95944  Austin       TX        9047     2110     2520
# 24  78737  30.18779 -97.95966  Austin       TX       16160     2770     3310
# 25  78738  30.31942 -97.95838  Austin       TX       15589     2320     2770
# 26  78739  30.17845 -97.88869  Austin       TX       20312     2770     3310
# 27  78741  30.23049 -97.71401  Austin       TX       52716     1640     1950
# 28  78742  30.24413 -97.65830  Austin       TX         828     1650     1970
# 29  78744  30.18277 -97.72920  Austin       TX       48969     1690     2020
# 30  78745  30.20685 -97.79738  Austin       TX       62771     1930     2310
# 31  78746  30.29729 -97.81054  Austin       TX       28495     2410     2880
# 32  78747  30.12653 -97.74017  Austin       TX       20166     2170     2590
# 33  78748  30.16538 -97.82343  Austin       TX       50997     1960     2340
# 34  78749  30.21376 -97.85821  Austin       TX       37774     2140     2550
# 35  78750  30.41828 -97.80246  Austin       TX       30847     1950     2320
# 36  78751  30.31082 -97.72274  Austin       TX       15805     2260     2690
# 37  78752  30.33180 -97.70426  Austin       TX       21324     1600     1920
# 38  78753  30.38204 -97.67361  Austin       TX       59085     1660     1990
# 39  78754  30.35575 -97.64482  Austin       TX       24408     1870     2230
# 40  78756  30.32227 -97.74017  Austin       TX        8323     1950     2320
# 41  78757  30.35158 -97.73252  Austin       TX       24823     1830     2190
# 42  78758  30.38799 -97.70684  Austin       TX       47470     1780     2120
# 43  78759  30.40268 -97.76105  Austin       TX       42524     2050     2450
#
#     bdgt3br  isAffordable  rentscore             pool   distance
# 0      -610         False  -0.616438      West Austin   1.607251
# 1       370          True   0.726027  Parque Zaragoza   0.168510
# 2       140          True   0.410959      Westenfield   0.848818
# 3       -10          True   0.205479           Gillis   0.734390
# 4      -290         False  -0.178082            Shipe   1.769221
# 5      -300         False  -0.191781      West Austin   2.301549
# 6       160          True   0.438356      Springwoods   3.798111
# 7       570          True   1.000000     Dove Springs   8.147567
# 8       540          True   0.958904           Givens   1.143478
# 9       140          True   0.410959        Patterson   0.739031
# 10      570          True   1.000000      Bartholomew   1.142250
# 11      390          True   0.753425    Dottie Jordan   6.105106
# 12      -30          True   0.178082          Civitan   7.980237
# 13      360          True   0.712329     Canyon Vista   5.507843
# 14       20          True   0.246575         Balcones   1.820022
# 15      360          True   0.712329         Balcones   5.643365
# 16      150          True   0.424658      Springwoods   2.734333
# 17      140          True   0.410959        Murchison   7.649753
# 18      180          True   0.465753        Murchison   1.150395
# 19     -280         False  -0.164384     Canyon Vista  11.687588
# 20     -430         False  -0.369863             Reed  10.345357
# 21     -520         False  -0.493151     Canyon Vista  16.714405
# 22      -30          True   0.178082     Dick Nichols   5.683519
# 23       50          True   0.287671     Dick Nichols  10.568972
# 24     -610         False  -0.616438     Dick Nichols   9.736027
# 25     -160          True   0.000000     Dick Nichols  14.782299
# 26     -610         False  -0.616438     Dick Nichols   4.726786
# 27      520          True   0.931507       Montopolis   1.445724
# 28      510          True   0.917808          Civitan   3.279002
# 29      470          True   0.863014     Dove Springs   1.130993
# 30      230          True   0.534247         Garrison   0.800950
# 31     -250         False  -0.123288             Reed   3.862507
# 32      -10          True   0.205479     Dove Springs   6.849550
# 33      200          True   0.493151          Dittmar   3.122580
# 34       20          True   0.246575     Dick Nichols   0.505727
# 35      210          True   0.506849     Canyon Vista   1.967804
# 36     -100          True   0.082192            Shipe   0.609528
# 37      560          True   0.986301        Brentwood   2.683783
# 38      500          True   0.904110     Walnut Creek   1.909593
# 39      290          True   0.616438    Dottie Jordan   5.362139
# 40      210          True   0.506849           Ramsey   1.206782
# 41      330          True   0.671233        Northwest   0.771882
# 42      380          True   0.739726     Walnut Creek   2.868177
# 43      110          True   0.369863     Canyon Vista   3.539981

# %%
austx_zrp['nearPool'] = austx_zrp['distance'] < 10.0

# %%
austx_zrp
# Out:
#       zip       lat       lng    city state_id  population  rent3br  rent4br  \
# 0   78701  30.27049 -97.74235  Austin       TX        9427     2770     3310
# 1   78702  30.26327 -97.71432  Austin       TX       23389     1790     2140
# 2   78703  30.29409 -97.76571  Austin       TX       20890     2020     2420
# 3   78704  30.24315 -97.76537  Austin       TX       48486     2170     2590
# 4   78705  30.29437 -97.73855  Austin       TX       33948     2450     2920
# 5   78712  30.28502 -97.73477  Austin       TX         860     2460     2930
# 6   78717  30.48988 -97.75371  Austin       TX       30218     2000     2390
# 7   78719  30.14483 -97.67083  Austin       TX        1815     1590     1920
# 8   78721  30.27005 -97.68365  Austin       TX       12492     1620     1940
# 9   78722  30.28997 -97.71465  Austin       TX        7110     2020     2420
# 10  78723  30.30427 -97.68570  Austin       TX       34569     1590     1920
# 11  78724  30.29440 -97.61415  Austin       TX       24779     1770     2110
# 12  78725  30.23581 -97.60837  Austin       TX        7886     2190     2620
# 13  78726  30.42949 -97.84207  Austin       TX       13867     1800     2150
# 14  78727  30.42950 -97.71741  Austin       TX       29509     2140     2550
# 15  78728  30.45655 -97.68986  Austin       TX       21480     1800     2150
# 16  78729  30.45842 -97.75595  Austin       TX       29315     2010     2400
# 17  78730  30.36489 -97.83731  Austin       TX        9186     2020     2420
# 18  78731  30.34736 -97.76847  Austin       TX       27175     1980     2370
# 19  78732  30.37912 -97.89310  Austin       TX       17849     2440     2910
# 20  78733  30.32323 -97.87609  Austin       TX        8611     2590     3090
# 21  78734  30.37853 -97.94961  Austin       TX       18745     2680     3200
# 22  78735  30.26590 -97.86658  Austin       TX       17923     2190     2620
# 23  78736  30.26110 -97.95944  Austin       TX        9047     2110     2520
# 24  78737  30.18779 -97.95966  Austin       TX       16160     2770     3310
# 25  78738  30.31942 -97.95838  Austin       TX       15589     2320     2770
# 26  78739  30.17845 -97.88869  Austin       TX       20312     2770     3310
# 27  78741  30.23049 -97.71401  Austin       TX       52716     1640     1950
# 28  78742  30.24413 -97.65830  Austin       TX         828     1650     1970
# 29  78744  30.18277 -97.72920  Austin       TX       48969     1690     2020
# 30  78745  30.20685 -97.79738  Austin       TX       62771     1930     2310
# 31  78746  30.29729 -97.81054  Austin       TX       28495     2410     2880
# 32  78747  30.12653 -97.74017  Austin       TX       20166     2170     2590
# 33  78748  30.16538 -97.82343  Austin       TX       50997     1960     2340
# 34  78749  30.21376 -97.85821  Austin       TX       37774     2140     2550
# 35  78750  30.41828 -97.80246  Austin       TX       30847     1950     2320
# 36  78751  30.31082 -97.72274  Austin       TX       15805     2260     2690
# 37  78752  30.33180 -97.70426  Austin       TX       21324     1600     1920
# 38  78753  30.38204 -97.67361  Austin       TX       59085     1660     1990
# 39  78754  30.35575 -97.64482  Austin       TX       24408     1870     2230
# 40  78756  30.32227 -97.74017  Austin       TX        8323     1950     2320
# 41  78757  30.35158 -97.73252  Austin       TX       24823     1830     2190
# 42  78758  30.38799 -97.70684  Austin       TX       47470     1780     2120
# 43  78759  30.40268 -97.76105  Austin       TX       42524     2050     2450
#
#     bdgt3br  isAffordable  rentscore             pool   distance  nearPool
# 0      -610         False  -0.616438      West Austin   1.607251      True
# 1       370          True   0.726027  Parque Zaragoza   0.168510      True
# 2       140          True   0.410959      Westenfield   0.848818      True
# 3       -10          True   0.205479           Gillis   0.734390      True
# 4      -290         False  -0.178082            Shipe   1.769221      True
# 5      -300         False  -0.191781      West Austin   2.301549      True
# 6       160          True   0.438356      Springwoods   3.798111      True
# 7       570          True   1.000000     Dove Springs   8.147567      True
# 8       540          True   0.958904           Givens   1.143478      True
# 9       140          True   0.410959        Patterson   0.739031      True
# 10      570          True   1.000000      Bartholomew   1.142250      True
# 11      390          True   0.753425    Dottie Jordan   6.105106      True
# 12      -30          True   0.178082          Civitan   7.980237      True
# 13      360          True   0.712329     Canyon Vista   5.507843      True
# 14       20          True   0.246575         Balcones   1.820022      True
# 15      360          True   0.712329         Balcones   5.643365      True
# 16      150          True   0.424658      Springwoods   2.734333      True
# 17      140          True   0.410959        Murchison   7.649753      True
# 18      180          True   0.465753        Murchison   1.150395      True
# 19     -280         False  -0.164384     Canyon Vista  11.687588     False
# 20     -430         False  -0.369863             Reed  10.345357     False
# 21     -520         False  -0.493151     Canyon Vista  16.714405     False
# 22      -30          True   0.178082     Dick Nichols   5.683519      True
# 23       50          True   0.287671     Dick Nichols  10.568972     False
# 24     -610         False  -0.616438     Dick Nichols   9.736027      True
# 25     -160          True   0.000000     Dick Nichols  14.782299     False
# 26     -610         False  -0.616438     Dick Nichols   4.726786      True
# 27      520          True   0.931507       Montopolis   1.445724      True
# 28      510          True   0.917808          Civitan   3.279002      True
# 29      470          True   0.863014     Dove Springs   1.130993      True
# 30      230          True   0.534247         Garrison   0.800950      True
# 31     -250         False  -0.123288             Reed   3.862507      True
# 32      -10          True   0.205479     Dove Springs   6.849550      True
# 33      200          True   0.493151          Dittmar   3.122580      True
# 34       20          True   0.246575     Dick Nichols   0.505727      True
# 35      210          True   0.506849     Canyon Vista   1.967804      True
# 36     -100          True   0.082192            Shipe   0.609528      True
# 37      560          True   0.986301        Brentwood   2.683783      True
# 38      500          True   0.904110     Walnut Creek   1.909593      True
# 39      290          True   0.616438    Dottie Jordan   5.362139      True
# 40      210          True   0.506849           Ramsey   1.206782      True
# 41      330          True   0.671233        Northwest   0.771882      True
# 42      380          True   0.739726     Walnut Creek   2.868177      True
# 43      110          True   0.369863     Canyon Vista   3.539981      True

# %%
maxpdist = austx_zrp.loc[austx_zrp['nearPool'] == True]['distance'].max()
minpdist = austx_zrp.loc[austx_zrp['nearPool'] == True]['distance'].min()
print('min: {}, max: {}'.format(maxpdist, minpdist))
# Out:
# min: 9.736026545708985, max: 0.16851017556696285

# %%
austx_zrp['poolscore'] = 1 - (austx_zrp['distance'] - minpdist)/ (maxpdist - minpdist)
austx_zrp.head()
# Out:
#      zip       lat       lng    city state_id  population  rent3br  rent4br  \
# 0  78701  30.27049 -97.74235  Austin       TX        9427     2770     3310
# 1  78702  30.26327 -97.71432  Austin       TX       23389     1790     2140
# 2  78703  30.29409 -97.76571  Austin       TX       20890     2020     2420
# 3  78704  30.24315 -97.76537  Austin       TX       48486     2170     2590
# 4  78705  30.29437 -97.73855  Austin       TX       33948     2450     2920
#
#    bdgt3br  isAffordable  rentscore             pool  distance  nearPool  \
# 0     -610         False  -0.616438      West Austin  1.607251      True
# 1      370          True   0.726027  Parque Zaragoza  0.168510      True
# 2      140          True   0.410959      Westenfield  0.848818      True
# 3      -10          True   0.205479           Gillis  0.734390      True
# 4     -290         False  -0.178082            Shipe  1.769221      True
#
#    poolscore
# 0   0.849622
# 1   1.000000
# 2   0.928894
# 3   0.940854
# 4   0.832693

# %% [markdown]
# This should be enough for us to use later for overall scoring. We can exclude places where !isAffordable and !nearPool and use the scores to figure out the better candidate places.

# %%
#visualization of areas with better pool proximity
poolmap = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, zipcode,poolscore, nearp in builtins.zip(austx_zrp['lat'], austx_zrp['lng'], austx_zrp['zip'], austx_zrp['poolscore'],austx_zrp['nearPool']):
    label = str(zipcode)+ '\nTS:'+str(int(tsr))
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=3+10*poolscore, # should produce a 3-10 scale for the markers
        popup=label,
        color=('red','purple')[nearp],
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(poolmap)  
    
poolmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Third criteria: Transit for wife.
# My wife prefers to avoid driving (especially in Austin traffic!) and relies on public transportation whenever possible. Thankfully, the site WalkScore.com offers metrics for this, and allows up to 5000 queries daily for free:
#
# https://www.walkscore.com/professional/public-transit-api.php
#
# Their service takes a latitude, a longitude, and a city, state and returns a 0-100 transit_score for each location. This can be used to find places that have the best transit scores for her ease of travel.
#
# We can reduce the number of calls needed by filtering out the places already eliminated for affordability and pool distance.
#
# Here's an example URL for a transitscore:
# https://transit.walkscore.com/transit/score/?lat=47.6101359&lon=-122.3420567&city=Seattle&state=WA&wsapikey=your_key
#
# My key from Walk Score is set in the next (hidden) cell...

# %%
# @hidden_cell
mywskey = '20b43588f707d2a8ac971c5d423c2350'

# %%
def transitstring(lat,long):
    return "lat={}&lon={}&city=Austin&state=TX&wsapikey={}".format(lat,long,mywskey)

# %% [markdown]
# I'll test one call, and then write a loop to take each zip and get the transit score for it. We'll just set the score to zero for excluded places since it's irrelevant how their transit is to us, and it will economize on the calls I make.

# %%
test_lat = 30.27049
test_long=-97.74235
url = ' https://transit.walkscore.com/transit/score/?' + transitstring(test_lat,test_long)

# %%
import requests
results = requests.get(url).json()
results
# Out:
# {'transit_score': 72,
#  'help_link': 'https://www.redfin.com/how-walk-score-works',
#  'summary': '29 nearby routes: 28 bus, 1 rail, 0 other',
#  'logo_url': 'https://cdn.walk.sc/images/transit-score-logo.png',
#  'ws_link': 'https://www.walkscore.com/score/loc/lat=30.2705/lng=-97.7424/?utm_source=mooman.com&utm_medium=ts_api&utm_campaign=ts_api',
#  'description': 'Excellent Transit'}

# %%
results['transit_score']
# Out:
# 72

# %%
for index,zc in austx_zrp.iterrows():
    score = 0
    print('I={}: zip {}, l/l = {},{}'.format(index, zc['zip'],zc['lat'],zc['lng']))
    if zc['isAffordable'] & zc['nearPool']:
        print('Calling transit score API for {}'.format(zc['zip']))
        url = ' https://transit.walkscore.com/transit/score/?' + transitstring(zc['lat'],zc['lng'])
        try:
            results = requests.get(url).json()
            score = results['transit_score']
        except:
            print('ERROR parsing JSON reply')
    else:
        print('Skipping call for {}'.format(zc['zip']))
    austx_zrp.at[index,'transit_score'] = score
# Out:
# I=0: zip 78701, l/l = 30.270490000000002,-97.74235
# Skipping call for 78701
# I=1: zip 78702, l/l = 30.263270000000002,-97.71432
# Calling transit score API for 78702
# I=2: zip 78703, l/l = 30.29409,-97.76571
# Calling transit score API for 78703
# I=3: zip 78704, l/l = 30.24315,-97.76536999999999
# Calling transit score API for 78704
# I=4: zip 78705, l/l = 30.29437,-97.73855
# Skipping call for 78705
# I=5: zip 78712, l/l = 30.285020000000003,-97.73477
# Skipping call for 78712
# I=6: zip 78717, l/l = 30.48988,-97.75371
# Calling transit score API for 78717
# I=7: zip 78719, l/l = 30.14483,-97.67083000000001
# Calling transit score API for 78719
# I=8: zip 78721, l/l = 30.27005,-97.68365
# Calling transit score API for 78721
# I=9: zip 78722, l/l = 30.28997,-97.71465
# Calling transit score API for 78722
# I=10: zip 78723, l/l = 30.304270000000002,-97.6857
# Calling transit score API for 78723
# I=11: zip 78724, l/l = 30.2944,-97.61415
# Calling transit score API for 78724
# I=12: zip 78725, l/l = 30.235809999999997,-97.60837
# Calling transit score API for 78725
# I=13: zip 78726, l/l = 30.42949,-97.84206999999999
# Calling transit score API for 78726
# I=14: zip 78727, l/l = 30.4295,-97.71741
# Calling transit score API for 78727
# I=15: zip 78728, l/l = 30.45655,-97.68986
# Calling transit score API for 78728
# I=16: zip 78729, l/l = 30.45842,-97.75595
# Calling transit score API for 78729
# I=17: zip 78730, l/l = 30.364890000000003,-97.83731
# Calling transit score API for 78730
# I=18: zip 78731, l/l = 30.34736,-97.76847
# Calling transit score API for 78731
# I=19: zip 78732, l/l = 30.37912,-97.8931
# Skipping call for 78732
# I=20: zip 78733, l/l = 30.32323,-97.87609
# Skipping call for 78733
# I=21: zip 78734, l/l = 30.378529999999998,-97.94960999999999
# Skipping call for 78734
# I=22: zip 78735, l/l = 30.2659,-97.86658
# Calling transit score API for 78735
# I=23: zip 78736, l/l = 30.2611,-97.95944
# Skipping call for 78736
# I=24: zip 78737, l/l = 30.187790000000003,-97.95966
# Skipping call for 78737
# I=25: zip 78738, l/l = 30.31942,-97.95838
# Skipping call for 78738
# I=26: zip 78739, l/l = 30.17845,-97.88869
# Skipping call for 78739
# I=27: zip 78741, l/l = 30.230490000000003,-97.71401
# Calling transit score API for 78741
# I=28: zip 78742, l/l = 30.24413,-97.6583
# Calling transit score API for 78742
# I=29: zip 78744, l/l = 30.18277,-97.7292
# Calling transit score API for 78744
# I=30: zip 78745, l/l = 30.20685,-97.79738
# Calling transit score API for 78745
# I=31: zip 78746, l/l = 30.297290000000004,-97.81054
# Skipping call for 78746
# I=32: zip 78747, l/l = 30.12653,-97.74016999999999
# Calling transit score API for 78747
# I=33: zip 78748, l/l = 30.16538,-97.82343
# Calling transit score API for 78748
# I=34: zip 78749, l/l = 30.213759999999997,-97.85821
# Calling transit score API for 78749
# I=35: zip 78750, l/l = 30.41828,-97.80246
# Calling transit score API for 78750
# I=36: zip 78751, l/l = 30.31082,-97.72274
# Calling transit score API for 78751
# I=37: zip 78752, l/l = 30.3318,-97.70425999999999
# Calling transit score API for 78752
# I=38: zip 78753, l/l = 30.382040000000003,-97.67361
# Calling transit score API for 78753
# I=39: zip 78754, l/l = 30.35575,-97.64482
# Calling transit score API for 78754
# I=40: zip 78756, l/l = 30.32227,-97.74016999999999
# Calling transit score API for 78756
# I=41: zip 78757, l/l = 30.35158,-97.73252
# Calling transit score API for 78757
# I=42: zip 78758, l/l = 30.387990000000002,-97.70684
# Calling transit score API for 78758
# I=43: zip 78759, l/l = 30.40268,-97.76105
# Calling transit score API for 78759

# %%
austx_zrp.head(5)
# Out:
#      zip       lat       lng    city state_id  population  rent3br  rent4br  \
# 0  78701  30.27049 -97.74235  Austin       TX        9427     2770     3310
# 1  78702  30.26327 -97.71432  Austin       TX       23389     1790     2140
# 2  78703  30.29409 -97.76571  Austin       TX       20890     2020     2420
# 3  78704  30.24315 -97.76537  Austin       TX       48486     2170     2590
# 4  78705  30.29437 -97.73855  Austin       TX       33948     2450     2920
#
#    bdgt3br  isAffordable  rentscore             pool  distance  nearPool  \
# 0     -610         False  -0.616438      West Austin  1.607251      True
# 1      370          True   0.726027  Parque Zaragoza  0.168510      True
# 2      140          True   0.410959      Westenfield  0.848818      True
# 3      -10          True   0.205479           Gillis  0.734390      True
# 4     -290         False  -0.178082            Shipe  1.769221      True
#
#    poolscore  ts_result  transitscore
# 0   0.849622        0.0      0.000000
# 1   1.000000       52.0      0.866667
# 2   0.928894       32.0      0.533333
# 3   0.940854       52.0      0.866667
# 4   0.832693        0.0      0.000000

# %% [markdown]
# I'll convert these into a normalized feature scale as well, using the same method as before.

# %%
maxts = austx_zrp['transit_score'].max()
mints = austx_zrp['transit_score'].min()
print('min: {}, max: {}'.format(maxts, mints))
# Out:
# min: 60.0, max: 0.0

# %%
austx_zrp['transitscore'] = (austx_zrp['transit_score'] - mints)/ (maxts - mints)
austx_zrp.rename(columns={'transit_score':'ts_result'}, inplace=True)
austx_zrp.head()
# Out:
#      zip       lat       lng    city state_id  population  rent3br  rent4br  \
# 0  78701  30.27049 -97.74235  Austin       TX        9427     2770     3310
# 1  78702  30.26327 -97.71432  Austin       TX       23389     1790     2140
# 2  78703  30.29409 -97.76571  Austin       TX       20890     2020     2420
# 3  78704  30.24315 -97.76537  Austin       TX       48486     2170     2590
# 4  78705  30.29437 -97.73855  Austin       TX       33948     2450     2920
#
#    bdgt3br  isAffordable  rentscore             pool  distance  nearPool  \
# 0     -610         False  -0.616438      West Austin  1.607251      True
# 1      370          True   0.726027  Parque Zaragoza  0.168510      True
# 2      140          True   0.410959      Westenfield  0.848818      True
# 3      -10          True   0.205479           Gillis  0.734390      True
# 4     -290         False  -0.178082            Shipe  1.769221      True
#
#    poolscore  ts_result  transitscore
# 0   0.849622        0.0      0.000000
# 1   1.000000       52.0      0.866667
# 2   0.928894       32.0      0.533333
# 3   0.940854       52.0      0.866667
# 4   0.832693        0.0      0.000000

# %% [markdown]
# Let's do a quick visualization to see where the transit scores are the best around town. Remember that I've excluded expensive places, so there will be some zeros in unexpected places like downtown. I'll scale the dot size to indicate the better scores, and use red to indicate the ones deemed too expensive.

# %%
austsmap = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, zipcode, tsr, transitscore,afford in builtins.zip(austx_zrp['lat'], austx_zrp['lng'], austx_zrp['zip'], austx_zrp['ts_result'],austx_zrp['transitscore'],austx_zrp['isAffordable']):
    label = str(zipcode)+ '\nTS:'+str(int(tsr))
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=2+10*transitscore, # should produce a 2-12 scale for the markers
        popup=label,
        color=('red','green')[afford],
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(austsmap)  
    
austsmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# from this map we can see that North Austin has the best transit overall along with the area immediately south of the river downtown, while still being affordable. The suburbs in general don't appear to have very good transit.

# %% [markdown]
# ## Final Criteria: Bonus points for sushi and pizza!
# All of my family is quite a fan of certain foods, in particular sushi and pizza. Having a home close to such places would be a distinct bonus. So I will query the Foursquare API for Austin specifically looking for locations that have pizza and/or sushi nearby.
#
# I will use a 2km search radius for each zipcode centroid using the 'explore' endpoint, and passing in category ids for 'Sushi Restuarant' (example CA id = 4bf58dd8d48988d1d2941735) and 'Pizza Place' (example CA id = 4bf58dd8d48988d1ca941735) and get a count of how many are near each zip code centroid. This will be scaled using feature scaling to produce 0-1 scores for each, and then since both are important in our family, I will compute the harmonic mean for each zip code, which should promote the places with both, and penalize the places with only one. I may need to renormalize those means depending on the ranges I see after computing the means.

# %% [markdown]
# Procedurally, this will be somewhat different than the prior calls since each zip code will have a variable number of responses and I'll have to *count* the restaurants in the JSON replies, rather than computing distance.

# %%
## setup for Foursquare API calls
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value
RADIUS = 3000
SECTION = 'food' #limit our findings to places to eat
test_lat = 30.27049
test_long = -97.74235
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&radius={}&section={}&limit={}&query'.format(CLIENT_ID, CLIENT_SECRET, test_lat, test_long, MY_TOKEN, VERSION, RADIUS, SECTION, LIMIT)
# my secret key is in the hidden cell that follows

# %%
# @hidden_cell
CLIENT_ID = 'AR2GDRKHV2PFFOQZUPHKYI11OWFLJONZNTBD2KUIIXQEO23N' # your Foursquare ID
CLIENT_SECRET = 'SAYV4MJV4TU3PXJF2DO4JDMQD3DOLJ42FMXCJUYYPKZNXENB' # your Foursquare Secret
MY_TOKEN = 'GKU3M1PGEPCPCIO0KCOPDHZZEFW3THK5STICE5X2XNFLNQ3K'

print('My credentials (partial for security):')
print('CLIENT_ID: ' + CLIENT_ID[:40] + '...')
print('CLIENT_SECRET:' + CLIENT_SECRET[:40] + '...')
print('MY_TOKEN:' + MY_TOKEN[:40] + '...')
# Out:
# My credentials (partial for security):
# CLIENT_ID: AR2GDRKHV2PFFOQZUPHKYI11OWFLJONZNTBD2KUI...
# CLIENT_SECRET:SAYV4MJV4TU3PXJF2DO4JDMQD3DOLJ42FMXCJUYY...
# MY_TOKEN:GKU3M1PGEPCPCIO0KCOPDHZZEFW3THK5STICE5X2...

# %% [markdown]
# Per the Foursquare documentation, these are the specific category IDs for the restuarants of interest:
# **pizza** 4bf58dd8d48988d1ca941735
# **sushi** 4bf58dd8d48988d1d2941735
#
# The API supports a parameter of 'categoryId' with either a single or comma-delimited list of IDs,  so I can make one call for each and parse the results to accumulate the restuarants for each.

# %%
RADIUS = 5000 # 5000 meters ~ 3 miles. This should be a good radius for nearby restaurants
test_lat = 30.40268
test_long = -97.76105
sushipizza = '4bf58dd8d48988d1ca941735,4bf58dd8d48988d1d2941735'
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&radius={}&limit={}&categoryId={}'.format(CLIENT_ID, CLIENT_SECRET, test_lat, test_long, MY_TOKEN, VERSION, RADIUS, LIMIT,sushipizza)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5febb7d6d358eb7aca556826'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'},
#     {'name': '$-$$$$', 'key': 'price'}]},
#   'headerLocation': 'Austin',
#   'headerFullLocation': 'Austin',
#   'headerLocationGranularity': 'city',
#   'query': 'pizza',
#   'totalResults': 51,
#   'suggestedBounds': {'ne': {'lat': 30.447680045000045,
#     'lng': -97.70897284566948},
#    'sw': {'lat': 30.357679954999956, 'lng': -97.81312715433052}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '523b35acbce69c7c875b38cc',
#        'name': 'Pour House Pints & Pies',
#        'location': {'address': '11835 Jollyville Road',
#         'lat': 30.422826069375297,
#         'lng': -97.7552983452688,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.422826069375297,
#           'lng': -97.7552983452688},
#          {'label': 'entrance', 'lat': 30.422861, 'lng': -97.755475}],
#         'distance': 2309,
#         'postalCode': '78759',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['11835 Jollyville Road', 'Austin, TX 78759']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '71979466'}},
#       'referralId': 'e-0-523b35acbce69c7c875b38cc-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ab2c955f964a5205b6c20e3',
#        'name': 'California Pizza Kitchen',
#        'location': {'address': '3401 Esperanza Xing, Spc. E01, The Domain',
#         'crossStreet': 'at Oaks Terrace',
#         'lat': 30.400407,
#         'lng': -97.726967,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.400407,
#           'lng': -97.726967}],
#         'distance': 3282,
#         'postalCode': '78758',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['3401 Esperanza Xing, Spc. E01, The Domain (at Oaks Terrace)',
#          'Austin, TX 78758']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '435166',
#         'url': 'https://www.grubhub.com/restaurant/california-pizza-kitchen-3401-esperanza-xing-spc-e01-austin/435166?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=435166',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ab2c955f964a5205b6c20e3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b734390f964a5201ea52de3',
#        'name': 'North Italia',
#        'location': {'address': '11506 Century Oaks Ter Ste 124',
#         'crossStreet': 'Agave Ln.',
#         'lat': 30.402333927620102,
#         'lng': -97.72587453428201,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.402333927620102,
#           'lng': -97.72587453428201}],
#         'distance': 3377,
#         'postalCode': '78758',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['11506 Century Oaks Ter Ste 124 (Agave Ln.)',
#          'Austin, TX 78758']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1564191',
#         'url': 'https://www.grubhub.com/restaurant/north-italia-11506-century-oaks-terrace-austin/1564191?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1564191',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b734390f964a5201ea52de3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5728ef0f498e5d75bbd319e9',
#        'name': 'Haru',
#        'location': {'address': '9503 Research Blvd',
#         'lat': 30.386704977485962,
#         'lng': -97.74187186437221,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.386704977485962,
#           'lng': -97.74187186437221}],
#         'distance': 2559,
#         'postalCode': '78759',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['9503 Research Blvd', 'Austin, TX 78759']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '883473',
#         'url': 'https://www.grubhub.com/restaurant/haru-sushi-9503-research-blvd-ste-500-austin/883473?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=883473',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5728ef0f498e5d75bbd319e9-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '515f5a74e4b063f828754416',
#        'name': "Marco's Pizza",
#        'location': {'address': '11011 Research Blvd.',
#         'lat': 30.403639000000002,
#         'lng': -97.744732,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.403639000000002,
#           'lng': -97.744732},
#          {'label': 'entrance', 'lat': 30.403708, 'lng': -97.744917}],
#         'distance': 1570,
#         'postalCode': '78759',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['11011 Research Blvd.', 'Austin, TX 78759']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2151092',
#         'url': 'https://www.grubhub.com/restaurant/marcos-pizza-11011-research-blvd-ste-100-austin/2151092?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2151092',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-515f5a74e4b063f828754416-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cc1cfe3bde8f04d235e9a4b',
#        'name': 'Pizza Day',
#        'location': {'address': '10225 Research Blvd',
#         'crossStreet': 'at Great Hills Trl',
#         'lat': 30.394506594843964,
#         'lng': -97.74433235886563,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.394506594843964,
#           'lng': -97.74433235886563}],
#         'distance': 1845,
#         'postalCode': '78759',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['10225 Research Blvd (at Great Hills Trl)',
#          'Austin, TX 78759']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '380860',
#         'url': 'https://www.grubhub.com/restaurant/pizza-day-10225-research-blvd-austin/380860?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=380860',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '403362754'}},
#       'referralId': 'e-0-4cc1cfe3bde8f04d235e9a4b-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '45e6cb42f964a52056431fe3',
#        'name': 'Fujiyama',
#        'location': {'address': '4815 W Braker Ln',
#         'crossStreet': 'btw Research Blvd & Jollyville Rd',
#         'lat': 30.39989833455877,
#         'lng': -97.74847807740201,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.39989833455877,
#           'lng': -97.74847807740201}],
#         'distance': 1246,
#         'postalCode': '78759',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['4815 W Braker Ln (btw Research Blvd & Jollyville Rd)',
#          'Austin, TX 78759']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1558016',
#         'url': 'https://www.grubhub.com/restaurant/fujiyama-japanese-steakhouse-4815-west-braker-lane-austin/1558016?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1558016',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-45e6cb42f964a52056431fe3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cad0e3576d3a0930c28376b',
#        'name': "Papa Murphy's",
#        'location': {'address': '12856 N Highway 183',
#         'crossStreet': 'at Spicewood Springs Rd',
#         'lat': 30.434345791244773,
#         'lng': -97.7725422061863,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.434345791244773,
#           'lng': -97.7725422061863}],
#         'distance': 3693,
#         'postalCode': '78750',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['12856 N Highway 183 (at Spicewood Springs Rd)',
#          'Austin, TX 78750']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cad0e3576d3a0930c28376b-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b8d43bff964a520b9f032e3',
#        'name': "Carrabba's Italian Grill",
#        'location': {'address': '11590 Research Blvd',
#         'lat': 30.4147898,
#         'lng': -97.7470601,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.4147898,
#           'lng': -97.7470601},
#          {'label': 'entrance', 'lat': 30.414884, 'lng': -97.746899}],
#         'distance': 1902,
#         'postalCode': '78759',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['11590 Research Blvd', 'Austin, TX 78759']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1532046',
#         'url': 'https://www.grubhub.com/restaurant/carrabbas-italian-grill-11590-research-blvd-austin/1532046?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1532046',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b8d43bff964a520b9f032e3-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53e54d4f498ec9c3ab459bad',
#        'name': 'Mangia Pizza',
#        'location': {'lat': 30.40746534085846,
#         'lng': -97.71348865101157,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.40746534085846,
#           'lng': -97.71348865101157}],
#         'distance': 4597,
#         'postalCode': '78758',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Austin, TX 78758']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1561031',
#         'url': 'https://www.grubhub.com/restaurant/mangia-pizza-12001-burnet-road-austin/1561031?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1561031',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53e54d4f498ec9c3ab459bad-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '436aa480f964a5209a291fe3',
#        'name': 'Brick Oven Restaurant',
#        'location': {'address': '10710 Research Blvd',
#         'crossStreet': 'Braker Ln',
#         'lat': 30.398890161592604,
#         'lng': -97.74912054174393,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.398890161592604,
#           'lng': -97.74912054174393}],
#         'distance': 1220,
#         'postalCode': '78759',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['10710 Research Blvd (Braker Ln)',
#          'Austin, TX 78759']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-436aa480f964a5209a291fe3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4db49ad1fa8c350240e9009c',
#        'name': "BJ's Restaurant & Brewhouse",
#        'location': {'address': '10515 MoPac Expressway',
#         'lat': 30.3936342,
#         'lng': -97.7314889,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.3936342,
#           'lng': -97.7314889}],
#         'distance': 3011,
#         'postalCode': '78759',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['10515 MoPac Expressway', 'Austin, TX 78759']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '473466',
#         'url': 'https://www.grubhub.com/restaurant/bjs-restaurant--brewhouse-10515-n-mopac-expy-austin/473466?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=473466',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '563869188'}},
#       'referralId': 'e-0-4db49ad1fa8c350240e9009c-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb7f9741261d13a0e2fe898',
#        'name': "Austin's Pizza",
#        'location': {'address': '10900 Research Blvd',
#         'crossStreet': 'Braker',
#         'lat': 30.4019488,
#         'lng': -97.746772,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.4019488,
#           'lng': -97.746772}],
#         'distance': 1373,
#         'postalCode': '78759',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['10900 Research Blvd (Braker)',
#          'Austin, TX 78759']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb7f9741261d13a0e2fe898-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b8da3d6f964a520db0533e3',
#        'name': 'Sushi Zushi',
#        'location': {'address': '3221 Feathergrass Ct',
#         'lat': 30.39497780231956,
#         'lng': -97.72762172567478,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.39497780231956,
#           'lng': -97.72762172567478}],
#         'distance': 3322,
#         'postalCode': '78758',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['3221 Feathergrass Ct', 'Austin, TX 78758']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '536590',
#         'url': 'https://www.grubhub.com/restaurant/sushi-zushi-3221-feathergrass-ct-austin/536590?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=536590',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b8da3d6f964a520db0533e3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aac3415f964a520de5c20e3',
#        'name': 'Buca di Beppo',
#        'location': {'address': '3612 Tudor Blvd',
#         'crossStreet': 'at S Mopac Access Rd',
#         'lat': 30.384572594268864,
#         'lng': -97.7368895803566,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.384572594268864,
#           'lng': -97.7368895803566},
#          {'label': 'entrance', 'lat': 30.384633, 'lng': -97.73762}],
#         'distance': 3073,
#         'postalCode': '78759',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['3612 Tudor Blvd (at S Mopac Access Rd)',
#          'Austin, TX 78759']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '325119',
#         'url': 'https://www.grubhub.com/restaurant/buca-di-beppo-3612-tudor-blvd-austin/325119?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=325119',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4aac3415f964a520de5c20e3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '460d9079f964a5200c451fe3',
#        'name': 'Tomodachi Sushi',
#        'location': {'address': '4101 W Parmer Ln Ste E',
#         'crossStreet': 'at Silver Creek Dr',
#         'lat': 30.4255931493702,
#         'lng': -97.71689383160869,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.4255931493702,
#           'lng': -97.71689383160869}],
#         'distance': 4947,
#         'postalCode': '78727',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['4101 W Parmer Ln Ste E (at Silver Creek Dr)',
#          'Austin, TX 78727']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1545137',
#         'url': 'https://www.grubhub.com/restaurant/tomodachi-sushi-4101-west-parmer-lane-austin/1545137?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1545137',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-460d9079f964a5200c451fe3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a92d67ef964a520db1d20e3',
#        'name': 'Drunk Fish',
#        'location': {'address': '10000 Research Blvd Ste 139',
#         'crossStreet': 'Great Hills Trail',
#         'lat': 30.391092606028952,
#         'lng': -97.74854929246904,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.391092606028952,
#           'lng': -97.74854929246904}],
#         'distance': 1761,
#         'postalCode': '78759',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['10000 Research Blvd Ste 139 (Great Hills Trail)',
#          'Austin, TX 78759']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a92d67ef964a520db1d20e3-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b107debf964a520a17123e3',
#        'name': 'Pizza Hut',
#        'location': {'address': '12636 Research Blvd., #A10-5 / Jollyville',
#         'lat': 30.4304819052505,
#         'lng': -97.7641586427914,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.4304819052505,
#           'lng': -97.7641586427914}],
#         'distance': 3109,
#         'postalCode': '78759',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['12636 Research Blvd., #A10-5 / Jollyville',
#          'Austin, TX 78759']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b107debf964a520a17123e3-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b51f7a4f964a520fd5d27e3',
#        'name': "Papa John's Pizza",
#        'location': {'address': '5114 Balcones Woods Dr Ste 310',
#         'lat': 30.40822977978113,
#         'lng': -97.74730150616892,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.40822977978113,
#           'lng': -97.74730150616892},
#          {'label': 'entrance', 'lat': 30.408083, 'lng': -97.747033}],
#         'distance': 1457,
#         'postalCode': '78759',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['5114 Balcones Woods Dr Ste 310',
#          'Austin, TX 78759']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2413967',
#         'url': 'https://www.grubhub.com/restaurant/papa-johns-pizza-5114-balcones-woods-dr-austin/2413967?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2413967',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b51f7a4f964a520fd5d27e3-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '45e6c9a3f964a52055431fe3',
#        'name': 'Mikado Ryotei',
#        'location': {'address': '9033 Research Blvd',
#         'lat': 30.37343,
#         'lng': -97.72469,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.37343,
#           'lng': -97.72469},
#          {'label': 'entrance', 'lat': 30.373361, 'lng': -97.724749}],
#         'distance': 4774,
#         'postalCode': '78758',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['9033 Research Blvd', 'Austin, TX 78758']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2164835',
#         'url': 'https://www.grubhub.com/restaurant/mikado-ryotei-9033-research-boulevard-austin/2164835?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2164835',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '58480216'}},
#       'referralId': 'e-0-45e6c9a3f964a52055431fe3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54b9cfd1498e5618f8031c48',
#        'name': 'Pacific Rim Sushi & Yakitori Lounge',
#        'location': {'address': '9070 Research Blvd Ste 305',
#         'lat': 30.37189904459804,
#         'lng': -97.72738387128969,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.37189904459804,
#           'lng': -97.72738387128969}],
#         'distance': 4710,
#         'postalCode': '78758',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['9070 Research Blvd Ste 305',
#          'Austin, TX 78758']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '422070822'}},
#       'referralId': 'e-0-54b9cfd1498e5618f8031c48-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '555cc35c498e86f0d9101303',
#        'name': "Double Dave's Pizzaworks",
#        'location': {'address': '8108 Mesa Drive, Ste C 100',
#         'lat': 30.373311334959524,
#         'lng': -97.75659537123538,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.373311334959524,
#           'lng': -97.75659537123538},
#          {'label': 'entrance', 'lat': 30.372998, 'lng': -97.756844}],
#         'distance': 3297,
#         'postalCode': '78759',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['8108 Mesa Drive, Ste C 100',
#          'Austin, TX 78759']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '151876100'}},
#       'referralId': 'e-0-555cc35c498e86f0d9101303-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '40b13b00f964a52065f31ee3',
#        'name': "BB Rover's Cafe & Pub",
#        'location': {'address': '12636 Research Blvd Ste B101',
#         'lat': 30.430803892475545,
#         'lng': -97.76476051905888,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.430803892475545,
#           'lng': -97.76476051905888}],
#         'distance': 3150,
#         'postalCode': '78759',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['12636 Research Blvd Ste B101',
#          'Austin, TX 78759']},
#        'categories': [{'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'shortName': 'Pub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-40b13b00f964a52065f31ee3-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd8d774e914a59342ce54fa',
#        'name': "Newk's Express Cafe",
#        'location': {'address': '9722 Great Hills Trl #130',
#         'crossStreet': 'Corner of Jolleyville Rd and Great Hills Trail',
#         'lat': 30.39508886628646,
#         'lng': -97.75089056838658,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.39508886628646,
#           'lng': -97.75089056838658}],
#         'distance': 1290,
#         'postalCode': '78759',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['9722 Great Hills Trl #130 (Corner of Jolleyville Rd and Great Hills Trail)',
#          'Austin, TX 78759']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '41025939'}},
#       'referralId': 'e-0-4bd8d774e914a59342ce54fa-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba7c724f964a5208bb239e3',
#        'name': "Schlotzsky's",
#        'location': {'address': '5105 Balcones Woods Dr',
#         'lat': 30.407614147722374,
#         'lng': -97.74585855736034,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.407614147722374,
#           'lng': -97.74585855736034},
#          {'label': 'entrance', 'lat': 30.407675, 'lng': -97.745813}],
#         'distance': 1558,
#         'postalCode': '78759',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['5105 Balcones Woods Dr', 'Austin, TX 78759']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1032113',
#         'url': 'https://www.grubhub.com/restaurant/schlotzskys-deli-5105-balcones-woods-dr-austin/1032113?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1032113',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba7c724f964a5208bb239e3-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fb299f6e4b0a8c81131c4fb',
#        'name': 'Blue Baker',
#        'location': {'address': '10000 Research Blvd',
#         'crossStreet': 'Great Hills Trail',
#         'lat': 30.393612769447806,
#         'lng': -97.74767802376137,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.393612769447806,
#           'lng': -97.74767802376137}],
#         'distance': 1633,
#         'postalCode': '78759',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['10000 Research Blvd (Great Hills Trail)',
#          'Austin, TX 78759']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fb299f6e4b0a8c81131c4fb-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dd6fc01ae60680f14fbf5fd',
#        'name': 'The Park at The Domain',
#        'location': {'address': '11601 Domain Dr Ste 200',
#         'crossStreet': 'in the Domain',
#         'lat': 30.40313888349391,
#         'lng': -97.72367017058379,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.40313888349391,
#           'lng': -97.72367017058379},
#          {'label': 'entrance', 'lat': 30.402912, 'lng': -97.723853}],
#         'distance': 3589,
#         'postalCode': '78758',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['11601 Domain Dr Ste 200 (in the Domain)',
#          'Austin, TX 78758']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dd6fc01ae60680f14fbf5fd-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cfd7b19c51fa1cda856f12b',
#        'name': 'Brick House Tavern + Tap',
#        'location': {'address': '11680A Research Blvd,',
#         'lat': 30.41806238136166,
#         'lng': -97.74758763216987,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.41806238136166,
#           'lng': -97.74758763216987}],
#         'distance': 2145,
#         'postalCode': '78759',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['11680A Research Blvd,', 'Austin, TX 78759']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2216001',
#         'url': 'https://www.grubhub.com/restaurant/brick-house-tavern--tap-11680a-research-blvd-austin/2216001?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2216001',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cfd7b19c51fa1cda856f12b-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cd8755e3ec4b1f7f498be3f',
#        'name': "Domino's Pizza",
#        'location': {'address': '8141 Mesa Dr #C',
#         'lat': 30.373775594164876,
#         'lng': -97.75539104642121,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.373775594164876,
#           'lng': -97.75539104642121},
#          {'label': 'entrance', 'lat': 30.37378, 'lng': -97.755488}],
#         'distance': 3263,
#         'postalCode': '78759',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['8141 Mesa Dr #C', 'Austin, TX 78759']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cd8755e3ec4b1f7f498be3f-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '555e2ab0498e9927b93bd41f',
#        'name': 'Flaming Pizza',
#        'location': {'address': '3220 Feathergrass Ct',
#         'lat': 30.396155519737253,
#         'lng': -97.72737147252784,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.396155519737253,
#           'lng': -97.72737147252784},
#          {'label': 'entrance', 'lat': 30.395045, 'lng': -97.72709}],
#         'distance': 3314,
#         'postalCode': '78758',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['3220 Feathergrass Ct', 'Austin, TX 78758']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1160655',
#         'url': 'https://www.grubhub.com/restaurant/flaming-pizza-3220-feathergrass-ct-ste-140-austin/1160655?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1160655',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-555e2ab0498e9927b93bd41f-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a2aff1cf964a52080961fe3',
#        'name': 'Roaring Fork',
#        'location': {'address': '10850 Stonelake Blvd',
#         'crossStreet': 'N Mopac Expwy',
#         'lat': 30.400931931821884,
#         'lng': -97.7378534945488,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.400931931821884,
#           'lng': -97.7378534945488},
#          {'label': 'entrance', 'lat': 30.400721, 'lng': -97.737707}],
#         'distance': 2235,
#         'postalCode': '78759',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['10850 Stonelake Blvd (N Mopac Expwy)',
#          'Austin, TX 78759']},
#        'categories': [{'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'shortName': 'Steakhouse',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '152773321'}},
#       'referralId': 'e-0-4a2aff1cf964a52080961fe3-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5808144138fa82854748bb72',
#        'name': 'i Fratelli',
#        'location': {'lat': 30.39237,
#         'lng': -97.74506,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.39237,
#           'lng': -97.74506}],
#         'distance': 1916,
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Austin, TX']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1551386',
#         'url': 'https://www.grubhub.com/restaurant/i-fratelli-pizza-north-10001-research-boulevard-austin/1551386?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1551386',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5808144138fa82854748bb72-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f320f7219833175d60c8f60',
#        'name': 'Little Caesars Pizza',
#        'location': {'address': '4815 W Braker Ln',
#         'lat': 30.400299072265625,
#         'lng': -97.74784851074219,
#         'labeledLatLngs': [{'label': 'entrance',
#           'lat': 30.400414,
#           'lng': -97.748001},
#          {'label': 'display',
#           'lat': 30.400299072265625,
#           'lng': -97.74784851074219}],
# ...
#       'venue': {'id': '4b999fdcf964a520378835e3',
#        'name': 'Urban an American Grill',
#        'location': {'address': '11301 Domain Dr',
#         'crossStreet': 'at Westin Austin Domain',
#         'lat': 30.399165,
#         'lng': -97.724591,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.399165,
#           'lng': -97.724591}],
#         'distance': 3522,
#         'postalCode': '78758',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['11301 Domain Dr (at Westin Austin Domain)',
#          'Austin, TX 78758']},
#        'categories': [{'id': '4bf58dd8d48988d1d5941735',
#          'name': 'Hotel Bar',
#          'pluralName': 'Hotel Bars',
#          'shortName': 'Hotel Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1559222',
#         'url': 'https://www.grubhub.com/restaurant/urban-11301-domain-drive-austin/1559222?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1559222',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b999fdcf964a520378835e3-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56b933f0498eba5683f6ec13',
#        'name': 'Salvation Pizza - Rock Rose',
#        'location': {'address': '11501 Rock Rose Ave. Suite 146',
#         'lat': 30.4010799018006,
#         'lng': -97.7227822401486,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.4010799018006,
#           'lng': -97.7227822401486}],
#         'distance': 3678,
#         'postalCode': '78758',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['11501 Rock Rose Ave. Suite 146',
#          'Austin, TX 78758']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '347116',
#         'url': 'https://www.grubhub.com/restaurant/salvation-pizza-11501-rock-rose-ave-ste-146-austin/347116?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=347116',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '156084906'}},
#       'referralId': 'e-0-56b933f0498eba5683f6ec13-40'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '588797be51d19e386ddf5d06',
#        'name': 'Taverna Pizzeria & Risotteria',
#        'location': {'address': '3120 Palm Way #160',
#         'lat': 30.40314466985076,
#         'lng': -97.72161968495715,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.40314466985076,
#           'lng': -97.72161968495715}],
#         'distance': 3786,
#         'postalCode': '78758',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['3120 Palm Way #160', 'Austin, TX 78758']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1565861',
#         'url': 'https://www.grubhub.com/restaurant/taverna-3120-palm-way-austin/1565861?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1565861',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-588797be51d19e386ddf5d06-41'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4df8df59aeb70af3f2780f75',
#        'name': 'RedBrickPizza',
#        'location': {'address': '10515 N Mopac Expy',
#         'crossStreet': 'Barker Lane',
#         'lat': 30.38969099521637,
#         'lng': -97.73218631744385,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.38969099521637,
#           'lng': -97.73218631744385}],
#         'distance': 3125,
#         'postalCode': '78759',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['10515 N Mopac Expy (Barker Lane)',
#          'Austin, TX 78759']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4df8df59aeb70af3f2780f75-42'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f32667319836c91c7d416fe',
#        'name': 'VOD',
#        'location': {'address': '4412 Spicewood Springs Rd',
#         'lat': 30.373188,
#         'lng': -97.758459,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.373188,
#           'lng': -97.758459}],
#         'distance': 3292,
#         'postalCode': '78759',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['4412 Spicewood Springs Rd', 'Austin, TX 78759']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f32667319836c91c7d416fe-43'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58dc62cfe6160c0156533cac',
#        'name': '3 Train Pizzeria',
#        'location': {'address': '8127 Mesa Dr Ste B202',
#         'lat': 30.372782,
#         'lng': -97.75605,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.372782,
#           'lng': -97.75605}],
#         'distance': 3362,
#         'postalCode': '78759',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['8127 Mesa Dr Ste B202', 'Austin, TX 78759']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58dc62cfe6160c0156533cac-44'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58f112fce65d0c4b18a7812c',
#        'name': 'Jersey Giant Pizza',
#        'location': {'address': '7318 McNeil Dr',
#         'lat': 30.435627,
#         'lng': -97.76780600000001,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.435627,
#           'lng': -97.76780600000001}],
#         'distance': 3724,
#         'postalCode': '78729',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['7318 McNeil Dr', 'Austin, TX 78729']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1561673',
#         'url': 'https://www.grubhub.com/restaurant/jersey-giant-pizza-7318-mcneil-drive-austin/1561673?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1561673',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58f112fce65d0c4b18a7812c-45'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f32873119836c91c7e098ab',
#        'name': "Mr Gatti's Pizza",
#        'location': {'address': '13058 N Highway 183',
#         'lat': 30.4382225060852,
#         'lng': -97.77974952818735,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.4382225060852,
#           'lng': -97.77974952818735},
#          {'label': 'entrance', 'lat': 30.4384, 'lng': -97.779235}],
#         'distance': 4344,
#         'postalCode': '78750',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['13058 N Highway 183', 'Austin, TX 78750']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f32873119836c91c7e098ab-46'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f439c6819834bc91f57ddd9',
#        'name': "Woody's Pizza and Wings",
#        'location': {'address': '6301 W Parmer Ln',
#         'lat': 30.444839477539062,
#         'lng': -97.74373626708984,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.444839477539062,
#           'lng': -97.74373626708984}],
#         'distance': 4978,
#         'postalCode': '78729',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['6301 W Parmer Ln', 'Austin, TX 78729']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f439c6819834bc91f57ddd9-47'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f32575319836c91c7ce32dc',
#        'name': 'Papa Johns Pizza',
#        'location': {'address': '3918 Far West Blvd',
#         'lat': 30.35788917541504,
#         'lng': -97.76172637939453,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.35788917541504,
#           'lng': -97.76172637939453}],
#         'distance': 4986,
#         'postalCode': '78731',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['3918 Far West Blvd', 'Austin, TX 78731']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f32575319836c91c7ce32dc-48'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5eaf71a3775d4d00082f31a0',
#        'name': 'Aviator Pizza & Drafthouse',
#        'location': {'address': '4005 W Parmer Ln Ste E',
#         'crossStreet': 'Silver Creek Drive',
#         'lat': 30.424989,
#         'lng': -97.715915,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.424989,
#           'lng': -97.715915}],
#         'distance': 4994,
#         'postalCode': '78727',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['4005 W Parmer Ln Ste E (Silver Creek Drive)',
#          'Austin, TX 78727']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2389300',
#         'url': 'https://www.grubhub.com/restaurant/aviator-pizza--drafthouse--parmer-lane-4005-west-parmer-lane-austin/2389300?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2389300',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5eaf71a3775d4d00082f31a0-49'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4babadcdf964a5209bbf3ae3',
#        'name': '7-Eleven',
#        'location': {'address': '9200 Burnet Rd',
#         'lat': 30.3759690135644,
#         'lng': -97.7265737159269,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.3759690135644,
#           'lng': -97.7265737159269}],
#         'distance': 4449,
#         'postalCode': '78758',
#         'cc': 'US',
#         'city': 'Austin',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['9200 Burnet Rd', 'Austin, TX 78758']},
#        'categories': [{'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'shortName': 'Convenience Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4babadcdf964a5209bbf3ae3-50'}]}]}}

# %%
def getSushiPizza(cityzips):
    repizza = '4bf58dd8d48988d1ca941735'
    resushi = '4bf58dd8d48988d1d2941735'
    radius = 5000
    column_names = ['zip', 'pizza', 'sushi'] 
    dl = pd.DataFrame(columns=column_names)
    for zc, lat, lng in builtins.zip(cityzips['zip'],cityzips['lat'], cityzips['lng']):
        #print(zc,lat,lng)
        url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&categoryId={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT,
            '4bf58dd8d48988d1ca941735,4bf58dd8d48988d1d2941735')
        results = requests.get(url).json()
        pizzacount = len(re.findall(repizza, json.dumps(results)))
        sushicount = len(re.findall(resushi, json.dumps(results)))
        print('Found {} pizzas and {} sushis for zipcode {}'.format(pizzacount, sushicount, zc))
        ap = {'zip': zc, 'pizza': pizzacount, 'sushi': sushicount }
        print('ap = {}'.format(ap))
        dl = dl.append(ap, ignore_index=True)
    return dl

# %%
len(results)
# Out:
# 3

# %%
import re
repizza = '4bf58dd8d48988d1ca941735'
resushi = '4bf58dd8d48988d1d2941735'
len(re.findall(resushi, json.dumps(results)))
# Out:
# 8

# %%
type(json.dumps(results))
# Out:
# str

# %%
austx_food = getSushiPizza(austx_zrp)
# Out:
# Found 63 pizzas and 20 sushis for zipcode 78701
# ap = {'zip': 78701, 'pizza': 63, 'sushi': 20}
# Found 66 pizzas and 19 sushis for zipcode 78702
# ap = {'zip': 78702, 'pizza': 66, 'sushi': 19}
# Found 67 pizzas and 21 sushis for zipcode 78703
# ap = {'zip': 78703, 'pizza': 67, 'sushi': 21}
# Found 67 pizzas and 17 sushis for zipcode 78704
# ap = {'zip': 78704, 'pizza': 67, 'sushi': 17}
# Found 63 pizzas and 23 sushis for zipcode 78705
# ap = {'zip': 78705, 'pizza': 63, 'sushi': 23}
# Found 65 pizzas and 21 sushis for zipcode 78712
# ap = {'zip': 78712, 'pizza': 65, 'sushi': 21}
# Found 16 pizzas and 5 sushis for zipcode 78717
# ap = {'zip': 78717, 'pizza': 16, 'sushi': 5}
# Found 1 pizzas and 0 sushis for zipcode 78719
# ap = {'zip': 78719, 'pizza': 1, 'sushi': 0}
# Found 22 pizzas and 3 sushis for zipcode 78721
# ap = {'zip': 78721, 'pizza': 22, 'sushi': 3}
# Found 65 pizzas and 19 sushis for zipcode 78722
# ap = {'zip': 78722, 'pizza': 65, 'sushi': 19}
# Found 26 pizzas and 7 sushis for zipcode 78723
# ap = {'zip': 78723, 'pizza': 26, 'sushi': 7}
# Found 0 pizzas and 0 sushis for zipcode 78724
# ap = {'zip': 78724, 'pizza': 0, 'sushi': 0}
# Found 1 pizzas and 0 sushis for zipcode 78725
# ap = {'zip': 78725, 'pizza': 1, 'sushi': 0}
# Found 14 pizzas and 1 sushis for zipcode 78726
# ap = {'zip': 78726, 'pizza': 14, 'sushi': 1}
# Found 41 pizzas and 7 sushis for zipcode 78727
# ap = {'zip': 78727, 'pizza': 41, 'sushi': 7}
# Found 27 pizzas and 6 sushis for zipcode 78728
# ap = {'zip': 78728, 'pizza': 27, 'sushi': 6}
# Found 33 pizzas and 10 sushis for zipcode 78729
# ap = {'zip': 78729, 'pizza': 33, 'sushi': 10}
# Found 10 pizzas and 1 sushis for zipcode 78730
# ap = {'zip': 78730, 'pizza': 10, 'sushi': 1}
# Found 44 pizzas and 8 sushis for zipcode 78731
# ap = {'zip': 78731, 'pizza': 44, 'sushi': 8}
# Found 5 pizzas and 1 sushis for zipcode 78732
# ap = {'zip': 78732, 'pizza': 5, 'sushi': 1}
# Found 7 pizzas and 0 sushis for zipcode 78733
# ap = {'zip': 78733, 'pizza': 7, 'sushi': 0}
# Found 7 pizzas and 1 sushis for zipcode 78734
# ap = {'zip': 78734, 'pizza': 7, 'sushi': 1}
# Found 14 pizzas and 2 sushis for zipcode 78735
# ap = {'zip': 78735, 'pizza': 14, 'sushi': 2}
# Found 0 pizzas and 0 sushis for zipcode 78736
# ap = {'zip': 78736, 'pizza': 0, 'sushi': 0}
# Found 3 pizzas and 1 sushis for zipcode 78737
# ap = {'zip': 78737, 'pizza': 3, 'sushi': 1}
# Found 18 pizzas and 3 sushis for zipcode 78738
# ap = {'zip': 78738, 'pizza': 18, 'sushi': 3}
# Found 5 pizzas and 1 sushis for zipcode 78739
# ap = {'zip': 78739, 'pizza': 5, 'sushi': 1}
# Found 60 pizzas and 12 sushis for zipcode 78741
# ap = {'zip': 78741, 'pizza': 60, 'sushi': 12}
# Found 7 pizzas and 1 sushis for zipcode 78742
# ap = {'zip': 78742, 'pizza': 7, 'sushi': 1}
# Found 11 pizzas and 1 sushis for zipcode 78744
# ap = {'zip': 78744, 'pizza': 11, 'sushi': 1}
# Found 48 pizzas and 4 sushis for zipcode 78745
# ap = {'zip': 78745, 'pizza': 48, 'sushi': 4}
# Found 19 pizzas and 2 sushis for zipcode 78746
# ap = {'zip': 78746, 'pizza': 19, 'sushi': 2}
# Found 1 pizzas and 0 sushis for zipcode 78747
# ap = {'zip': 78747, 'pizza': 1, 'sushi': 0}
# Found 30 pizzas and 3 sushis for zipcode 78748
# ap = {'zip': 78748, 'pizza': 30, 'sushi': 3}
# Found 28 pizzas and 3 sushis for zipcode 78749
# ap = {'zip': 78749, 'pizza': 28, 'sushi': 3}
# Found 24 pizzas and 4 sushis for zipcode 78750
# ap = {'zip': 78750, 'pizza': 24, 'sushi': 4}
# Found 66 pizzas and 18 sushis for zipcode 78751
# ap = {'zip': 78751, 'pizza': 66, 'sushi': 18}
# Found 49 pizzas and 16 sushis for zipcode 78752
# ap = {'zip': 78752, 'pizza': 49, 'sushi': 16}
# Found 30 pizzas and 5 sushis for zipcode 78753
# ap = {'zip': 78753, 'pizza': 30, 'sushi': 5}
# Found 9 pizzas and 0 sushis for zipcode 78754
# ap = {'zip': 78754, 'pizza': 9, 'sushi': 0}
# Found 66 pizzas and 19 sushis for zipcode 78756
# ap = {'zip': 78756, 'pizza': 66, 'sushi': 19}
# Found 59 pizzas and 19 sushis for zipcode 78757
# ap = {'zip': 78757, 'pizza': 59, 'sushi': 19}
# Found 50 pizzas and 15 sushis for zipcode 78758
# ap = {'zip': 78758, 'pizza': 50, 'sushi': 15}
# Found 31 pizzas and 8 sushis for zipcode 78759
# ap = {'zip': 78759, 'pizza': 31, 'sushi': 8}

# %%
austx_food
# Out:
#       zip pizza sushi
# 0   78701    63    20
# 1   78702    66    19
# 2   78703    67    21
# 3   78704    67    17
# 4   78705    63    23
# 5   78712    65    21
# 6   78717    16     5
# 7   78719     1     0
# 8   78721    22     3
# 9   78722    65    19
# 10  78723    26     7
# 11  78724     0     0
# 12  78725     1     0
# 13  78726    14     1
# 14  78727    41     7
# 15  78728    27     6
# 16  78729    33    10
# 17  78730    10     1
# 18  78731    44     8
# 19  78732     5     1
# 20  78733     7     0
# 21  78734     7     1
# 22  78735    14     2
# 23  78736     0     0
# 24  78737     3     1
# 25  78738    18     3
# 26  78739     5     1
# 27  78741    60    12
# 28  78742     7     1
# 29  78744    11     1
# 30  78745    48     4
# 31  78746    19     2
# 32  78747     1     0
# 33  78748    30     3
# 34  78749    28     3
# 35  78750    24     4
# 36  78751    66    18
# 37  78752    49    16
# 38  78753    30     5
# 39  78754     9     0
# 40  78756    66    19
# 41  78757    59    19
# 42  78758    50    15
# 43  78759    31     8

# %% [markdown]
# Now that I have the counts for pizza and sushi restaurants, I can come up with a score for them.
#
# In this case, an area with 60 pizza places versus 30 pizza places is not a huge gain, as I'm very likely to find decent pizza among those 30. However, single digit places might be a concern.
#
# So for this metric, I will use a natural log function first to rescale the counts (adding a trivial 1 for to each to avoid the error of ln(0)) and then I will do the same normalized feature scaling used for the other scores.

# %%
austx_food['pizza_rescale'] = np.log(austx_food['pizza'].astype(float) + 1)
austx_food.head()
# Out:
#      zip pizza sushi  pizza_rescale
# 0  78701    63    20       4.158883
# 1  78702    66    19       4.204693
# 2  78703    67    21       4.219508
# 3  78704    67    17       4.219508
# 4  78705    63    23       4.158883

# %%
austx_food['sushi_rescale'] = np.log(austx_food['sushi'].astype(float) + 1)
austx_food.head()
# Out:
#      zip pizza sushi  pizza_rescale  sushi_rescale
# 0  78701    63    20       4.158883       3.044522
# 1  78702    66    19       4.204693       2.995732
# 2  78703    67    21       4.219508       3.091042
# 3  78704    67    17       4.219508       2.890372
# 4  78705    63    23       4.158883       3.178054

# %%
austx_food['pizzascore'] = (austx_food['pizza_rescale'] - austx_food['pizza_rescale'].min()) / (austx_food['pizza_rescale'].max() - austx_food['pizza_rescale'].min())
austx_food.head(10)
# Out:
#      zip pizza sushi  pizza_rescale  sushi_rescale  pizzascore
# 0  78701    63    20       4.158883       3.044522    0.985632
# 1  78702    66    19       4.204693       2.995732    0.996489
# 2  78703    67    21       4.219508       3.091042    1.000000
# 3  78704    67    17       4.219508       2.890372    1.000000
# 4  78705    63    23       4.158883       3.178054    0.985632
# 5  78712    65    21       4.189655       3.091042    0.992925
# 6  78717    16     5       2.833213       1.791759    0.671456
# 7  78719     1     0       0.693147       0.000000    0.164272
# 8  78721    22     3       3.135494       1.386294    0.743095
# 9  78722    65    19       4.189655       2.995732    0.992925

# %%
austx_food['sushiscore'] = (austx_food['sushi_rescale'] - austx_food['sushi_rescale'].min()) / (austx_food['sushi_rescale'].max() - austx_food['sushi_rescale'].min())
austx_food.head(10)
# Out:
#      zip pizza sushi  pizza_rescale  sushi_rescale  pizzascore  sushiscore
# 0  78701    63    20       4.158883       3.044522    0.985632    0.957983
# 1  78702    66    19       4.204693       2.995732    0.996489    0.942631
# 2  78703    67    21       4.219508       3.091042    1.000000    0.972621
# 3  78704    67    17       4.219508       2.890372    1.000000    0.909479
# 4  78705    63    23       4.158883       3.178054    0.985632    1.000000
# 5  78712    65    21       4.189655       3.091042    0.992925    0.972621
# 6  78717    16     5       2.833213       1.791759    0.671456    0.563791
# 7  78719     1     0       0.693147       0.000000    0.164272    0.000000
# 8  78721    22     3       3.135494       1.386294    0.743095    0.436209
# 9  78722    65    19       4.189655       2.995732    0.992925    0.942631

# %% [markdown]
# Now, since my family would want #both# kinds of food, I will compute a harmonic mean of those two scores, to give more value to places where both scores are high, and to penalize places where either is low.

# %%
austx_food['foodscore'] = (2 * austx_food['pizzascore'] * austx_food['sushiscore']) / (austx_food['pizzascore'] + austx_food['sushiscore'])

# %%
#fix the few NaN values with zero scores...
austx_food['foodscore'] = austx_food['foodscore'].fillna(0.0)
austx_food
# Out:
#       zip pizza sushi  pizza_rescale  sushi_rescale  pizzascore  sushiscore  \
# 0   78701    63    20       4.158883       3.044522    0.985632    0.957983
# 1   78702    66    19       4.204693       2.995732    0.996489    0.942631
# 2   78703    67    21       4.219508       3.091042    1.000000    0.972621
# 3   78704    67    17       4.219508       2.890372    1.000000    0.909479
# 4   78705    63    23       4.158883       3.178054    0.985632    1.000000
# 5   78712    65    21       4.189655       3.091042    0.992925    0.972621
# 6   78717    16     5       2.833213       1.791759    0.671456    0.563791
# 7   78719     1     0       0.693147       0.000000    0.164272    0.000000
# 8   78721    22     3       3.135494       1.386294    0.743095    0.436209
# 9   78722    65    19       4.189655       2.995732    0.992925    0.942631
# 10  78723    26     7       3.295837       2.079442    0.781095    0.654313
# 11  78724     0     0       0.000000       0.000000    0.000000    0.000000
# 12  78725     1     0       0.693147       0.000000    0.164272    0.000000
# 13  78726    14     1       2.708050       0.693147    0.641793    0.218104
# 14  78727    41     7       3.737670       2.079442    0.885807    0.654313
# 15  78728    27     6       3.332205       1.945910    0.789714    0.612296
# 16  78729    33    10       3.526361       2.397895    0.835728    0.754517
# 17  78730    10     1       2.397895       0.693147    0.568288    0.218104
# 18  78731    44     8       3.806662       2.197225    0.902158    0.691374
# 19  78732     5     1       1.791759       0.693147    0.424637    0.218104
# 20  78733     7     0       2.079442       0.000000    0.492816    0.000000
# 21  78734     7     1       2.079442       0.693147    0.492816    0.218104
# 22  78735    14     2       2.708050       1.098612    0.641793    0.345687
# 23  78736     0     0       0.000000       0.000000    0.000000    0.000000
# 24  78737     3     1       1.386294       0.693147    0.328544    0.218104
# 25  78738    18     3       2.944439       1.386294    0.697816    0.436209
# 26  78739     5     1       1.791759       0.693147    0.424637    0.218104
# 27  78741    60    12       4.110874       2.564949    0.974254    0.807082
# 28  78742     7     1       2.079442       0.693147    0.492816    0.218104
# 29  78744    11     1       2.484907       0.693147    0.588909    0.218104
# 30  78745    48     4       3.891820       1.609438    0.922340    0.506422
# 31  78746    19     2       2.995732       1.098612    0.709972    0.345687
# 32  78747     1     0       0.693147       0.000000    0.164272    0.000000
# 33  78748    30     3       3.433987       1.386294    0.813836    0.436209
# 34  78749    28     3       3.367296       1.386294    0.798030    0.436209
# 35  78750    24     4       3.218876       1.609438    0.762856    0.506422
# 36  78751    66    18       4.204693       2.944439    0.996489    0.926491
# 37  78752    49    16       3.912023       2.833213    0.927128    0.891493
# 38  78753    30     5       3.433987       1.791759    0.813836    0.563791
# 39  78754     9     0       2.302585       0.000000    0.545700    0.000000
# 40  78756    66    19       4.204693       2.995732    0.996489    0.942631
# 41  78757    59    19       4.094345       2.995732    0.970337    0.942631
# 42  78758    50    15       3.931826       2.772589    0.931821    0.872417
# 43  78759    31     8       3.465736       2.197225    0.821360    0.691374
#
#     foodscore
# 0    0.971611
# 1    0.968812
# 2    0.986121
# 3    0.952594
# 4    0.992764
# 5    0.982668
# 6    0.612932
# 7    0.000000
# 8    0.549722
# 9    0.967125
# 10   0.712105
# 11   0.000000
# 12   0.000000
# 13   0.325569
# 14   0.752662
# 15   0.689779
# 16   0.793049
# 17   0.315227
# 18   0.782825
# 19   0.288188
# 20   0.000000
# 21   0.302384
# 22   0.449345
# 23   0.000000
# 24   0.262168
# 25   0.536837
# 26   0.288188
# 27   0.882824
# 28   0.302384
# 29   0.318318
# 30   0.653844
# 31   0.464976
# 32   0.000000
# 33   0.567983
# 34   0.564085
# 35   0.608735
# 36   0.960216
# 37   0.908961
# 38   0.666122
# 39   0.000000
# 40   0.968812
# 41   0.956283
# 42   0.901141
# 43   0.750783

# %% [markdown]
# Finally, I can merge this foodscore into our master file so we will have all the scores in one place.

# %%
austx_zrpf = austx_zrp[:] #make copy
austx_zrpf = pd.merge(austx_zrp,austx_food[['zip','foodscore']],on='zip', how='left')
austx_zrpf
# Out:
#       zip       lat       lng    city state_id  population  rent3br  rent4br  \
# 0   78701  30.27049 -97.74235  Austin       TX        9427     2770     3310
# 1   78702  30.26327 -97.71432  Austin       TX       23389     1790     2140
# 2   78703  30.29409 -97.76571  Austin       TX       20890     2020     2420
# 3   78704  30.24315 -97.76537  Austin       TX       48486     2170     2590
# 4   78705  30.29437 -97.73855  Austin       TX       33948     2450     2920
# 5   78712  30.28502 -97.73477  Austin       TX         860     2460     2930
# 6   78717  30.48988 -97.75371  Austin       TX       30218     2000     2390
# 7   78719  30.14483 -97.67083  Austin       TX        1815     1590     1920
# 8   78721  30.27005 -97.68365  Austin       TX       12492     1620     1940
# 9   78722  30.28997 -97.71465  Austin       TX        7110     2020     2420
# 10  78723  30.30427 -97.68570  Austin       TX       34569     1590     1920
# 11  78724  30.29440 -97.61415  Austin       TX       24779     1770     2110
# 12  78725  30.23581 -97.60837  Austin       TX        7886     2190     2620
# 13  78726  30.42949 -97.84207  Austin       TX       13867     1800     2150
# 14  78727  30.42950 -97.71741  Austin       TX       29509     2140     2550
# 15  78728  30.45655 -97.68986  Austin       TX       21480     1800     2150
# 16  78729  30.45842 -97.75595  Austin       TX       29315     2010     2400
# 17  78730  30.36489 -97.83731  Austin       TX        9186     2020     2420
# 18  78731  30.34736 -97.76847  Austin       TX       27175     1980     2370
# 19  78732  30.37912 -97.89310  Austin       TX       17849     2440     2910
# 20  78733  30.32323 -97.87609  Austin       TX        8611     2590     3090
# 21  78734  30.37853 -97.94961  Austin       TX       18745     2680     3200
# 22  78735  30.26590 -97.86658  Austin       TX       17923     2190     2620
# 23  78736  30.26110 -97.95944  Austin       TX        9047     2110     2520
# 24  78737  30.18779 -97.95966  Austin       TX       16160     2770     3310
# 25  78738  30.31942 -97.95838  Austin       TX       15589     2320     2770
# 26  78739  30.17845 -97.88869  Austin       TX       20312     2770     3310
# 27  78741  30.23049 -97.71401  Austin       TX       52716     1640     1950
# 28  78742  30.24413 -97.65830  Austin       TX         828     1650     1970
# 29  78744  30.18277 -97.72920  Austin       TX       48969     1690     2020
# 30  78745  30.20685 -97.79738  Austin       TX       62771     1930     2310
# 31  78746  30.29729 -97.81054  Austin       TX       28495     2410     2880
# 32  78747  30.12653 -97.74017  Austin       TX       20166     2170     2590
# 33  78748  30.16538 -97.82343  Austin       TX       50997     1960     2340
# 34  78749  30.21376 -97.85821  Austin       TX       37774     2140     2550
# 35  78750  30.41828 -97.80246  Austin       TX       30847     1950     2320
# 36  78751  30.31082 -97.72274  Austin       TX       15805     2260     2690
# 37  78752  30.33180 -97.70426  Austin       TX       21324     1600     1920
# 38  78753  30.38204 -97.67361  Austin       TX       59085     1660     1990
# 39  78754  30.35575 -97.64482  Austin       TX       24408     1870     2230
# 40  78756  30.32227 -97.74017  Austin       TX        8323     1950     2320
# 41  78757  30.35158 -97.73252  Austin       TX       24823     1830     2190
# 42  78758  30.38799 -97.70684  Austin       TX       47470     1780     2120
# 43  78759  30.40268 -97.76105  Austin       TX       42524     2050     2450
#
#     bdgt3br  isAffordable  rentscore             pool   distance  nearPool  \
# 0      -610         False  -0.616438      West Austin   1.607251      True
# 1       370          True   0.726027  Parque Zaragoza   0.168510      True
# 2       140          True   0.410959      Westenfield   0.848818      True
# 3       -10          True   0.205479           Gillis   0.734390      True
# 4      -290         False  -0.178082            Shipe   1.769221      True
# 5      -300         False  -0.191781      West Austin   2.301549      True
# 6       160          True   0.438356      Springwoods   3.798111      True
# 7       570          True   1.000000     Dove Springs   8.147567      True
# 8       540          True   0.958904           Givens   1.143478      True
# 9       140          True   0.410959        Patterson   0.739031      True
# 10      570          True   1.000000      Bartholomew   1.142250      True
# 11      390          True   0.753425    Dottie Jordan   6.105106      True
# 12      -30          True   0.178082          Civitan   7.980237      True
# 13      360          True   0.712329     Canyon Vista   5.507843      True
# 14       20          True   0.246575         Balcones   1.820022      True
# 15      360          True   0.712329         Balcones   5.643365      True
# 16      150          True   0.424658      Springwoods   2.734333      True
# 17      140          True   0.410959        Murchison   7.649753      True
# 18      180          True   0.465753        Murchison   1.150395      True
# 19     -280         False  -0.164384     Canyon Vista  11.687588     False
# 20     -430         False  -0.369863             Reed  10.345357     False
# 21     -520         False  -0.493151     Canyon Vista  16.714405     False
# 22      -30          True   0.178082     Dick Nichols   5.683519      True
# 23       50          True   0.287671     Dick Nichols  10.568972     False
# 24     -610         False  -0.616438     Dick Nichols   9.736027      True
# 25     -160          True   0.000000     Dick Nichols  14.782299     False
# 26     -610         False  -0.616438     Dick Nichols   4.726786      True
# 27      520          True   0.931507       Montopolis   1.445724      True
# 28      510          True   0.917808          Civitan   3.279002      True
# 29      470          True   0.863014     Dove Springs   1.130993      True
# 30      230          True   0.534247         Garrison   0.800950      True
# 31     -250         False  -0.123288             Reed   3.862507      True
# 32      -10          True   0.205479     Dove Springs   6.849550      True
# 33      200          True   0.493151          Dittmar   3.122580      True
# 34       20          True   0.246575     Dick Nichols   0.505727      True
# 35      210          True   0.506849     Canyon Vista   1.967804      True
# 36     -100          True   0.082192            Shipe   0.609528      True
# 37      560          True   0.986301        Brentwood   2.683783      True
# 38      500          True   0.904110     Walnut Creek   1.909593      True
# 39      290          True   0.616438    Dottie Jordan   5.362139      True
# 40      210          True   0.506849           Ramsey   1.206782      True
# 41      330          True   0.671233        Northwest   0.771882      True
# 42      380          True   0.739726     Walnut Creek   2.868177      True
# 43      110          True   0.369863     Canyon Vista   3.539981      True
#
#     poolscore  ts_result  transitscore  foodscore
# 0    0.849622        0.0      0.000000   0.971611
# 1    1.000000       52.0      0.866667   0.968812
# 2    0.928894       32.0      0.533333   0.986121
# 3    0.940854       52.0      0.866667   0.952594
# 4    0.832693        0.0      0.000000   0.992764
# 5    0.777054        0.0      0.000000   0.982668
# 6    0.620633        0.0      0.000000   0.612932
# 7    0.166026        0.0      0.000000   0.000000
# 8    0.898096       43.0      0.716667   0.549722
# 9    0.940369       55.0      0.916667   0.967125
# 10   0.898224       46.0      0.766667   0.712105
# 11   0.379505       24.0      0.400000   0.000000
# 12   0.183516        0.0      0.000000   0.000000
# 13   0.441931        0.0      0.000000   0.325569
# 14   0.827383       10.0      0.166667   0.752662
# 15   0.427766        0.0      0.000000   0.689779
# 16   0.731819        0.0      0.000000   0.793049
# 17   0.218058        0.0      0.000000   0.315227
# 18   0.897373       25.0      0.416667   0.782825
# 19  -0.203978        0.0      0.000000   0.288188
# 20  -0.063687        0.0      0.000000   0.000000
# 21  -0.729382        0.0      0.000000   0.302384
# 22   0.423569        0.0      0.000000   0.449345
# 23  -0.087060        0.0      0.000000   0.000000
# 24   0.000000        0.0      0.000000   0.262168
# 25  -0.527438        0.0      0.000000   0.536837
# 26   0.523567        0.0      0.000000   0.288188
# 27   0.866505       60.0      1.000000   0.882824
# 28   0.674890        0.0      0.000000   0.302384
# 29   0.899401       16.0      0.266667   0.318318
# 30   0.933897       41.0      0.683333   0.653844
# 31   0.613902        0.0      0.000000   0.464976
# 32   0.301695        0.0      0.000000   0.000000
# 33   0.691240       29.0      0.483333   0.567983
# 34   0.964754       32.0      0.533333   0.564085
# 35   0.811937        0.0      0.000000   0.608735
# 36   0.953905       55.0      0.916667   0.960216
# 37   0.737103       49.0      0.816667   0.908961
# 38   0.818021       33.0      0.550000   0.666122
# 39   0.457160        0.0      0.000000   0.000000
# 40   0.891479       53.0      0.883333   0.968812
# 41   0.936935       49.0      0.816667   0.956283
# 42   0.717830       40.0      0.666667   0.901141
# 43   0.647613       26.0      0.433333   0.750783

# %% [markdown]
# ## Final score computation and determination of best places to live

# %% [markdown]
# My datafile now has flags for affordability and nearby pools, as well as scores for all four of my criteria:
#  - cost
#  - pool distance
#  - transit options
#  - prefered restaurants nearby
# From this I can generate an overall livibility score and send the top contenders to realtors to narrow my search to those areas.
# Affordability is clearly one of those things that cannot be compromised on, so it should be weighted more heavily in my overall evaluation. The food choices are nice to have, but really should be more like tie-breakers between otherwise similar places.
#
# To this end, I will compute a weighted rubric as follows:
# **overall score** = **3** * *affordability* + **2** * *pool distance* + **2** * *transit score* + **1** * *food options* / **8**

# %%
austx_zrpf["overallscore"] = ( 3 * austx_zrpf["rentscore"] + 2 * austx_zrpf["poolscore"] + 2 * austx_zrpf["transitscore"] + 1 * austx_zrpf["foodscore"] ) * 0.125

# %%
austx_zrpf
# Out:
#       zip       lat       lng    city state_id  population  rent3br  rent4br  \
# 0   78701  30.27049 -97.74235  Austin       TX        9427     2770     3310
# 1   78702  30.26327 -97.71432  Austin       TX       23389     1790     2140
# 2   78703  30.29409 -97.76571  Austin       TX       20890     2020     2420
# 3   78704  30.24315 -97.76537  Austin       TX       48486     2170     2590
# 4   78705  30.29437 -97.73855  Austin       TX       33948     2450     2920
# 5   78712  30.28502 -97.73477  Austin       TX         860     2460     2930
# 6   78717  30.48988 -97.75371  Austin       TX       30218     2000     2390
# 7   78719  30.14483 -97.67083  Austin       TX        1815     1590     1920
# 8   78721  30.27005 -97.68365  Austin       TX       12492     1620     1940
# 9   78722  30.28997 -97.71465  Austin       TX        7110     2020     2420
# 10  78723  30.30427 -97.68570  Austin       TX       34569     1590     1920
# 11  78724  30.29440 -97.61415  Austin       TX       24779     1770     2110
# 12  78725  30.23581 -97.60837  Austin       TX        7886     2190     2620
# 13  78726  30.42949 -97.84207  Austin       TX       13867     1800     2150
# 14  78727  30.42950 -97.71741  Austin       TX       29509     2140     2550
# 15  78728  30.45655 -97.68986  Austin       TX       21480     1800     2150
# 16  78729  30.45842 -97.75595  Austin       TX       29315     2010     2400
# 17  78730  30.36489 -97.83731  Austin       TX        9186     2020     2420
# 18  78731  30.34736 -97.76847  Austin       TX       27175     1980     2370
# 19  78732  30.37912 -97.89310  Austin       TX       17849     2440     2910
# 20  78733  30.32323 -97.87609  Austin       TX        8611     2590     3090
# 21  78734  30.37853 -97.94961  Austin       TX       18745     2680     3200
# 22  78735  30.26590 -97.86658  Austin       TX       17923     2190     2620
# 23  78736  30.26110 -97.95944  Austin       TX        9047     2110     2520
# 24  78737  30.18779 -97.95966  Austin       TX       16160     2770     3310
# 25  78738  30.31942 -97.95838  Austin       TX       15589     2320     2770
# 26  78739  30.17845 -97.88869  Austin       TX       20312     2770     3310
# 27  78741  30.23049 -97.71401  Austin       TX       52716     1640     1950
# 28  78742  30.24413 -97.65830  Austin       TX         828     1650     1970
# 29  78744  30.18277 -97.72920  Austin       TX       48969     1690     2020
# 30  78745  30.20685 -97.79738  Austin       TX       62771     1930     2310
# 31  78746  30.29729 -97.81054  Austin       TX       28495     2410     2880
# 32  78747  30.12653 -97.74017  Austin       TX       20166     2170     2590
# 33  78748  30.16538 -97.82343  Austin       TX       50997     1960     2340
# 34  78749  30.21376 -97.85821  Austin       TX       37774     2140     2550
# 35  78750  30.41828 -97.80246  Austin       TX       30847     1950     2320
# 36  78751  30.31082 -97.72274  Austin       TX       15805     2260     2690
# 37  78752  30.33180 -97.70426  Austin       TX       21324     1600     1920
# 38  78753  30.38204 -97.67361  Austin       TX       59085     1660     1990
# 39  78754  30.35575 -97.64482  Austin       TX       24408     1870     2230
# 40  78756  30.32227 -97.74017  Austin       TX        8323     1950     2320
# 41  78757  30.35158 -97.73252  Austin       TX       24823     1830     2190
# 42  78758  30.38799 -97.70684  Austin       TX       47470     1780     2120
# 43  78759  30.40268 -97.76105  Austin       TX       42524     2050     2450
#
#     bdgt3br  isAffordable  rentscore             pool   distance  nearPool  \
# 0      -610         False  -0.616438      West Austin   1.607251      True
# 1       370          True   0.726027  Parque Zaragoza   0.168510      True
# 2       140          True   0.410959      Westenfield   0.848818      True
# 3       -10          True   0.205479           Gillis   0.734390      True
# 4      -290         False  -0.178082            Shipe   1.769221      True
# 5      -300         False  -0.191781      West Austin   2.301549      True
# 6       160          True   0.438356      Springwoods   3.798111      True
# 7       570          True   1.000000     Dove Springs   8.147567      True
# 8       540          True   0.958904           Givens   1.143478      True
# 9       140          True   0.410959        Patterson   0.739031      True
# 10      570          True   1.000000      Bartholomew   1.142250      True
# 11      390          True   0.753425    Dottie Jordan   6.105106      True
# 12      -30          True   0.178082          Civitan   7.980237      True
# 13      360          True   0.712329     Canyon Vista   5.507843      True
# 14       20          True   0.246575         Balcones   1.820022      True
# 15      360          True   0.712329         Balcones   5.643365      True
# 16      150          True   0.424658      Springwoods   2.734333      True
# 17      140          True   0.410959        Murchison   7.649753      True
# 18      180          True   0.465753        Murchison   1.150395      True
# 19     -280         False  -0.164384     Canyon Vista  11.687588     False
# 20     -430         False  -0.369863             Reed  10.345357     False
# 21     -520         False  -0.493151     Canyon Vista  16.714405     False
# 22      -30          True   0.178082     Dick Nichols   5.683519      True
# 23       50          True   0.287671     Dick Nichols  10.568972     False
# 24     -610         False  -0.616438     Dick Nichols   9.736027      True
# 25     -160          True   0.000000     Dick Nichols  14.782299     False
# 26     -610         False  -0.616438     Dick Nichols   4.726786      True
# 27      520          True   0.931507       Montopolis   1.445724      True
# 28      510          True   0.917808          Civitan   3.279002      True
# 29      470          True   0.863014     Dove Springs   1.130993      True
# 30      230          True   0.534247         Garrison   0.800950      True
# 31     -250         False  -0.123288             Reed   3.862507      True
# 32      -10          True   0.205479     Dove Springs   6.849550      True
# 33      200          True   0.493151          Dittmar   3.122580      True
# 34       20          True   0.246575     Dick Nichols   0.505727      True
# 35      210          True   0.506849     Canyon Vista   1.967804      True
# 36     -100          True   0.082192            Shipe   0.609528      True
# 37      560          True   0.986301        Brentwood   2.683783      True
# 38      500          True   0.904110     Walnut Creek   1.909593      True
# 39      290          True   0.616438    Dottie Jordan   5.362139      True
# 40      210          True   0.506849           Ramsey   1.206782      True
# 41      330          True   0.671233        Northwest   0.771882      True
# 42      380          True   0.739726     Walnut Creek   2.868177      True
# 43      110          True   0.369863     Canyon Vista   3.539981      True
#
#     poolscore  ts_result  transitscore  foodscore  overallscore
# 0    0.849622        0.0      0.000000   0.971611      0.102693
# 1    1.000000       52.0      0.866667   0.968812      0.860028
# 2    0.928894       32.0      0.533333   0.986121      0.642932
# 3    0.940854       52.0      0.866667   0.952594      0.648009
# 4    0.832693        0.0      0.000000   0.992764      0.265488
# 5    0.777054        0.0      0.000000   0.982668      0.245179
# 6    0.620633        0.0      0.000000   0.612932      0.396158
# 7    0.166026        0.0      0.000000   0.000000      0.416507
# 8    0.898096       43.0      0.716667   0.549722      0.831995
# 9    0.940369       55.0      0.916667   0.967125      0.739259
# 10   0.898224       46.0      0.766667   0.712105      0.880236
# 11   0.379505       24.0      0.400000   0.000000      0.477411
# 12   0.183516        0.0      0.000000   0.000000      0.112660
# 13   0.441931        0.0      0.000000   0.325569      0.418302
# 14   0.827383       10.0      0.166667   0.752662      0.435061
# 15   0.427766        0.0      0.000000   0.689779      0.460287
# 16   0.731819        0.0      0.000000   0.793049      0.441333
# 17   0.218058        0.0      0.000000   0.315227      0.248027
# 18   0.897373       25.0      0.416667   0.782825      0.601021
# 19  -0.203978        0.0      0.000000   0.288188     -0.076615
# 20  -0.063687        0.0      0.000000   0.000000     -0.154620
# 21  -0.729382        0.0      0.000000   0.302384     -0.329479
# 22   0.423569        0.0      0.000000   0.449345      0.228841
# 23  -0.087060        0.0      0.000000   0.000000      0.086112
# 24   0.000000        0.0      0.000000   0.262168     -0.198393
# 25  -0.527438        0.0      0.000000   0.536837     -0.064755
# 26   0.523567        0.0      0.000000   0.288188     -0.064249
# 27   0.866505       60.0      1.000000   0.882824      0.926294
# 28   0.674890        0.0      0.000000   0.302384      0.550699
# 29   0.899401       16.0      0.266667   0.318318      0.654937
# 30   0.933897       41.0      0.683333   0.653844      0.686381
# 31   0.613902        0.0      0.000000   0.464976      0.165365
# 32   0.301695        0.0      0.000000   0.000000      0.152479
# 33   0.691240       29.0      0.483333   0.567983      0.549573
# 34   0.964754       32.0      0.533333   0.564085      0.537498
# 35   0.811937        0.0      0.000000   0.608735      0.469145
# 36   0.953905       55.0      0.916667   0.960216      0.618492
# 37   0.737103       49.0      0.816667   0.908961      0.871926
# 38   0.818021       33.0      0.550000   0.666122      0.764312
# 39   0.457160        0.0      0.000000   0.000000      0.345454
# 40   0.891479       53.0      0.883333   0.968812      0.754873
# 41   0.936935       49.0      0.816667   0.956283      0.809648
# 42   0.717830       40.0      0.666667   0.901141      0.736164
# 43   0.647613       26.0      0.433333   0.750783      0.502783

# %% [markdown]
# Now we are "data complete" and can clean up our final dataframe and fix negative numbers, assign an overall ranking, and built a map of the results

# %%
austx_zrpf.dtypes
austx_final = austx_zrpf[:]
austx_final['zip'] = austx_final['zip'].astype(str)
austx_final.dtypes
austx_final['overallscore'] = austx_final['overallscore'].clip(lower = 0)

# %%
austx_sorted = austx_final.sort_values(by=['overallscore', 'bdgt3br'],ascending=[False, False])
austx_sorted['finalrank'] = austx_sorted['overallscore'].rank(method='max',ascending =False)
austx_sorted['finalrank'] = austx_sorted['finalrank'].astype(int)
austx_sorted
# Out:
#       zip       lat       lng    city state_id  population  rent3br  rent4br  \
# 27  78741  30.23049 -97.71401  Austin       TX       52716     1640     1950
# 10  78723  30.30427 -97.68570  Austin       TX       34569     1590     1920
# 37  78752  30.33180 -97.70426  Austin       TX       21324     1600     1920
# 1   78702  30.26327 -97.71432  Austin       TX       23389     1790     2140
# 8   78721  30.27005 -97.68365  Austin       TX       12492     1620     1940
# 41  78757  30.35158 -97.73252  Austin       TX       24823     1830     2190
# 38  78753  30.38204 -97.67361  Austin       TX       59085     1660     1990
# 40  78756  30.32227 -97.74017  Austin       TX        8323     1950     2320
# 9   78722  30.28997 -97.71465  Austin       TX        7110     2020     2420
# 42  78758  30.38799 -97.70684  Austin       TX       47470     1780     2120
# 30  78745  30.20685 -97.79738  Austin       TX       62771     1930     2310
# 29  78744  30.18277 -97.72920  Austin       TX       48969     1690     2020
# 3   78704  30.24315 -97.76537  Austin       TX       48486     2170     2590
# 2   78703  30.29409 -97.76571  Austin       TX       20890     2020     2420
# 36  78751  30.31082 -97.72274  Austin       TX       15805     2260     2690
# 18  78731  30.34736 -97.76847  Austin       TX       27175     1980     2370
# 28  78742  30.24413 -97.65830  Austin       TX         828     1650     1970
# 33  78748  30.16538 -97.82343  Austin       TX       50997     1960     2340
# 34  78749  30.21376 -97.85821  Austin       TX       37774     2140     2550
# 43  78759  30.40268 -97.76105  Austin       TX       42524     2050     2450
# 11  78724  30.29440 -97.61415  Austin       TX       24779     1770     2110
# 35  78750  30.41828 -97.80246  Austin       TX       30847     1950     2320
# 15  78728  30.45655 -97.68986  Austin       TX       21480     1800     2150
# 16  78729  30.45842 -97.75595  Austin       TX       29315     2010     2400
# 14  78727  30.42950 -97.71741  Austin       TX       29509     2140     2550
# 13  78726  30.42949 -97.84207  Austin       TX       13867     1800     2150
# 7   78719  30.14483 -97.67083  Austin       TX        1815     1590     1920
# 6   78717  30.48988 -97.75371  Austin       TX       30218     2000     2390
# 39  78754  30.35575 -97.64482  Austin       TX       24408     1870     2230
# 4   78705  30.29437 -97.73855  Austin       TX       33948     2450     2920
# 17  78730  30.36489 -97.83731  Austin       TX        9186     2020     2420
# 5   78712  30.28502 -97.73477  Austin       TX         860     2460     2930
# 22  78735  30.26590 -97.86658  Austin       TX       17923     2190     2620
# 31  78746  30.29729 -97.81054  Austin       TX       28495     2410     2880
# 32  78747  30.12653 -97.74017  Austin       TX       20166     2170     2590
# 12  78725  30.23581 -97.60837  Austin       TX        7886     2190     2620
# 0   78701  30.27049 -97.74235  Austin       TX        9427     2770     3310
# 23  78736  30.26110 -97.95944  Austin       TX        9047     2110     2520
# 25  78738  30.31942 -97.95838  Austin       TX       15589     2320     2770
# 19  78732  30.37912 -97.89310  Austin       TX       17849     2440     2910
# 20  78733  30.32323 -97.87609  Austin       TX        8611     2590     3090
# 21  78734  30.37853 -97.94961  Austin       TX       18745     2680     3200
# 24  78737  30.18779 -97.95966  Austin       TX       16160     2770     3310
# 26  78739  30.17845 -97.88869  Austin       TX       20312     2770     3310
#
#     bdgt3br  isAffordable  rentscore             pool   distance  nearPool  \
# 27      520          True   0.931507       Montopolis   1.445724      True
# 10      570          True   1.000000      Bartholomew   1.142250      True
# 37      560          True   0.986301        Brentwood   2.683783      True
# 1       370          True   0.726027  Parque Zaragoza   0.168510      True
# 8       540          True   0.958904           Givens   1.143478      True
# 41      330          True   0.671233        Northwest   0.771882      True
# 38      500          True   0.904110     Walnut Creek   1.909593      True
# 40      210          True   0.506849           Ramsey   1.206782      True
# 9       140          True   0.410959        Patterson   0.739031      True
# 42      380          True   0.739726     Walnut Creek   2.868177      True
# 30      230          True   0.534247         Garrison   0.800950      True
# 29      470          True   0.863014     Dove Springs   1.130993      True
# 3       -10          True   0.205479           Gillis   0.734390      True
# 2       140          True   0.410959      Westenfield   0.848818      True
# 36     -100          True   0.082192            Shipe   0.609528      True
# 18      180          True   0.465753        Murchison   1.150395      True
# 28      510          True   0.917808          Civitan   3.279002      True
# 33      200          True   0.493151          Dittmar   3.122580      True
# 34       20          True   0.246575     Dick Nichols   0.505727      True
# 43      110          True   0.369863     Canyon Vista   3.539981      True
# 11      390          True   0.753425    Dottie Jordan   6.105106      True
# 35      210          True   0.506849     Canyon Vista   1.967804      True
# 15      360          True   0.712329         Balcones   5.643365      True
# 16      150          True   0.424658      Springwoods   2.734333      True
# 14       20          True   0.246575         Balcones   1.820022      True
# 13      360          True   0.712329     Canyon Vista   5.507843      True
# 7       570          True   1.000000     Dove Springs   8.147567      True
# 6       160          True   0.438356      Springwoods   3.798111      True
# 39      290          True   0.616438    Dottie Jordan   5.362139      True
# 4      -290         False  -0.178082            Shipe   1.769221      True
# 17      140          True   0.410959        Murchison   7.649753      True
# 5      -300         False  -0.191781      West Austin   2.301549      True
# 22      -30          True   0.178082     Dick Nichols   5.683519      True
# 31     -250         False  -0.123288             Reed   3.862507      True
# 32      -10          True   0.205479     Dove Springs   6.849550      True
# 12      -30          True   0.178082          Civitan   7.980237      True
# 0      -610         False  -0.616438      West Austin   1.607251      True
# 23       50          True   0.287671     Dick Nichols  10.568972     False
# 25     -160          True   0.000000     Dick Nichols  14.782299     False
# 19     -280         False  -0.164384     Canyon Vista  11.687588     False
# 20     -430         False  -0.369863             Reed  10.345357     False
# 21     -520         False  -0.493151     Canyon Vista  16.714405     False
# 24     -610         False  -0.616438     Dick Nichols   9.736027      True
# 26     -610         False  -0.616438     Dick Nichols   4.726786      True
#
#     poolscore  ts_result  transitscore  foodscore  overallscore  finalrank
# 27   0.866505       60.0      1.000000   0.882824      0.926294          1
# 10   0.898224       46.0      0.766667   0.712105      0.880236          2
# 37   0.737103       49.0      0.816667   0.908961      0.871926          3
# 1    1.000000       52.0      0.866667   0.968812      0.860028          4
# 8    0.898096       43.0      0.716667   0.549722      0.831995          5
# 41   0.936935       49.0      0.816667   0.956283      0.809648          6
# 38   0.818021       33.0      0.550000   0.666122      0.764312          7
# 40   0.891479       53.0      0.883333   0.968812      0.754873          8
# 9    0.940369       55.0      0.916667   0.967125      0.739259          9
# 42   0.717830       40.0      0.666667   0.901141      0.736164         10
# 30   0.933897       41.0      0.683333   0.653844      0.686381         11
# 29   0.899401       16.0      0.266667   0.318318      0.654937         12
# 3    0.940854       52.0      0.866667   0.952594      0.648009         13
# 2    0.928894       32.0      0.533333   0.986121      0.642932         14
# 36   0.953905       55.0      0.916667   0.960216      0.618492         15
# 18   0.897373       25.0      0.416667   0.782825      0.601021         16
# 28   0.674890        0.0      0.000000   0.302384      0.550699         17
# 33   0.691240       29.0      0.483333   0.567983      0.549573         18
# 34   0.964754       32.0      0.533333   0.564085      0.537498         19
# 43   0.647613       26.0      0.433333   0.750783      0.502783         20
# 11   0.379505       24.0      0.400000   0.000000      0.477411         21
# 35   0.811937        0.0      0.000000   0.608735      0.469145         22
# 15   0.427766        0.0      0.000000   0.689779      0.460287         23
# 16   0.731819        0.0      0.000000   0.793049      0.441333         24
# 14   0.827383       10.0      0.166667   0.752662      0.435061         25
# 13   0.441931        0.0      0.000000   0.325569      0.418302         26
# 7    0.166026        0.0      0.000000   0.000000      0.416507         27
# 6    0.620633        0.0      0.000000   0.612932      0.396158         28
# 39   0.457160        0.0      0.000000   0.000000      0.345454         29
# 4    0.832693        0.0      0.000000   0.992764      0.265488         30
# 17   0.218058        0.0      0.000000   0.315227      0.248027         31
# 5    0.777054        0.0      0.000000   0.982668      0.245179         32
# 22   0.423569        0.0      0.000000   0.449345      0.228841         33
# 31   0.613902        0.0      0.000000   0.464976      0.165365         34
# 32   0.301695        0.0      0.000000   0.000000      0.152479         35
# 12   0.183516        0.0      0.000000   0.000000      0.112660         36
# 0    0.849622        0.0      0.000000   0.971611      0.102693         37
# 23  -0.087060        0.0      0.000000   0.000000      0.086112         38
# 25  -0.527438        0.0      0.000000   0.536837      0.000000         44
# 19  -0.203978        0.0      0.000000   0.288188      0.000000         44
# 20  -0.063687        0.0      0.000000   0.000000      0.000000         44
# 21  -0.729382        0.0      0.000000   0.302384      0.000000         44
# 24   0.000000        0.0      0.000000   0.262168      0.000000         44
# 26   0.523567        0.0      0.000000   0.288188      0.000000         44

# %%
def assigncolor(affordflag, poolflag, score):
    return

finalmap = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, zipcode, population in zip(austx_zips['lat'], austx_zips['lng'], austx_zips['zip'], austx_zips['population']):
    label = str(zipcode)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=2*int(np.log10(population)), #scales the points to represent population in that zip
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(austxmap)  
    
austxmap

# %%
final_map = folium.Map(
   location=[latitude, longitude], zoom_start=10,
   tiles='Stamen Toner'
)
mygeofile = r'austin_zips.json'
final_map.choropleth(
   geo_data = mygeofile,
   data = austx_final,
   columns = ['zip', 'overallscore'],
   key_on = 'feature.properties.zipcode',
   fill_color = 'RdYlGn',
   legend_name = 'Final Score for Optimal Austin Areas'
)

for lat, lng, zipcode,ranknum in builtins.zip(austx_sorted['lat'], austx_sorted['lng'], austx_sorted['zip'], austx_sorted['finalrank']):
    htmlstr = '<b><i>{}<br>RANK&nbsp;{}</i></b>'.format(zipcode,ranknum)
    icon = folium.DivIcon(html=htmlstr)
    folium.Marker([lat+.005, lng-.007], icon=icon).add_to(final_map)

# %%
final_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## nearly done
# Last step is to make a pretty table of the results by dropping unneeded columns and doing some column renaming

# %%
austx_zrn = austx_zr[:]
austx_zrn['rentscore'] = austx_zrn['rentscore'].clip(lower = 0)

# %%
austx_table = austx_table.drop(['state_id','bdgt3br'], axis=1)
austx_table.rename(columns={'pool':'nearestPool'}, inplace=True)
austx_table
# Out:
#       zip    city  rent3br  rentscore      nearestPool  poolscore  \
# 27  78741  Austin     1640   0.931507       Montopolis   0.866505
# 10  78723  Austin     1590   1.000000      Bartholomew   0.898224
# 37  78752  Austin     1600   0.986301        Brentwood   0.737103
# 1   78702  Austin     1790   0.726027  Parque Zaragoza   1.000000
# 8   78721  Austin     1620   0.958904           Givens   0.898096
# 41  78757  Austin     1830   0.671233        Northwest   0.936935
# 38  78753  Austin     1660   0.904110     Walnut Creek   0.818021
# 40  78756  Austin     1950   0.506849           Ramsey   0.891479
# 9   78722  Austin     2020   0.410959        Patterson   0.940369
# 42  78758  Austin     1780   0.739726     Walnut Creek   0.717830
# 30  78745  Austin     1930   0.534247         Garrison   0.933897
# 29  78744  Austin     1690   0.863014     Dove Springs   0.899401
# 3   78704  Austin     2170   0.205479           Gillis   0.940854
# 2   78703  Austin     2020   0.410959      Westenfield   0.928894
# 36  78751  Austin     2260   0.082192            Shipe   0.953905
# 18  78731  Austin     1980   0.465753        Murchison   0.897373
# 28  78742  Austin     1650   0.917808          Civitan   0.674890
# 33  78748  Austin     1960   0.493151          Dittmar   0.691240
# 34  78749  Austin     2140   0.246575     Dick Nichols   0.964754
# 43  78759  Austin     2050   0.369863     Canyon Vista   0.647613
# 11  78724  Austin     1770   0.753425    Dottie Jordan   0.379505
# 35  78750  Austin     1950   0.506849     Canyon Vista   0.811937
# 15  78728  Austin     1800   0.712329         Balcones   0.427766
# 16  78729  Austin     2010   0.424658      Springwoods   0.731819
# 14  78727  Austin     2140   0.246575         Balcones   0.827383
# 13  78726  Austin     1800   0.712329     Canyon Vista   0.441931
# 7   78719  Austin     1590   1.000000     Dove Springs   0.166026
# 6   78717  Austin     2000   0.438356      Springwoods   0.620633
# 39  78754  Austin     1870   0.616438    Dottie Jordan   0.457160
# 4   78705  Austin     2450  -0.178082            Shipe   0.832693
# 17  78730  Austin     2020   0.410959        Murchison   0.218058
# 5   78712  Austin     2460  -0.191781      West Austin   0.777054
# 22  78735  Austin     2190   0.178082     Dick Nichols   0.423569
# 31  78746  Austin     2410  -0.123288             Reed   0.613902
# 32  78747  Austin     2170   0.205479     Dove Springs   0.301695
# 12  78725  Austin     2190   0.178082          Civitan   0.183516
# 0   78701  Austin     2770  -0.616438      West Austin   0.849622
# 23  78736  Austin     2110   0.287671     Dick Nichols  -0.087060
# 25  78738  Austin     2320   0.000000     Dick Nichols  -0.527438
# 19  78732  Austin     2440  -0.164384     Canyon Vista  -0.203978
# 20  78733  Austin     2590  -0.369863             Reed  -0.063687
# 21  78734  Austin     2680  -0.493151     Canyon Vista  -0.729382
# 24  78737  Austin     2770  -0.616438     Dick Nichols   0.000000
# 26  78739  Austin     2770  -0.616438     Dick Nichols   0.523567
#
#     transitscore  foodscore  overallscore  finalrank
# 27      1.000000   0.882824      0.926294          1
# 10      0.766667   0.712105      0.880236          2
# 37      0.816667   0.908961      0.871926          3
# 1       0.866667   0.968812      0.860028          4
# 8       0.716667   0.549722      0.831995          5
# 41      0.816667   0.956283      0.809648          6
# 38      0.550000   0.666122      0.764312          7
# 40      0.883333   0.968812      0.754873          8
# 9       0.916667   0.967125      0.739259          9
# 42      0.666667   0.901141      0.736164         10
# 30      0.683333   0.653844      0.686381         11
# 29      0.266667   0.318318      0.654937         12
# 3       0.866667   0.952594      0.648009         13
# 2       0.533333   0.986121      0.642932         14
# 36      0.916667   0.960216      0.618492         15
# 18      0.416667   0.782825      0.601021         16
# 28      0.000000   0.302384      0.550699         17
# 33      0.483333   0.567983      0.549573         18
# 34      0.533333   0.564085      0.537498         19
# 43      0.433333   0.750783      0.502783         20
# 11      0.400000   0.000000      0.477411         21
# 35      0.000000   0.608735      0.469145         22
# 15      0.000000   0.689779      0.460287         23
# 16      0.000000   0.793049      0.441333         24
# 14      0.166667   0.752662      0.435061         25
# 13      0.000000   0.325569      0.418302         26
# 7       0.000000   0.000000      0.416507         27
# 6       0.000000   0.612932      0.396158         28
# 39      0.000000   0.000000      0.345454         29
# 4       0.000000   0.992764      0.265488         30
# 17      0.000000   0.315227      0.248027         31
# 5       0.000000   0.982668      0.245179         32
# 22      0.000000   0.449345      0.228841         33
# 31      0.000000   0.464976      0.165365         34
# 32      0.000000   0.000000      0.152479         35
# 12      0.000000   0.000000      0.112660         36
# 0       0.000000   0.971611      0.102693         37
# 23      0.000000   0.000000      0.086112         38
# 25      0.000000   0.536837      0.000000         44
# 19      0.000000   0.288188      0.000000         44
# 20      0.000000   0.000000      0.000000         44
# 21      0.000000   0.302384      0.000000         44
# 24      0.000000   0.262168      0.000000         44
# 26      0.000000   0.288188      0.000000         44
